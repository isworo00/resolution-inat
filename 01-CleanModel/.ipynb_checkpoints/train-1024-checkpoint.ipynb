# %%
import os
import random
import pandas as pd
from pathlib import Path
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from torchvision.models import VGG16_BN_Weights
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from tqdm import tqdm
import time

def train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
          SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1, LR_ADJUSTMENT = False, CLASSIFIER_ONLY = False):
    df_train = pd.read_csv(TRAIN_CSV, low_memory=False)
    classes = sorted(df_train['class'].unique())
    class_to_idx = {c: i for i, c in enumerate(classes)}
    print(f"Found {len(classes)} classes: {classes}")
    
    class CSVDataset(Dataset):
        def __init__(self, csv_file, img_dir, class_to_idx, transform=None):
            self.df = pd.read_csv(csv_file, low_memory=False)
            self.img_dir = Path(img_dir)
            self.class_to_idx = class_to_idx
            self.transform = transform
    
        def __len__(self):
            return len(self.df)
    
        def __getitem__(self, idx):
            row = self.df.iloc[idx]
            img_path = self.img_dir / row['rel_path'].lstrip('/')
            image = Image.open(img_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            label = self.class_to_idx[row['class']]
            return image, label
    
    data_transforms = {
        'train': transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(10),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),
            transforms.ToTensor(),
            transforms.RandomErasing(p=0.3, scale=(0.02, 0.2), ratio=(0.3, 3.3)),  
            transforms.Normalize([0.4812775254249573, 0.4674863815307617, 0.4093940854072571],
                                 [0.19709135591983795, 0.1933959424495697, 0.19051066040992737]),
        ]),
        'val': transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.4812775254249573, 0.4674863815307617, 0.4093940854072571],
                                 [0.19709135591983795, 0.1933959424495697, 0.19051066040992737])
        ])
    }
    
    
    datasets = {
        x: CSVDataset(
            TRAIN_CSV if x == 'train' else VAL_CSV,
            IMAGE_DIR, class_to_idx,
            transform=data_transforms[x]
        ) for x in ['train', 'val']
    }
    
    dl_generator = torch.Generator()
    dl_generator.manual_seed(SEED)
    
    def seed_worker(worker_id):
        worker_seed = SEED + worker_id
        np.random.seed(worker_seed)
        random.seed(worker_seed)
    
    dataloaders = {
        x: DataLoader(
            datasets[x],
            batch_size=BATCH_SIZE,
            shuffle=(x == 'train'),
            generator=dl_generator,
            worker_init_fn=seed_worker
        ) for x in ['train', 'val']
    }
    
    dataset_sizes = {x: len(datasets[x]) for x in ['train', 'val']}
    print(f"Sizes → Train: {dataset_sizes['train']}, Val: {dataset_sizes['val']}")
    
    if SAVE_LAST.exists():
        print(f"Checkpoint found at {SAVE_LAST}, initializing random VGG-16 and loading weights")
        model = models.vgg16_bn(weights=None)
    else:
        print("No checkpoint found; initializing VGG-16 with ImageNet pretrained weights")
        model = models.vgg16_bn(weights=VGG16_BN_Weights.IMAGENET1K_V1)
    
    model.avgpool = nn.AdaptiveAvgPool2d((7,7))
    model.classifier[6] = nn.Linear(4096, len(classes))
    
    model = model.to(DEVICE)
    criterion = nn.CrossEntropyLoss()

    if CLASSIFIER_ONLY:
        optimizer = optim.AdamW([
            {'params': model.classifier.parameters(), 'lr': LEARNING_RATE}
        ], weight_decay=0.05)
    else:
        optimizer = optim.AdamW([
            {'params': model.features.parameters(), 'lr': LEARNING_RATE * 0.1 if LR_ADJUSTMENT else LEARNING_RATE},
            {'params': model.classifier.parameters(), 'lr': LEARNING_RATE}
        ], weight_decay=0.05)
    
    
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.7, patience=2, min_lr=1e-6)
    
    history = {'train_loss':[], 'val_loss':[], 'train_acc':[], 'val_acc':[],
               'train_min_acc':[], 'val_min_acc':[], 'train_f1':[], 'val_f1':[]}
    best_acc = best_f1 = 0.0
    best_min = 0.0
    best_min_ref_acc = 0.0
    start_epoch = 1
    
    if SAVE_LAST.exists():
        checkpoint = torch.load(SAVE_LAST, map_location=DEVICE, weights_only=False)
        model.load_state_dict(checkpoint['model_state'])
        optimizer.load_state_dict(checkpoint['optimizer_state'])
        scheduler.load_state_dict(checkpoint['scheduler_state'])
        best_acc = checkpoint.get('best_acc', 0.0)
        best_min = checkpoint.get('best_min', 0.0)
        best_min_ref_acc = checkpoint.get('best_min_ref_acc', 0.0)
        best_f1 = checkpoint.get('best_f1', 0.0)
        history = checkpoint.get('history', history)
        start_epoch = checkpoint.get('epoch', 0) + 1
        print(f"Resuming from epoch {start_epoch}. Loaded best_min_ref_acc={best_min_ref_acc:.4f}")
    
    t0 = time.time()
    for epoch in range(start_epoch, NUM_EPOCHS+1):
        print(f"\nEpoch {epoch}/{NUM_EPOCHS}")
        print('-'*40)
        for phase in ['train', 'val']:
            model.train() if phase == 'train' else model.eval()
            running_loss, running_corrects = 0.0, 0
            all_preds, all_labels = [], []
    
            for inputs, labels in tqdm(dataloaders[phase], desc=phase.capitalize()):
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
    
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
    
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]
            counts, corrects = [0]*len(classes), [0]*len(classes)
            for t, p in zip(all_labels, all_preds):
                counts[t] += 1
                corrects[t] += (t == p)
            min_rec = min(corrects[i]/counts[i] if counts[i] else 0 for i in range(len(classes)))
            avg_f1 = f1_score(all_labels, all_preds, average='macro')
    
            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_min_acc'].append(min_rec)
            history[f'{phase}_f1'].append(avg_f1)
            print(f"{phase.capitalize()} → Loss: {epoch_loss:.4f}, "
                  f"Avg Acc: {epoch_acc:.4f}, Min Acc: {min_rec:.4f}, Avg F1: {avg_f1:.4f}")
    
            if phase == 'val':
                scheduler.step(epoch_loss)
    
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), SAVE_BEST_ACC)
                    print(f"  -> Saved Best Avg-Acc: {best_acc:.4f}")
    

                if (min_rec > best_min) or (min_rec == best_min and epoch_acc > best_min_ref_acc):
                    prev_min = best_min
                    prev_ref = best_min_ref_acc
                    best_min = min_rec
                    best_min_ref_acc = epoch_acc
                    torch.save(model.state_dict(), SAVE_BEST_MINCLASS)
                    print(f"  -> Saved Best Min-Acc: {best_min:.4f} (was {prev_min:.4f}; ref-acc updated {prev_ref:.4f} -> {best_min_ref_acc:.4f})")
    
                if avg_f1 > best_f1:
                    best_f1 = avg_f1
                    torch.save(model.state_dict(), SAVE_BEST_F1)
                    print(f"  -> Saved Best F1: {best_f1:.4f}")
    
        if epoch % 2 == 0:
            torch.save({
                'epoch': epoch,
                'model_state': model.state_dict(),
                'optimizer_state': optimizer.state_dict(),
                'scheduler_state': scheduler.state_dict(),
                'best_acc': best_acc,
                'best_min': best_min,
                'best_min_ref_acc': best_min_ref_acc,
                'best_f1': best_f1,
                'history': history
            }, SAVE_LAST)
            print(f"Checkpoint at epoch {epoch} saved → {SAVE_LAST}")
    
    if NUM_EPOCHS % 20 != 0:
        torch.save({
            'epoch': NUM_EPOCHS,
            'model_state': model.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'scheduler_state': scheduler.state_dict(),
            'best_acc': best_acc,
            'best_min': best_min,
            'best_min_ref_acc': best_min_ref_acc,
            'best_f1': best_f1,
            'history': history
        }, SAVE_LAST)
        print(f"Final checkpoint at epoch {NUM_EPOCHS} saved → {SAVE_LAST}")
    
    print(f"\nTraining complete in {int((time.time()-t0)//60)}m{int((time.time()-t0)%60)}s")
    print(f"Final Bests → Avg Acc: {best_acc:.4f}, Min Acc: {best_min:.4f}, Best-Min Ref Acc: {best_min_ref_acc:.4f}, Avg F1: {best_f1:.4f}")
    
    plt.figure(figsize=(14,6))
    for idx, metric in enumerate(['loss','acc','min_acc','f1']):
        plt.subplot(2,2,idx+1)
        plt.plot(history[f'train_{metric}'], label=f'Train {metric.title()}')
        plt.plot(history[f'val_{metric}'], label=f'Val {metric.title()}')
        plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
MODEL_NAME    = 'Model-2'
BASE_DIR      = Path("/kaggle/input/datasetinat/01-CleanModel/Dataset")
SIZE          = 1024
IMAGE_DIR     = BASE_DIR / f"{SIZE}x{SIZE}"
TRAIN_CSV     = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_train.csv"
VAL_CSV       = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_val.csv"
BATCH_SIZE    = 4
NUM_EPOCHS    = 40
LEARNING_RATE = 0.001
DEVICE        = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

BaseOutput = f'./Models/{SIZE}x{SIZE}/'

os.makedirs(BaseOutput, exist_ok=True)

SAVE_BEST_ACC      = Path(BaseOutput+f"best_avg_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_MINCLASS = Path(BaseOutput+f"best_min_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_F1       = Path(BaseOutput+f"best_avg_f1_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_LAST          = Path(BaseOutput+f"last_checkpoint_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_FINAL         = Path(BaseOutput+f"final_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")


SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Device: {DEVICE}")

train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
      SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1, LR_ADJUSTMENT = True, CLASSIFIER_ONLY = False)
# Out:
# Device: cuda:0
# Found 7 classes: ['bird', 'cat', 'fish', 'frog', 'monkey', 'moth', 'spider']
# Sizes → Train: 2799, Val: 350
# No checkpoint found; initializing VGG-16 with ImageNet pretrained weights
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# 100%|██████████| 528M/528M [00:04<00:00, 126MB/s]
# Epoch 1/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:24<00:00,  1.41s/it]
# Train → Loss: 1.9299, Avg Acc: 0.2147, Min Acc: 0.1253, Avg F1: 0.2126
# Val: 100%|██████████| 88/88 [00:35<00:00,  2.49it/s]
# Val → Loss: 1.7745, Avg Acc: 0.2629, Min Acc: 0.0000, Avg F1: 0.1883
#   -> Saved Best Avg-Acc: 0.2629
#   -> Saved Best Min-Acc: 0.0000 (was 0.0000; ref-acc updated 0.0000 -> 0.2629)
#   -> Saved Best F1: 0.1883
#
# Epoch 2/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:43<00:00,  1.35s/it]
# Train → Loss: 1.6671, Avg Acc: 0.3512, Min Acc: 0.1975, Avg F1: 0.3481
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.93it/s]
# Val → Loss: 1.5568, Avg Acc: 0.4343, Min Acc: 0.0000, Avg F1: 0.4101
#   -> Saved Best Avg-Acc: 0.4343
#   -> Saved Best Min-Acc: 0.0000 (was 0.0000; ref-acc updated 0.2629 -> 0.4343)
#   -> Saved Best F1: 0.4101
# Checkpoint at epoch 2 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 3/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 1.4734, Avg Acc: 0.4405, Min Acc: 0.1800, Avg F1: 0.4383
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.90it/s]
# Val → Loss: 1.3700, Avg Acc: 0.4971, Min Acc: 0.0400, Avg F1: 0.4587
#   -> Saved Best Avg-Acc: 0.4971
#   -> Saved Best Min-Acc: 0.0400 (was 0.0000; ref-acc updated 0.4343 -> 0.4971)
#   -> Saved Best F1: 0.4587
#
# Epoch 4/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 1.3861, Avg Acc: 0.4691, Min Acc: 0.2675, Avg F1: 0.4694
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.90it/s]
# Val → Loss: 1.3396, Avg Acc: 0.5143, Min Acc: 0.0000, Avg F1: 0.4775
#   -> Saved Best Avg-Acc: 0.5143
#   -> Saved Best F1: 0.4775
# Checkpoint at epoch 4 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 5/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:37<00:00,  1.34s/it]
# Train → Loss: 1.3293, Avg Acc: 0.5145, Min Acc: 0.3375, Avg F1: 0.5171
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 1.3729, Avg Acc: 0.5457, Min Acc: 0.0000, Avg F1: 0.4990
#   -> Saved Best Avg-Acc: 0.5457
#   -> Saved Best F1: 0.4990
#
# Epoch 6/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:36<00:00,  1.34s/it]
# Train → Loss: 1.2511, Avg Acc: 0.5230, Min Acc: 0.2575, Avg F1: 0.5240
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 1.2150, Avg Acc: 0.5286, Min Acc: 0.0800, Avg F1: 0.4976
#   -> Saved Best Min-Acc: 0.0800 (was 0.0400; ref-acc updated 0.4971 -> 0.5286)
# Checkpoint at epoch 6 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 7/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 1.2301, Avg Acc: 0.5484, Min Acc: 0.3225, Avg F1: 0.5498
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 1.2038, Avg Acc: 0.5571, Min Acc: 0.3400, Avg F1: 0.5587
#   -> Saved Best Avg-Acc: 0.5571
#   -> Saved Best Min-Acc: 0.3400 (was 0.0800; ref-acc updated 0.5286 -> 0.5571)
#   -> Saved Best F1: 0.5587
#
# Epoch 8/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 1.1723, Avg Acc: 0.5684, Min Acc: 0.3550, Avg F1: 0.5721
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 1.3742, Avg Acc: 0.5743, Min Acc: 0.2000, Avg F1: 0.5629
#   -> Saved Best Avg-Acc: 0.5743
#   -> Saved Best F1: 0.5629
# Checkpoint at epoch 8 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 9/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 1.1609, Avg Acc: 0.5723, Min Acc: 0.3550, Avg F1: 0.5755
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 1.2730, Avg Acc: 0.5771, Min Acc: 0.3000, Avg F1: 0.5701
#   -> Saved Best Avg-Acc: 0.5771
#   -> Saved Best F1: 0.5701
#
# Epoch 10/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:32<00:00,  1.33s/it]
# Train → Loss: 1.1067, Avg Acc: 0.6141, Min Acc: 0.4300, Avg F1: 0.6172
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 1.1808, Avg Acc: 0.6114, Min Acc: 0.2400, Avg F1: 0.6080
#   -> Saved Best Avg-Acc: 0.6114
#   -> Saved Best F1: 0.6080
# Checkpoint at epoch 10 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 11/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 1.0614, Avg Acc: 0.6034, Min Acc: 0.4075, Avg F1: 0.6064
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 1.1164, Avg Acc: 0.6343, Min Acc: 0.4200, Avg F1: 0.6408
#   -> Saved Best Avg-Acc: 0.6343
#   -> Saved Best Min-Acc: 0.4200 (was 0.3400; ref-acc updated 0.5571 -> 0.6343)
#   -> Saved Best F1: 0.6408
#
# Epoch 12/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:34<00:00,  1.33s/it]
# Train → Loss: 1.0300, Avg Acc: 0.6284, Min Acc: 0.4350, Avg F1: 0.6315
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.91it/s]
# Val → Loss: 1.0197, Avg Acc: 0.6571, Min Acc: 0.3600, Avg F1: 0.6622
#   -> Saved Best Avg-Acc: 0.6571
#   -> Saved Best F1: 0.6622
# Checkpoint at epoch 12 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 13/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:34<00:00,  1.34s/it]
# Train → Loss: 0.9783, Avg Acc: 0.6488, Min Acc: 0.4575, Avg F1: 0.6501
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 0.9682, Avg Acc: 0.6657, Min Acc: 0.5400, Avg F1: 0.6751
#   -> Saved Best Avg-Acc: 0.6657
#   -> Saved Best Min-Acc: 0.5400 (was 0.4200; ref-acc updated 0.6343 -> 0.6657)
#   -> Saved Best F1: 0.6751
#
# Epoch 14/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:34<00:00,  1.33s/it]
# Train → Loss: 0.9502, Avg Acc: 0.6495, Min Acc: 0.4550, Avg F1: 0.6531
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.90it/s]
# Val → Loss: 1.0638, Avg Acc: 0.6686, Min Acc: 0.3600, Avg F1: 0.6665
#   -> Saved Best Avg-Acc: 0.6686
# Checkpoint at epoch 14 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 15/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:32<00:00,  1.33s/it]
# Train → Loss: 0.9266, Avg Acc: 0.6735, Min Acc: 0.4925, Avg F1: 0.6761
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.90it/s]
# Val → Loss: 0.9823, Avg Acc: 0.6771, Min Acc: 0.5200, Avg F1: 0.6805
#   -> Saved Best Avg-Acc: 0.6771
#   -> Saved Best F1: 0.6805
#
# Epoch 16/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:34<00:00,  1.33s/it]
# Train → Loss: 0.9002, Avg Acc: 0.6885, Min Acc: 0.4850, Avg F1: 0.6896
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 1.1202, Avg Acc: 0.6114, Min Acc: 0.3600, Avg F1: 0.6169
# Checkpoint at epoch 16 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 17/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 0.8136, Avg Acc: 0.7170, Min Acc: 0.5625, Avg F1: 0.7197
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 0.9728, Avg Acc: 0.6914, Min Acc: 0.5200, Avg F1: 0.6976
#   -> Saved Best Avg-Acc: 0.6914
#   -> Saved Best F1: 0.6976
#
# Epoch 18/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:36<00:00,  1.34s/it]
# Train → Loss: 0.7560, Avg Acc: 0.7320, Min Acc: 0.5375, Avg F1: 0.7339
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.96it/s]
# Val → Loss: 0.8757, Avg Acc: 0.6886, Min Acc: 0.5400, Avg F1: 0.6945
#   -> Saved Best Min-Acc: 0.5400 (was 0.5400; ref-acc updated 0.6657 -> 0.6886)
# Checkpoint at epoch 18 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 19/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 0.7036, Avg Acc: 0.7553, Min Acc: 0.5900, Avg F1: 0.7568
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 1.2064, Avg Acc: 0.6629, Min Acc: 0.3000, Avg F1: 0.6600
#
# Epoch 20/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 0.6787, Avg Acc: 0.7553, Min Acc: 0.6000, Avg F1: 0.7571
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 0.9410, Avg Acc: 0.7343, Min Acc: 0.6000, Avg F1: 0.7410
#   -> Saved Best Avg-Acc: 0.7343
#   -> Saved Best Min-Acc: 0.6000 (was 0.5400; ref-acc updated 0.6886 -> 0.7343)
#   -> Saved Best F1: 0.7410
# Checkpoint at epoch 20 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 21/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 0.6756, Avg Acc: 0.7724, Min Acc: 0.6350, Avg F1: 0.7749
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.93it/s]
# Val → Loss: 0.8815, Avg Acc: 0.7229, Min Acc: 0.3800, Avg F1: 0.7169
#
# Epoch 22/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:33<00:00,  1.33s/it]
# Train → Loss: 0.5764, Avg Acc: 0.7874, Min Acc: 0.6275, Avg F1: 0.7889
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 1.0051, Avg Acc: 0.7400, Min Acc: 0.5800, Avg F1: 0.7463
#   -> Saved Best Avg-Acc: 0.7400
#   -> Saved Best F1: 0.7463
# Checkpoint at epoch 22 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 23/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:37<00:00,  1.34s/it]
# Train → Loss: 0.5368, Avg Acc: 0.8156, Min Acc: 0.6500, Avg F1: 0.8172
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 0.8057, Avg Acc: 0.7714, Min Acc: 0.5600, Avg F1: 0.7707
#   -> Saved Best Avg-Acc: 0.7714
#   -> Saved Best F1: 0.7707
#
# Epoch 24/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 0.4934, Avg Acc: 0.8249, Min Acc: 0.6575, Avg F1: 0.8253
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 1.0503, Avg Acc: 0.7486, Min Acc: 0.5800, Avg F1: 0.7473
# Checkpoint at epoch 24 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 25/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:38<00:00,  1.34s/it]
# Train → Loss: 0.5188, Avg Acc: 0.8139, Min Acc: 0.6700, Avg F1: 0.8148
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.90it/s]
# Val → Loss: 0.8286, Avg Acc: 0.7571, Min Acc: 0.4400, Avg F1: 0.7528
#
# Epoch 26/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:36<00:00,  1.34s/it]
# Train → Loss: 0.4818, Avg Acc: 0.8374, Min Acc: 0.6800, Avg F1: 0.8382
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.91it/s]
# Val → Loss: 0.9266, Avg Acc: 0.7543, Min Acc: 0.6200, Avg F1: 0.7568
#   -> Saved Best Min-Acc: 0.6200 (was 0.6000; ref-acc updated 0.7343 -> 0.7543)
# Checkpoint at epoch 26 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 27/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 0.4253, Avg Acc: 0.8449, Min Acc: 0.6875, Avg F1: 0.8457
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.91it/s]
# Val → Loss: 0.9119, Avg Acc: 0.7571, Min Acc: 0.5400, Avg F1: 0.7563
#
# Epoch 28/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:36<00:00,  1.34s/it]
# Train → Loss: 0.3910, Avg Acc: 0.8560, Min Acc: 0.7175, Avg F1: 0.8567
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.91it/s]
# Val → Loss: 0.8911, Avg Acc: 0.7571, Min Acc: 0.5800, Avg F1: 0.7560
# Checkpoint at epoch 28 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 29/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:41<00:00,  1.34s/it]
# Train → Loss: 0.3751, Avg Acc: 0.8717, Min Acc: 0.7325, Avg F1: 0.8726
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.92it/s]
# Val → Loss: 0.8744, Avg Acc: 0.7743, Min Acc: 0.6800, Avg F1: 0.7759
#   -> Saved Best Avg-Acc: 0.7743
#   -> Saved Best Min-Acc: 0.6800 (was 0.6200; ref-acc updated 0.7543 -> 0.7743)
#   -> Saved Best F1: 0.7759
#
# Epoch 30/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:39<00:00,  1.34s/it]
# Train → Loss: 0.3340, Avg Acc: 0.8778, Min Acc: 0.7375, Avg F1: 0.8787
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.91it/s]
# Val → Loss: 0.8473, Avg Acc: 0.7714, Min Acc: 0.6200, Avg F1: 0.7717
# Checkpoint at epoch 30 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 31/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:36<00:00,  1.34s/it]
# Train → Loss: 0.3181, Avg Acc: 0.8857, Min Acc: 0.7675, Avg F1: 0.8861
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.94it/s]
# Val → Loss: 0.9044, Avg Acc: 0.7800, Min Acc: 0.7000, Avg F1: 0.7851
#   -> Saved Best Avg-Acc: 0.7800
#   -> Saved Best Min-Acc: 0.7000 (was 0.6800; ref-acc updated 0.7743 -> 0.7800)
#   -> Saved Best F1: 0.7851
#
# Epoch 32/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:36<00:00,  1.34s/it]
# Train → Loss: 0.3016, Avg Acc: 0.8953, Min Acc: 0.7800, Avg F1: 0.8958
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.88it/s]
# Val → Loss: 0.8144, Avg Acc: 0.7857, Min Acc: 0.5400, Avg F1: 0.7844
#   -> Saved Best Avg-Acc: 0.7857
# Checkpoint at epoch 32 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 33/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:37<00:00,  1.34s/it]
# Train → Loss: 0.2801, Avg Acc: 0.9028, Min Acc: 0.7875, Avg F1: 0.9032
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.95it/s]
# Val → Loss: 0.8406, Avg Acc: 0.8000, Min Acc: 0.7200, Avg F1: 0.8008
#   -> Saved Best Avg-Acc: 0.8000
#   -> Saved Best Min-Acc: 0.7200 (was 0.7000; ref-acc updated 0.7800 -> 0.8000)
#   -> Saved Best F1: 0.8008
#
# Epoch 34/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 0.2489, Avg Acc: 0.9143, Min Acc: 0.8125, Avg F1: 0.9145
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.93it/s]
# Val → Loss: 0.9874, Avg Acc: 0.7714, Min Acc: 0.5800, Avg F1: 0.7705
# Checkpoint at epoch 34 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 35/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 0.2362, Avg Acc: 0.9171, Min Acc: 0.7925, Avg F1: 0.9172
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.87it/s]
# Val → Loss: 0.9573, Avg Acc: 0.7657, Min Acc: 0.6800, Avg F1: 0.7695
#
# Epoch 36/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:37<00:00,  1.34s/it]
# Train → Loss: 0.2202, Avg Acc: 0.9268, Min Acc: 0.8275, Avg F1: 0.9269
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.85it/s]
# Val → Loss: 0.8947, Avg Acc: 0.7714, Min Acc: 0.6200, Avg F1: 0.7703
# Checkpoint at epoch 36 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 37/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:34<00:00,  1.33s/it]
# Train → Loss: 0.2199, Avg Acc: 0.9275, Min Acc: 0.8300, Avg F1: 0.9277
# Val: 100%|██████████| 88/88 [00:31<00:00,  2.84it/s]
# Val → Loss: 0.9147, Avg Acc: 0.7971, Min Acc: 0.7200, Avg F1: 0.7991
#
# Epoch 38/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 0.1955, Avg Acc: 0.9353, Min Acc: 0.8475, Avg F1: 0.9356
# Val: 100%|██████████| 88/88 [00:30<00:00,  2.91it/s]
# Val → Loss: 1.1105, Avg Acc: 0.7829, Min Acc: 0.7200, Avg F1: 0.7866
# Checkpoint at epoch 38 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 39/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:35<00:00,  1.34s/it]
# Train → Loss: 0.1873, Avg Acc: 0.9307, Min Acc: 0.8550, Avg F1: 0.9312
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.94it/s]
# Val → Loss: 1.0315, Avg Acc: 0.7914, Min Acc: 0.7000, Avg F1: 0.7928
#
# Epoch 40/40
# ----------------------------------------
# Train: 100%|██████████| 700/700 [15:34<00:00,  1.34s/it]
# Train → Loss: 0.1563, Avg Acc: 0.9475, Min Acc: 0.8650, Avg F1: 0.9477
# Val: 100%|██████████| 88/88 [00:29<00:00,  2.94it/s]
# Val → Loss: 1.0332, Avg Acc: 0.7857, Min Acc: 0.6400, Avg F1: 0.7858
# Checkpoint at epoch 40 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Training complete in 647m32s
# Final Bests → Avg Acc: 0.8000, Min Acc: 0.7200, Best-Min Ref Acc: 0.8000, Avg F1: 0.8008

# %%
MODEL_NAME    = 'Model-2'
BASE_DIR      = Path("/kaggle/input/datasetinat/01-CleanModel/Dataset")
SIZE          = 1024
IMAGE_DIR     = BASE_DIR / f"{SIZE}x{SIZE}"
TRAIN_CSV     = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_train.csv"
VAL_CSV       = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_val.csv"
BATCH_SIZE    = 4
NUM_EPOCHS    = 50
LEARNING_RATE = 0.001
DEVICE        = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

BaseOutput = f'./Models/{SIZE}x{SIZE}/'

os.makedirs(BaseOutput, exist_ok=True)

SAVE_BEST_ACC      = Path(BaseOutput+f"best_avg_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_MINCLASS = Path(BaseOutput+f"best_min_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_F1       = Path(BaseOutput+f"best_avg_f1_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_LAST          = Path(BaseOutput+f"last_checkpoint_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_FINAL         = Path(BaseOutput+f"final_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")


SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Device: {DEVICE}")

train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
      SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1, LR_ADJUSTMENT = True, CLASSIFIER_ONLY = False)
# Out:
# Device: cuda:0
# Found 7 classes: ['bird', 'cat', 'fish', 'frog', 'monkey', 'moth', 'spider']
# Sizes → Train: 2799, Val: 350
# Checkpoint found at Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth, initializing random VGG-16 and loading weights
# Resuming from epoch 41. Loaded best_min_ref_acc=0.8000
#
# Epoch 41/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:57<00:00,  1.45s/it]
# Train → Loss: 0.1686, Avg Acc: 0.9432, Min Acc: 0.8800, Avg F1: 0.9434
# Val: 100%|██████████| 88/88 [00:36<00:00,  2.44it/s]
# Val → Loss: 1.0429, Avg Acc: 0.7886, Min Acc: 0.7000, Avg F1: 0.7901
#
# Epoch 42/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:27<00:00,  1.41s/it]
# Train → Loss: 0.1546, Avg Acc: 0.9482, Min Acc: 0.8850, Avg F1: 0.9483
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.71it/s]
# Val → Loss: 1.0076, Avg Acc: 0.7829, Min Acc: 0.7000, Avg F1: 0.7852
# Checkpoint at epoch 42 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 43/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:28<00:00,  1.41s/it]
# Train → Loss: 0.1558, Avg Acc: 0.9496, Min Acc: 0.8900, Avg F1: 0.9500
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.69it/s]
# Val → Loss: 0.9745, Avg Acc: 0.8029, Min Acc: 0.7000, Avg F1: 0.8034
#   -> Saved Best Avg-Acc: 0.8029
#   -> Saved Best F1: 0.8034
#
# Epoch 44/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:26<00:00,  1.41s/it]
# Train → Loss: 0.1467, Avg Acc: 0.9496, Min Acc: 0.8650, Avg F1: 0.9498
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.72it/s]
# Val → Loss: 0.9983, Avg Acc: 0.7914, Min Acc: 0.6800, Avg F1: 0.7916
# Checkpoint at epoch 44 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 45/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:26<00:00,  1.41s/it]
# Train → Loss: 0.1457, Avg Acc: 0.9514, Min Acc: 0.8950, Avg F1: 0.9516
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.74it/s]
# Val → Loss: 1.1213, Avg Acc: 0.7857, Min Acc: 0.6800, Avg F1: 0.7870
#
# Epoch 46/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:26<00:00,  1.41s/it]
# Train → Loss: 0.1316, Avg Acc: 0.9539, Min Acc: 0.8975, Avg F1: 0.9539
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.69it/s]
# Val → Loss: 0.9975, Avg Acc: 0.8057, Min Acc: 0.7000, Avg F1: 0.8066
#   -> Saved Best Avg-Acc: 0.8057
#   -> Saved Best F1: 0.8066
# Checkpoint at epoch 46 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 47/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:30<00:00,  1.42s/it]
# Train → Loss: 0.1272, Avg Acc: 0.9561, Min Acc: 0.9125, Avg F1: 0.9561
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.69it/s]
# Val → Loss: 1.0931, Avg Acc: 0.7886, Min Acc: 0.7000, Avg F1: 0.7902
#
# Epoch 48/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:30<00:00,  1.42s/it]
# Train → Loss: 0.1193, Avg Acc: 0.9600, Min Acc: 0.9125, Avg F1: 0.9600
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.67it/s]
# Val → Loss: 1.1184, Avg Acc: 0.7829, Min Acc: 0.6800, Avg F1: 0.7841
# Checkpoint at epoch 48 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Epoch 49/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:29<00:00,  1.41s/it]
# Train → Loss: 0.1267, Avg Acc: 0.9564, Min Acc: 0.8950, Avg F1: 0.9565
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.70it/s]
# Val → Loss: 1.0684, Avg Acc: 0.8057, Min Acc: 0.7200, Avg F1: 0.8058
#   -> Saved Best Min-Acc: 0.7200 (was 0.7200; ref-acc updated 0.8000 -> 0.8057)
#
# Epoch 50/50
# ----------------------------------------
# Train: 100%|██████████| 700/700 [16:29<00:00,  1.41s/it]
# Train → Loss: 0.1290, Avg Acc: 0.9589, Min Acc: 0.9025, Avg F1: 0.9589
# Val: 100%|██████████| 88/88 [00:32<00:00,  2.69it/s]
# Val → Loss: 1.0496, Avg Acc: 0.8057, Min Acc: 0.7200, Avg F1: 0.8058
# Checkpoint at epoch 50 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
# Final checkpoint at epoch 50 saved → Models/1024x1024/last_checkpoint_vgg16_1024x1024_Model-2.pth
#
# Training complete in 171m20s
# Final Bests → Avg Acc: 0.8057, Min Acc: 0.7200, Best-Min Ref Acc: 0.8057, Avg F1: 0.8066
