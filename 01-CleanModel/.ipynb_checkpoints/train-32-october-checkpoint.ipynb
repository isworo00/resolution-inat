# %%
import os
import random
import pandas as pd
from pathlib import Path
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from torchvision.models import VGG16_BN_Weights
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from tqdm import tqdm
import time

def train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
          SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1, LR_ADJUSTMENT = False, CLASSIFIER_ONLY = False):
    # Cell 3: Dataset and Class Mapping
    df_train = pd.read_csv(TRAIN_CSV, low_memory=False)
    classes = sorted(df_train['class'].unique())
    class_to_idx = {c: i for i, c in enumerate(classes)}
    print(f"Found {len(classes)} classes: {classes}")
    
    class CSVDataset(Dataset):
        def __init__(self, csv_file, img_dir, class_to_idx, transform=None):
            self.df = pd.read_csv(csv_file, low_memory=False)
            self.img_dir = Path(img_dir)
            self.class_to_idx = class_to_idx
            self.transform = transform
    
        def __len__(self):
            return len(self.df)
    
        def __getitem__(self, idx):
            row = self.df.iloc[idx]
            img_path = self.img_dir / row['rel_path'].lstrip('/')
            image = Image.open(img_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            label = self.class_to_idx[row['class']]
            return image, label
    
    # Cell 4: Transforms & DataLoaders
    data_transforms = {
        'train': transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(10),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),
            transforms.ToTensor(),
            transforms.RandomErasing(p=0.3, scale=(0.02, 0.2), ratio=(0.3, 3.3)),  
            transforms.Normalize([0.4812775254249573, 0.4674863815307617, 0.4093940854072571],
                                 [0.19709135591983795, 0.1933959424495697, 0.19051066040992737]),
        ]),
        'val': transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.4812775254249573, 0.4674863815307617, 0.4093940854072571],
                                 [0.19709135591983795, 0.1933959424495697, 0.19051066040992737])
        ])
    }
    
    
    datasets = {
        x: CSVDataset(
            TRAIN_CSV if x == 'train' else VAL_CSV,
            IMAGE_DIR, class_to_idx,
            transform=data_transforms[x]
        ) for x in ['train', 'val']
    }
    
    # Use a seeded Generator for DataLoader to help reproducibility
    dl_generator = torch.Generator()
    dl_generator.manual_seed(SEED)
    
    def seed_worker(worker_id):
        worker_seed = SEED + worker_id
        np.random.seed(worker_seed)
        random.seed(worker_seed)
    
    # If you use multiple workers, pass worker_init_fn=seed_worker for determinism
    dataloaders = {
        x: DataLoader(
            datasets[x],
            batch_size=BATCH_SIZE,
            shuffle=(x == 'train'),
            generator=dl_generator,
            worker_init_fn=seed_worker
        ) for x in ['train', 'val']
    }
    
    dataset_sizes = {x: len(datasets[x]) for x in ['train', 'val']}
    print(f"Sizes → Train: {dataset_sizes['train']}, Val: {dataset_sizes['val']}")
    
    # Cell 5: Model, Loss, Optimizer, Scheduler
    # Use ImageNet pretrained if no checkpoint, else random init
    if SAVE_LAST.exists():
        print(f"Checkpoint found at {SAVE_LAST}, initializing random VGG-16 and loading weights")
        model = models.vgg16_bn(weights=None)
    else:
        print("No checkpoint found; initializing VGG-16 with ImageNet pretrained weights")
        model = models.vgg16_bn(weights=VGG16_BN_Weights.IMAGENET1K_V1)
    
    model.avgpool = nn.AdaptiveAvgPool2d((7,7))
    model.classifier[6] = nn.Linear(4096, len(classes))
    
    model = model.to(DEVICE)
    criterion = nn.CrossEntropyLoss()

    if CLASSIFIER_ONLY:
        optimizer = optim.AdamW([
            {'params': model.classifier.parameters(), 'lr': LEARNING_RATE}
        ], weight_decay=0.05)
    else:
        optimizer = optim.AdamW([
            {'params': model.features.parameters(), 'lr': LEARNING_RATE * 0.1 if LR_ADJUSTMENT else LEARNING_RATE},
            {'params': model.classifier.parameters(), 'lr': LEARNING_RATE}
        ], weight_decay=0.05)
    
    
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.7, patience=2, min_lr=1e-6)
    
    # Cell 6: Resume or Initialize
    history = {'train_loss':[], 'val_loss':[], 'train_acc':[], 'val_acc':[],
               'train_min_acc':[], 'val_min_acc':[], 'train_f1':[], 'val_f1':[]}
    # best_acc remains the global best val avg-acc
    best_acc = best_f1 = 0.0
    # best_min stores the best min-class recall
    best_min = 0.0
    # best_min_ref_acc stores the average accuracy that accompanied the saved best_min checkpoint
    best_min_ref_acc = 0.0
    start_epoch = 1
    
    if SAVE_LAST.exists():
        checkpoint = torch.load(SAVE_LAST, map_location=DEVICE, weights_only = False)
        model.load_state_dict(checkpoint['model_state'])
        optimizer.load_state_dict(checkpoint['optimizer_state'])
        scheduler.load_state_dict(checkpoint['scheduler_state'])
        best_acc = checkpoint.get('best_acc', 0.0)
        best_min = checkpoint.get('best_min', 0.0)
        best_min_ref_acc = checkpoint.get('best_min_ref_acc', 0.0)
        best_f1 = checkpoint.get('best_f1', 0.0)
        history = checkpoint.get('history', history)
        start_epoch = checkpoint.get('epoch', 0) + 1
        print(f"Resuming from epoch {start_epoch}. Loaded best_min_ref_acc={best_min_ref_acc:.4f}")
    
    # Cell 7: Training Loop with Resume and Saving
    t0 = time.time()
    for epoch in range(start_epoch, NUM_EPOCHS+1):
        print(f"\nEpoch {epoch}/{NUM_EPOCHS}")
        print('-'*40)
        for phase in ['train', 'val']:
            model.train() if phase == 'train' else model.eval()
            running_loss, running_corrects = 0.0, 0
            all_preds, all_labels = [], []
    
            for inputs, labels in tqdm(dataloaders[phase], desc=phase.capitalize()):
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
    
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
    
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]
            counts, corrects = [0]*len(classes), [0]*len(classes)
            for t, p in zip(all_labels, all_preds):
                counts[t] += 1
                corrects[t] += (t == p)
            min_rec = min(corrects[i]/counts[i] if counts[i] else 0 for i in range(len(classes)))
            avg_f1 = f1_score(all_labels, all_preds, average='macro')
    
            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_min_acc'].append(min_rec)
            history[f'{phase}_f1'].append(avg_f1)
            print(f"{phase.capitalize()} → Loss: {epoch_loss:.4f}, "
                  f"Avg Acc: {epoch_acc:.4f}, Min Acc: {min_rec:.4f}, Avg F1: {avg_f1:.4f}")
    
            if phase == 'val':
                # scheduler.step using val-loss
                scheduler.step(epoch_loss)
    
                # Save best average accuracy (global)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), SAVE_BEST_ACC)
                    print(f"  -> Saved Best Avg-Acc: {best_acc:.4f}")
    
                # NEW: compare against best_min and best_min_ref_acc
                # Condition to save best-min checkpoint:
                # 1) if min_rec > best_min -> obvious improvement
                # 2) if min_rec == best_min AND epoch_acc > best_min_ref_acc -> prefer newer model because it has
                #    same min but better average acc than the one we saved previously for best_min.
                if (min_rec > best_min) or (min_rec == best_min and epoch_acc > best_min_ref_acc):
                    prev_min = best_min
                    prev_ref = best_min_ref_acc
                    best_min = min_rec
                    best_min_ref_acc = epoch_acc
                    torch.save(model.state_dict(), SAVE_BEST_MINCLASS)
                    print(f"  -> Saved Best Min-Acc: {best_min:.4f} (was {prev_min:.4f}; ref-acc updated {prev_ref:.4f} -> {best_min_ref_acc:.4f})")
    
                # Save best F1 (unchanged behaviour)
                if avg_f1 > best_f1:
                    best_f1 = avg_f1
                    torch.save(model.state_dict(), SAVE_BEST_F1)
                    print(f"  -> Saved Best F1: {best_f1:.4f}")
    
        # Save last checkpoint every 20 epochs (include best_min_ref_acc)
        if epoch % 20 == 0:
            torch.save({
                'epoch': epoch,
                'model_state': model.state_dict(),
                'optimizer_state': optimizer.state_dict(),
                'scheduler_state': scheduler.state_dict(),
                'best_acc': best_acc,
                'best_min': best_min,
                'best_min_ref_acc': best_min_ref_acc,
                'best_f1': best_f1,
                'history': history
            }, SAVE_LAST)
            print(f"Checkpoint at epoch {epoch} saved → {SAVE_LAST}")
    
    # Optional final save if NUM_EPOCHS not divisible by 20
    if NUM_EPOCHS % 20 != 0:
        torch.save({
            'epoch': NUM_EPOCHS,
            'model_state': model.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'scheduler_state': scheduler.state_dict(),
            'best_acc': best_acc,
            'best_min': best_min,
            'best_min_ref_acc': best_min_ref_acc,
            'best_f1': best_f1,
            'history': history
        }, SAVE_LAST)
        print(f"Final checkpoint at epoch {NUM_EPOCHS} saved → {SAVE_LAST}")
    
    print(f"\nTraining complete in {int((time.time()-t0)//60)}m{int((time.time()-t0)%60)}s")
    print(f"Final Bests → Avg Acc: {best_acc:.4f}, Min Acc: {best_min:.4f}, Best-Min Ref Acc: {best_min_ref_acc:.4f}, Avg F1: {best_f1:.4f}")
    
    # Cell 8: Plot Training History
    plt.figure(figsize=(14,6))
    for idx, metric in enumerate(['loss','acc','min_acc','f1']):
        plt.subplot(2,2,idx+1)
        plt.plot(history[f'train_{metric}'], label=f'Train {metric.title()}')
        plt.plot(history[f'val_{metric}'], label=f'Val {metric.title()}')
        plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
MODEL_NAME    = 'Model-1'
BASE_DIR      = Path("/kaggle/input/datasetinat/01-CleanModel/Dataset")
SIZE          = 32
IMAGE_DIR     = BASE_DIR / f"{SIZE}x{SIZE}"
TRAIN_CSV     = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_train.csv"
VAL_CSV       = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_val.csv"
BATCH_SIZE    = 512
NUM_EPOCHS    = 50
LEARNING_RATE = 0.001
DEVICE        = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

BaseOutput = f'./Models/{SIZE}x{SIZE}/'

os.makedirs(BaseOutput, exist_ok=True)

SAVE_BEST_ACC      = Path(BaseOutput+f"best_avg_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_MINCLASS = Path(BaseOutput+f"best_min_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_F1       = Path(BaseOutput+f"best_avg_f1_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_LAST          = Path(BaseOutput+f"last_checkpoint_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_FINAL         = Path(BaseOutput+f"final_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")


SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Device: {DEVICE}")

train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
      SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1)
# Out:
# Device: cuda:0
# Found 7 classes: ['bird', 'cat', 'fish', 'frog', 'monkey', 'moth', 'spider']
# Sizes → Train: 2799, Val: 350
# No checkpoint found; initializing VGG-16 with ImageNet pretrained weights
#
# Epoch 1/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 1.8865, Avg Acc: 0.2562, Min Acc: 0.0900, Avg F1: 0.2397
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 16.7639, Avg Acc: 0.2457, Min Acc: 0.0000, Avg F1: 0.1639
#   -> Saved Best Avg-Acc: 0.2457
#   -> Saved Best Min-Acc: 0.0000 (was 0.0000; ref-acc updated 0.0000 -> 0.2457)
#   -> Saved Best F1: 0.1639
#
# Epoch 2/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 1.3929, Avg Acc: 0.4898, Min Acc: 0.2650, Avg F1: 0.4946
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Val → Loss: 10.7579, Avg Acc: 0.3229, Min Acc: 0.0000, Avg F1: 0.2506
#   -> Saved Best Avg-Acc: 0.3229
#   -> Saved Best Min-Acc: 0.0000 (was 0.0000; ref-acc updated 0.2457 -> 0.3229)
#   -> Saved Best F1: 0.2506
#
# Epoch 3/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.1862, Avg Acc: 0.5909, Min Acc: 0.3600, Avg F1: 0.5926
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 3.5537, Avg Acc: 0.4714, Min Acc: 0.0000, Avg F1: 0.4154
#   -> Saved Best Avg-Acc: 0.4714
#   -> Saved Best Min-Acc: 0.0000 (was 0.0000; ref-acc updated 0.3229 -> 0.4714)
#   -> Saved Best F1: 0.4154
#
# Epoch 4/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.9821, Avg Acc: 0.6681, Min Acc: 0.4775, Avg F1: 0.6671
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 2.7374, Avg Acc: 0.5771, Min Acc: 0.1600, Avg F1: 0.5482
#   -> Saved Best Avg-Acc: 0.5771
#   -> Saved Best Min-Acc: 0.1600 (was 0.0000; ref-acc updated 0.4714 -> 0.5771)
#   -> Saved Best F1: 0.5482
#
# Epoch 5/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.8594, Avg Acc: 0.7092, Min Acc: 0.5550, Avg F1: 0.7086
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 1.7831, Avg Acc: 0.6571, Min Acc: 0.3400, Avg F1: 0.6501
#   -> Saved Best Avg-Acc: 0.6571
#   -> Saved Best Min-Acc: 0.3400 (was 0.1600; ref-acc updated 0.5771 -> 0.6571)
#   -> Saved Best F1: 0.6501
#
# Epoch 6/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# Train → Loss: 0.8199, Avg Acc: 0.7242, Min Acc: 0.5800, Avg F1: 0.7250
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# Val → Loss: 1.5104, Avg Acc: 0.6657, Min Acc: 0.2800, Avg F1: 0.6548
#   -> Saved Best Avg-Acc: 0.6657
#   -> Saved Best F1: 0.6548
#
# Epoch 7/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.7624, Avg Acc: 0.7460, Min Acc: 0.6175, Avg F1: 0.7474
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.3275, Avg Acc: 0.7029, Min Acc: 0.4200, Avg F1: 0.6981
#   -> Saved Best Avg-Acc: 0.7029
#   -> Saved Best Min-Acc: 0.4200 (was 0.3400; ref-acc updated 0.6571 -> 0.7029)
#   -> Saved Best F1: 0.6981
#
# Epoch 8/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# Train → Loss: 0.6766, Avg Acc: 0.7746, Min Acc: 0.5650, Avg F1: 0.7743
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# Val → Loss: 1.2191, Avg Acc: 0.6600, Min Acc: 0.5000, Avg F1: 0.6607
#   -> Saved Best Min-Acc: 0.5000 (was 0.4200; ref-acc updated 0.7029 -> 0.6600)
#
# Epoch 9/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.6681, Avg Acc: 0.7781, Min Acc: 0.6425, Avg F1: 0.7779
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Val → Loss: 1.2183, Avg Acc: 0.6857, Min Acc: 0.4800, Avg F1: 0.6851
#
# Epoch 10/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.6092, Avg Acc: 0.7942, Min Acc: 0.6950, Avg F1: 0.7937
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.6667, Avg Acc: 0.6571, Min Acc: 0.4600, Avg F1: 0.6608
#
# Epoch 11/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.5238, Avg Acc: 0.8228, Min Acc: 0.7350, Avg F1: 0.8239
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Val → Loss: 1.0554, Avg Acc: 0.6971, Min Acc: 0.5600, Avg F1: 0.7021
#   -> Saved Best Min-Acc: 0.5600 (was 0.5000; ref-acc updated 0.6600 -> 0.6971)
#   -> Saved Best F1: 0.7021
#
# Epoch 12/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.4745, Avg Acc: 0.8432, Min Acc: 0.7925, Avg F1: 0.8438
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
# Val → Loss: 1.0538, Avg Acc: 0.7086, Min Acc: 0.3200, Avg F1: 0.7027
#   -> Saved Best Avg-Acc: 0.7086
#   -> Saved Best F1: 0.7027
#
# Epoch 13/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.4148, Avg Acc: 0.8614, Min Acc: 0.7400, Avg F1: 0.8611
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Val → Loss: 1.2923, Avg Acc: 0.6771, Min Acc: 0.4200, Avg F1: 0.6822
#
# Epoch 14/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.3769, Avg Acc: 0.8757, Min Acc: 0.7875, Avg F1: 0.8754
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.1401, Avg Acc: 0.7229, Min Acc: 0.4200, Avg F1: 0.7230
#   -> Saved Best Avg-Acc: 0.7229
#   -> Saved Best F1: 0.7230
#
# Epoch 15/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.3609, Avg Acc: 0.8778, Min Acc: 0.8200, Avg F1: 0.8780
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 1.2491, Avg Acc: 0.6829, Min Acc: 0.4600, Avg F1: 0.6815
#
# Epoch 16/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.3341, Avg Acc: 0.8985, Min Acc: 0.8375, Avg F1: 0.8985
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 1.4207, Avg Acc: 0.7029, Min Acc: 0.5000, Avg F1: 0.7049
#
# Epoch 17/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2719, Avg Acc: 0.9135, Min Acc: 0.8250, Avg F1: 0.9134
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.08it/s]
# Val → Loss: 1.0608, Avg Acc: 0.7200, Min Acc: 0.4200, Avg F1: 0.7167
#
# Epoch 18/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2490, Avg Acc: 0.9278, Min Acc: 0.8900, Avg F1: 0.9282
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Val → Loss: 1.0868, Avg Acc: 0.7314, Min Acc: 0.4800, Avg F1: 0.7324
#   -> Saved Best Avg-Acc: 0.7314
#   -> Saved Best F1: 0.7324
#
# Epoch 19/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2104, Avg Acc: 0.9335, Min Acc: 0.8550, Avg F1: 0.9333
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.1336, Avg Acc: 0.7086, Min Acc: 0.4400, Avg F1: 0.7113
#
# Epoch 20/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.1986, Avg Acc: 0.9375, Min Acc: 0.9000, Avg F1: 0.9375
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
# Val → Loss: 1.0594, Avg Acc: 0.7429, Min Acc: 0.5200, Avg F1: 0.7443
#   -> Saved Best Avg-Acc: 0.7429
#   -> Saved Best F1: 0.7443
# Checkpoint at epoch 20 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-1.pth
#
# Epoch 21/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.1574, Avg Acc: 0.9482, Min Acc: 0.9100, Avg F1: 0.9483
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.2799, Avg Acc: 0.7000, Min Acc: 0.5000, Avg F1: 0.7073
#
# Epoch 22/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.1568, Avg Acc: 0.9493, Min Acc: 0.8650, Avg F1: 0.9490
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 1.0344, Avg Acc: 0.7343, Min Acc: 0.6200, Avg F1: 0.7369
#   -> Saved Best Min-Acc: 0.6200 (was 0.5600; ref-acc updated 0.6971 -> 0.7343)
#
# Epoch 23/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.1589, Avg Acc: 0.9507, Min Acc: 0.9275, Avg F1: 0.9508
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
# Val → Loss: 0.9786, Avg Acc: 0.7600, Min Acc: 0.6600, Avg F1: 0.7627
#   -> Saved Best Avg-Acc: 0.7600
#   -> Saved Best Min-Acc: 0.6600 (was 0.6200; ref-acc updated 0.7343 -> 0.7600)
#   -> Saved Best F1: 0.7627
#
# Epoch 24/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.1281, Avg Acc: 0.9593, Min Acc: 0.9450, Avg F1: 0.9594
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# Val → Loss: 1.1468, Avg Acc: 0.7286, Min Acc: 0.6000, Avg F1: 0.7335
#
# Epoch 25/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.1098, Avg Acc: 0.9675, Min Acc: 0.9425, Avg F1: 0.9675
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 1.1112, Avg Acc: 0.7257, Min Acc: 0.6000, Avg F1: 0.7291
#
# Epoch 26/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.1026, Avg Acc: 0.9668, Min Acc: 0.9475, Avg F1: 0.9667
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.08it/s]
# Val → Loss: 1.1163, Avg Acc: 0.7314, Min Acc: 0.4800, Avg F1: 0.7302
#
# Epoch 27/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.1038, Avg Acc: 0.9671, Min Acc: 0.9450, Avg F1: 0.9671
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 1.0443, Avg Acc: 0.7400, Min Acc: 0.4400, Avg F1: 0.7368
#
# Epoch 28/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.0756, Avg Acc: 0.9746, Min Acc: 0.9649, Avg F1: 0.9747
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Val → Loss: 1.0515, Avg Acc: 0.7514, Min Acc: 0.6600, Avg F1: 0.7545
#
# Epoch 29/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.0779, Avg Acc: 0.9753, Min Acc: 0.9575, Avg F1: 0.9753
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 1.0270, Avg Acc: 0.7600, Min Acc: 0.6800, Avg F1: 0.7633
#   -> Saved Best Min-Acc: 0.6800 (was 0.6600; ref-acc updated 0.7600 -> 0.7600)
#   -> Saved Best F1: 0.7633
#
# Epoch 30/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.0648, Avg Acc: 0.9814, Min Acc: 0.9700, Avg F1: 0.9814
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Val → Loss: 1.0722, Avg Acc: 0.7514, Min Acc: 0.6600, Avg F1: 0.7563
#
# Epoch 31/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.0726, Avg Acc: 0.9796, Min Acc: 0.9625, Avg F1: 0.9797
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
# Val → Loss: 1.1061, Avg Acc: 0.7600, Min Acc: 0.6800, Avg F1: 0.7652
#   -> Saved Best F1: 0.7652
#
# Epoch 32/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.0525, Avg Acc: 0.9825, Min Acc: 0.9725, Avg F1: 0.9825
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.0830, Avg Acc: 0.7686, Min Acc: 0.6400, Avg F1: 0.7727
#   -> Saved Best Avg-Acc: 0.7686
#   -> Saved Best F1: 0.7727
#
# Epoch 33/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.0542, Avg Acc: 0.9829, Min Acc: 0.9700, Avg F1: 0.9828
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Val → Loss: 1.0696, Avg Acc: 0.7714, Min Acc: 0.6200, Avg F1: 0.7744
#   -> Saved Best Avg-Acc: 0.7714
#   -> Saved Best F1: 0.7744
#
# Epoch 34/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.0523, Avg Acc: 0.9854, Min Acc: 0.9650, Avg F1: 0.9853
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# Val → Loss: 1.0633, Avg Acc: 0.7829, Min Acc: 0.6800, Avg F1: 0.7876
#   -> Saved Best Avg-Acc: 0.7829
#   -> Saved Best Min-Acc: 0.6800 (was 0.6800; ref-acc updated 0.7600 -> 0.7829)
#   -> Saved Best F1: 0.7876
#
# Epoch 35/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.0542, Avg Acc: 0.9821, Min Acc: 0.9600, Avg F1: 0.9821
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Val → Loss: 1.0766, Avg Acc: 0.7829, Min Acc: 0.7400, Avg F1: 0.7868
#   -> Saved Best Min-Acc: 0.7400 (was 0.6800; ref-acc updated 0.7829 -> 0.7829)
#
# Epoch 36/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.0439, Avg Acc: 0.9868, Min Acc: 0.9725, Avg F1: 0.9868
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 1.0948, Avg Acc: 0.7771, Min Acc: 0.7200, Avg F1: 0.7818
#
# Epoch 37/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.0456, Avg Acc: 0.9871, Min Acc: 0.9749, Avg F1: 0.9871
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Val → Loss: 1.0818, Avg Acc: 0.7714, Min Acc: 0.7200, Avg F1: 0.7754
#
# Epoch 38/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.0364, Avg Acc: 0.9886, Min Acc: 0.9675, Avg F1: 0.9886
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 1.1030, Avg Acc: 0.7714, Min Acc: 0.7000, Avg F1: 0.7756
#
# Epoch 39/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.0481, Avg Acc: 0.9843, Min Acc: 0.9700, Avg F1: 0.9843
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.05it/s]
# Val → Loss: 1.1034, Avg Acc: 0.7743, Min Acc: 0.6800, Avg F1: 0.7787
#
# Epoch 40/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.0463, Avg Acc: 0.9871, Min Acc: 0.9749, Avg F1: 0.9871
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 1.0948, Avg Acc: 0.7771, Min Acc: 0.7000, Avg F1: 0.7815
# Checkpoint at epoch 40 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-1.pth
#
# Epoch 41/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Train → Loss: 0.0437, Avg Acc: 0.9868, Min Acc: 0.9675, Avg F1: 0.9868
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Val → Loss: 1.0659, Avg Acc: 0.7714, Min Acc: 0.6800, Avg F1: 0.7750
#
# Epoch 42/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.0375, Avg Acc: 0.9875, Min Acc: 0.9750, Avg F1: 0.9875
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.0464, Avg Acc: 0.7771, Min Acc: 0.6800, Avg F1: 0.7809
#
# Epoch 43/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.0475, Avg Acc: 0.9882, Min Acc: 0.9774, Avg F1: 0.9882
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0613, Avg Acc: 0.7714, Min Acc: 0.6600, Avg F1: 0.7751
#
# Epoch 44/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.0364, Avg Acc: 0.9889, Min Acc: 0.9825, Avg F1: 0.9889
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.0721, Avg Acc: 0.7686, Min Acc: 0.6600, Avg F1: 0.7727
#
# Epoch 45/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.0360, Avg Acc: 0.9886, Min Acc: 0.9800, Avg F1: 0.9886
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 1.0600, Avg Acc: 0.7800, Min Acc: 0.6800, Avg F1: 0.7837
#
# Epoch 46/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.0434, Avg Acc: 0.9886, Min Acc: 0.9799, Avg F1: 0.9886
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0497, Avg Acc: 0.7857, Min Acc: 0.6800, Avg F1: 0.7892
#   -> Saved Best Avg-Acc: 0.7857
#   -> Saved Best F1: 0.7892
#
# Epoch 47/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.0379, Avg Acc: 0.9879, Min Acc: 0.9825, Avg F1: 0.9879
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.0568, Avg Acc: 0.7771, Min Acc: 0.7000, Avg F1: 0.7814
#
# Epoch 48/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.0356, Avg Acc: 0.9896, Min Acc: 0.9800, Avg F1: 0.9896
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# Val → Loss: 1.0592, Avg Acc: 0.7829, Min Acc: 0.7000, Avg F1: 0.7868
#
# Epoch 49/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.0402, Avg Acc: 0.9854, Min Acc: 0.9750, Avg F1: 0.9853
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Val → Loss: 1.0591, Avg Acc: 0.7857, Min Acc: 0.7200, Avg F1: 0.7896
#   -> Saved Best F1: 0.7896
#
# Epoch 50/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.0338, Avg Acc: 0.9889, Min Acc: 0.9800, Avg F1: 0.9889
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Val → Loss: 1.0610, Avg Acc: 0.7771, Min Acc: 0.6600, Avg F1: 0.7803
# Final checkpoint at epoch 50 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-1.pth
#
# Training complete in 6m57s
# Final Bests → Avg Acc: 0.7857, Min Acc: 0.7400, Best-Min Ref Acc: 0.7829, Avg F1: 0.7896

# %%
MODEL_NAME    = 'Model-2'
BASE_DIR      = Path("/kaggle/input/datasetinat/01-CleanModel/Dataset")
SIZE          = 32
IMAGE_DIR     = BASE_DIR / f"{SIZE}x{SIZE}"
TRAIN_CSV     = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_train.csv"
VAL_CSV       = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_val.csv"
BATCH_SIZE    = 512
NUM_EPOCHS    = 50
LEARNING_RATE = 0.001
DEVICE        = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

BaseOutput = f'./Models/{SIZE}x{SIZE}/'

os.makedirs(BaseOutput, exist_ok=True)

SAVE_BEST_ACC      = Path(BaseOutput+f"best_avg_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_MINCLASS = Path(BaseOutput+f"best_min_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_F1       = Path(BaseOutput+f"best_avg_f1_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_LAST          = Path(BaseOutput+f"last_checkpoint_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_FINAL         = Path(BaseOutput+f"final_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")


SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Device: {DEVICE}")

train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
          SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1, LR_ADJUSTMENT = True, CLASSIFIER_ONLY = False)
# Out:
# Device: cuda:0
# Found 7 classes: ['bird', 'cat', 'fish', 'frog', 'monkey', 'moth', 'spider']
# Sizes → Train: 2799, Val: 350
# No checkpoint found; initializing VGG-16 with ImageNet pretrained weights
#
# Epoch 1/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.8308, Avg Acc: 0.2808, Min Acc: 0.1654, Avg F1: 0.2792
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.3264, Avg Acc: 0.5057, Min Acc: 0.2600, Avg F1: 0.5132
#   -> Saved Best Avg-Acc: 0.5057
#   -> Saved Best Min-Acc: 0.2600 (was 0.0000; ref-acc updated 0.0000 -> 0.5057)
#   -> Saved Best F1: 0.5132
#
# Epoch 2/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 1.4705, Avg Acc: 0.4680, Min Acc: 0.2375, Avg F1: 0.4677
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.5073, Avg Acc: 0.5914, Min Acc: 0.3400, Avg F1: 0.5870
#   -> Saved Best Avg-Acc: 0.5914
#   -> Saved Best Min-Acc: 0.3400 (was 0.2600; ref-acc updated 0.5057 -> 0.5914)
#   -> Saved Best F1: 0.5870
#
# Epoch 3/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 1.2252, Avg Acc: 0.5413, Min Acc: 0.3100, Avg F1: 0.5371
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# Val → Loss: 1.1383, Avg Acc: 0.6257, Min Acc: 0.4400, Avg F1: 0.6237
#   -> Saved Best Avg-Acc: 0.6257
#   -> Saved Best Min-Acc: 0.4400 (was 0.3400; ref-acc updated 0.5914 -> 0.6257)
#   -> Saved Best F1: 0.6237
#
# Epoch 4/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 1.1322, Avg Acc: 0.5991, Min Acc: 0.4550, Avg F1: 0.6007
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 1.1879, Avg Acc: 0.6343, Min Acc: 0.4600, Avg F1: 0.6302
#   -> Saved Best Avg-Acc: 0.6343
#   -> Saved Best Min-Acc: 0.4600 (was 0.4400; ref-acc updated 0.6257 -> 0.6343)
#   -> Saved Best F1: 0.6302
#
# Epoch 5/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 1.0150, Avg Acc: 0.6370, Min Acc: 0.4775, Avg F1: 0.6344
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.07it/s]
# Val → Loss: 1.0609, Avg Acc: 0.6629, Min Acc: 0.4400, Avg F1: 0.6656
#   -> Saved Best Avg-Acc: 0.6629
#   -> Saved Best F1: 0.6656
#
# Epoch 6/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.9395, Avg Acc: 0.6649, Min Acc: 0.4975, Avg F1: 0.6670
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# Val → Loss: 1.0436, Avg Acc: 0.6943, Min Acc: 0.5600, Avg F1: 0.6941
#   -> Saved Best Avg-Acc: 0.6943
#   -> Saved Best Min-Acc: 0.5600 (was 0.4600; ref-acc updated 0.6343 -> 0.6943)
#   -> Saved Best F1: 0.6941
#
# Epoch 7/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.8460, Avg Acc: 0.7045, Min Acc: 0.5825, Avg F1: 0.7043
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0740, Avg Acc: 0.6629, Min Acc: 0.4600, Avg F1: 0.6642
#
# Epoch 8/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.7733, Avg Acc: 0.7242, Min Acc: 0.5950, Avg F1: 0.7249
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.0798, Avg Acc: 0.7000, Min Acc: 0.5600, Avg F1: 0.6982
#   -> Saved Best Avg-Acc: 0.7000
#   -> Saved Best Min-Acc: 0.5600 (was 0.5600; ref-acc updated 0.6943 -> 0.7000)
#   -> Saved Best F1: 0.6982
#
# Epoch 9/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.7112, Avg Acc: 0.7488, Min Acc: 0.6500, Avg F1: 0.7483
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# Val → Loss: 1.0981, Avg Acc: 0.6943, Min Acc: 0.5800, Avg F1: 0.6949
#   -> Saved Best Min-Acc: 0.5800 (was 0.5600; ref-acc updated 0.7000 -> 0.6943)
#
# Epoch 10/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.6518, Avg Acc: 0.7724, Min Acc: 0.6575, Avg F1: 0.7722
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0596, Avg Acc: 0.7000, Min Acc: 0.5000, Avg F1: 0.7003
#   -> Saved Best F1: 0.7003
#
# Epoch 11/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Train → Loss: 0.5902, Avg Acc: 0.7864, Min Acc: 0.6875, Avg F1: 0.7869
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.0657, Avg Acc: 0.7171, Min Acc: 0.6000, Avg F1: 0.7183
#   -> Saved Best Avg-Acc: 0.7171
#   -> Saved Best Min-Acc: 0.6000 (was 0.5800; ref-acc updated 0.6943 -> 0.7171)
#   -> Saved Best F1: 0.7183
#
# Epoch 12/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.5523, Avg Acc: 0.8117, Min Acc: 0.7150, Avg F1: 0.8112
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0467, Avg Acc: 0.7143, Min Acc: 0.5200, Avg F1: 0.7147
#
# Epoch 13/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.16s/it]
# Train → Loss: 0.5039, Avg Acc: 0.8210, Min Acc: 0.7300, Avg F1: 0.8212
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# Val → Loss: 1.0420, Avg Acc: 0.7114, Min Acc: 0.6200, Avg F1: 0.7132
#   -> Saved Best Min-Acc: 0.6200 (was 0.6000; ref-acc updated 0.7171 -> 0.7114)
#
# Epoch 14/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# Train → Loss: 0.4864, Avg Acc: 0.8299, Min Acc: 0.7200, Avg F1: 0.8304
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.0340, Avg Acc: 0.7229, Min Acc: 0.5800, Avg F1: 0.7231
#   -> Saved Best Avg-Acc: 0.7229
#   -> Saved Best F1: 0.7231
#
# Epoch 15/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.4631, Avg Acc: 0.8328, Min Acc: 0.7200, Avg F1: 0.8324
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.05it/s]
# Val → Loss: 1.0185, Avg Acc: 0.7400, Min Acc: 0.6000, Avg F1: 0.7398
#   -> Saved Best Avg-Acc: 0.7400
#   -> Saved Best F1: 0.7398
#
# Epoch 16/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.4400, Avg Acc: 0.8457, Min Acc: 0.7475, Avg F1: 0.8454
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 1.0386, Avg Acc: 0.7171, Min Acc: 0.6000, Avg F1: 0.7179
#
# Epoch 17/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.4252, Avg Acc: 0.8489, Min Acc: 0.7475, Avg F1: 0.8489
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 1.0694, Avg Acc: 0.7086, Min Acc: 0.5800, Avg F1: 0.7112
#
# Epoch 18/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.3988, Avg Acc: 0.8653, Min Acc: 0.7925, Avg F1: 0.8657
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Val → Loss: 1.0813, Avg Acc: 0.7171, Min Acc: 0.5000, Avg F1: 0.7133
#
# Epoch 19/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.3787, Avg Acc: 0.8714, Min Acc: 0.7925, Avg F1: 0.8708
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.0892, Avg Acc: 0.7200, Min Acc: 0.5800, Avg F1: 0.7196
#
# Epoch 20/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.3696, Avg Acc: 0.8707, Min Acc: 0.7725, Avg F1: 0.8703
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.06it/s]
# Val → Loss: 1.1254, Avg Acc: 0.7057, Min Acc: 0.5600, Avg F1: 0.7073
# Checkpoint at epoch 20 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-2.pth
#
# Epoch 21/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.3105, Avg Acc: 0.8914, Min Acc: 0.8400, Avg F1: 0.8917
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Val → Loss: 1.1833, Avg Acc: 0.7086, Min Acc: 0.5400, Avg F1: 0.7080
#
# Epoch 22/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Train → Loss: 0.3381, Avg Acc: 0.8792, Min Acc: 0.8050, Avg F1: 0.8793
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# Val → Loss: 1.2075, Avg Acc: 0.7000, Min Acc: 0.5200, Avg F1: 0.6981
#
# Epoch 23/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.3337, Avg Acc: 0.8796, Min Acc: 0.7875, Avg F1: 0.8793
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.1575, Avg Acc: 0.7171, Min Acc: 0.5800, Avg F1: 0.7169
#
# Epoch 24/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.3126, Avg Acc: 0.8871, Min Acc: 0.8200, Avg F1: 0.8871
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Val → Loss: 1.1481, Avg Acc: 0.7143, Min Acc: 0.5600, Avg F1: 0.7136
#
# Epoch 25/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.3082, Avg Acc: 0.8946, Min Acc: 0.8375, Avg F1: 0.8948
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Val → Loss: 1.1675, Avg Acc: 0.7171, Min Acc: 0.5800, Avg F1: 0.7171
#
# Epoch 26/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.3102, Avg Acc: 0.8942, Min Acc: 0.8075, Avg F1: 0.8943
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]
# Val → Loss: 1.1884, Avg Acc: 0.7086, Min Acc: 0.5600, Avg F1: 0.7076
#
# Epoch 27/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.2881, Avg Acc: 0.8917, Min Acc: 0.8125, Avg F1: 0.8918
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.2008, Avg Acc: 0.7086, Min Acc: 0.5400, Avg F1: 0.7073
#
# Epoch 28/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.2949, Avg Acc: 0.8982, Min Acc: 0.8325, Avg F1: 0.8984
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.1988, Avg Acc: 0.7086, Min Acc: 0.5600, Avg F1: 0.7079
#
# Epoch 29/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2856, Avg Acc: 0.9003, Min Acc: 0.8400, Avg F1: 0.9002
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.1993, Avg Acc: 0.7086, Min Acc: 0.5800, Avg F1: 0.7084
#
# Epoch 30/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2696, Avg Acc: 0.9078, Min Acc: 0.8550, Avg F1: 0.9077
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 1.1918, Avg Acc: 0.7143, Min Acc: 0.5800, Avg F1: 0.7138
#
# Epoch 31/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2675, Avg Acc: 0.9089, Min Acc: 0.8525, Avg F1: 0.9088
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 1.1952, Avg Acc: 0.7114, Min Acc: 0.5800, Avg F1: 0.7112
#
# Epoch 32/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.2775, Avg Acc: 0.9071, Min Acc: 0.8575, Avg F1: 0.9072
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Val → Loss: 1.2110, Avg Acc: 0.7029, Min Acc: 0.5400, Avg F1: 0.7025
#
# Epoch 33/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.2629, Avg Acc: 0.9171, Min Acc: 0.8700, Avg F1: 0.9172
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# Val → Loss: 1.2204, Avg Acc: 0.7029, Min Acc: 0.5600, Avg F1: 0.7026
#
# Epoch 34/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2562, Avg Acc: 0.9107, Min Acc: 0.8725, Avg F1: 0.9108
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]
# Val → Loss: 1.2122, Avg Acc: 0.7057, Min Acc: 0.5600, Avg F1: 0.7054
#
# Epoch 35/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2745, Avg Acc: 0.9064, Min Acc: 0.8400, Avg F1: 0.9063
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 1.2255, Avg Acc: 0.7057, Min Acc: 0.5800, Avg F1: 0.7059
#
# Epoch 36/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2496, Avg Acc: 0.9196, Min Acc: 0.8625, Avg F1: 0.9194
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.2127, Avg Acc: 0.7114, Min Acc: 0.5800, Avg F1: 0.7112
#
# Epoch 37/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.2669, Avg Acc: 0.9100, Min Acc: 0.8571, Avg F1: 0.9098
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.2345, Avg Acc: 0.7057, Min Acc: 0.5600, Avg F1: 0.7054
#
# Epoch 38/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.2717, Avg Acc: 0.9043, Min Acc: 0.8500, Avg F1: 0.9042
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Val → Loss: 1.2484, Avg Acc: 0.7029, Min Acc: 0.5600, Avg F1: 0.7025
#
# Epoch 39/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# Train → Loss: 0.2579, Avg Acc: 0.9078, Min Acc: 0.8475, Avg F1: 0.9079
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 1.2404, Avg Acc: 0.7000, Min Acc: 0.5400, Avg F1: 0.6994
#
# Epoch 40/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2540, Avg Acc: 0.9178, Min Acc: 0.8575, Avg F1: 0.9177
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.2381, Avg Acc: 0.7000, Min Acc: 0.5400, Avg F1: 0.6993
# Checkpoint at epoch 40 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-2.pth
#
# Epoch 41/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2685, Avg Acc: 0.9082, Min Acc: 0.8650, Avg F1: 0.9082
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 1.2294, Avg Acc: 0.6971, Min Acc: 0.5200, Avg F1: 0.6967
#
# Epoch 42/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2530, Avg Acc: 0.9157, Min Acc: 0.8700, Avg F1: 0.9158
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 1.2144, Avg Acc: 0.7000, Min Acc: 0.5200, Avg F1: 0.6990
#
# Epoch 43/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.2335, Avg Acc: 0.9178, Min Acc: 0.8550, Avg F1: 0.9178
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.2375, Avg Acc: 0.7000, Min Acc: 0.5200, Avg F1: 0.6995
#
# Epoch 44/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.2434, Avg Acc: 0.9168, Min Acc: 0.8725, Avg F1: 0.9167
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.2323, Avg Acc: 0.7000, Min Acc: 0.5200, Avg F1: 0.6996
#
# Epoch 45/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.2486, Avg Acc: 0.9110, Min Acc: 0.8650, Avg F1: 0.9112
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.33it/s]
# Val → Loss: 1.2296, Avg Acc: 0.7029, Min Acc: 0.5200, Avg F1: 0.7024
#
# Epoch 46/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.2438, Avg Acc: 0.9164, Min Acc: 0.8700, Avg F1: 0.9166
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Val → Loss: 1.2146, Avg Acc: 0.7029, Min Acc: 0.5200, Avg F1: 0.7024
#
# Epoch 47/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2494, Avg Acc: 0.9150, Min Acc: 0.8525, Avg F1: 0.9148
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 1.2208, Avg Acc: 0.7029, Min Acc: 0.5200, Avg F1: 0.7020
#
# Epoch 48/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.2280, Avg Acc: 0.9207, Min Acc: 0.8675, Avg F1: 0.9207
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
# Val → Loss: 1.2217, Avg Acc: 0.7057, Min Acc: 0.5400, Avg F1: 0.7050
#
# Epoch 49/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.01s/it]
# Train → Loss: 0.2586, Avg Acc: 0.9164, Min Acc: 0.8700, Avg F1: 0.9164
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 1.2148, Avg Acc: 0.7029, Min Acc: 0.5200, Avg F1: 0.7024
#
# Epoch 50/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.2646, Avg Acc: 0.9096, Min Acc: 0.8725, Avg F1: 0.9097
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 1.2266, Avg Acc: 0.7000, Min Acc: 0.5200, Avg F1: 0.6992
# Final checkpoint at epoch 50 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-2.pth
#
# Training complete in 6m29s
# Final Bests → Avg Acc: 0.7400, Min Acc: 0.6200, Best-Min Ref Acc: 0.7114, Avg F1: 0.7398

# %%
MODEL_NAME    = 'Model-3'
BASE_DIR      = Path("/kaggle/input/datasetinat/01-CleanModel/Dataset")
SIZE          = 32
IMAGE_DIR     = BASE_DIR / f"{SIZE}x{SIZE}"
TRAIN_CSV     = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_train.csv"
VAL_CSV       = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_val.csv"
BATCH_SIZE    = 512
NUM_EPOCHS    = 50
LEARNING_RATE = 0.0001
DEVICE        = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

BaseOutput = f'./Models/{SIZE}x{SIZE}/'

os.makedirs(BaseOutput, exist_ok=True)

SAVE_BEST_ACC      = Path(BaseOutput+f"best_avg_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_MINCLASS = Path(BaseOutput+f"best_min_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_F1       = Path(BaseOutput+f"best_avg_f1_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_LAST          = Path(BaseOutput+f"last_checkpoint_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_FINAL         = Path(BaseOutput+f"final_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")


SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Device: {DEVICE}")

train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
          SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1, LR_ADJUSTMENT = True, CLASSIFIER_ONLY = False)
# Out:
# Device: cuda:0
# Found 7 classes: ['bird', 'cat', 'fish', 'frog', 'monkey', 'moth', 'spider']
# Sizes → Train: 2799, Val: 350
# No checkpoint found; initializing VGG-16 with ImageNet pretrained weights
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# 100%|██████████| 528M/528M [00:02<00:00, 218MB/s]
# Epoch 1/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:19<00:00,  3.33s/it]
# Train → Loss: 1.8916, Avg Acc: 0.2351, Min Acc: 0.0875, Avg F1: 0.2282
# Val: 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
# Val → Loss: 1.4659, Avg Acc: 0.4886, Min Acc: 0.2800, Avg F1: 0.4884
#   -> Saved Best Avg-Acc: 0.4886
#   -> Saved Best Min-Acc: 0.2800 (was 0.0000; ref-acc updated 0.0000 -> 0.4886)
#   -> Saved Best F1: 0.4884
#
# Epoch 2/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.16s/it]
# Train → Loss: 1.7052, Avg Acc: 0.3594, Min Acc: 0.2050, Avg F1: 0.3572
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.04it/s]
# Val → Loss: 1.3075, Avg Acc: 0.5486, Min Acc: 0.3600, Avg F1: 0.5446
#   -> Saved Best Avg-Acc: 0.5486
#   -> Saved Best Min-Acc: 0.3600 (was 0.2800; ref-acc updated 0.4886 -> 0.5486)
#   -> Saved Best F1: 0.5446
#
# Epoch 3/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
# Train → Loss: 1.5597, Avg Acc: 0.4159, Min Acc: 0.2050, Avg F1: 0.4069
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# Val → Loss: 1.2788, Avg Acc: 0.5400, Min Acc: 0.3200, Avg F1: 0.5357
#
# Epoch 4/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Train → Loss: 1.4913, Avg Acc: 0.4455, Min Acc: 0.2725, Avg F1: 0.4464
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# Val → Loss: 1.2333, Avg Acc: 0.5200, Min Acc: 0.3800, Avg F1: 0.5169
#   -> Saved Best Min-Acc: 0.3800 (was 0.3600; ref-acc updated 0.5486 -> 0.5200)
#
# Epoch 5/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.16s/it]
# Train → Loss: 1.4133, Avg Acc: 0.4759, Min Acc: 0.3200, Avg F1: 0.4706
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.91it/s]
# Val → Loss: 1.2214, Avg Acc: 0.5457, Min Acc: 0.3800, Avg F1: 0.5397
#   -> Saved Best Min-Acc: 0.3800 (was 0.3800; ref-acc updated 0.5200 -> 0.5457)
#
# Epoch 6/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
# Train → Loss: 1.3877, Avg Acc: 0.4855, Min Acc: 0.3100, Avg F1: 0.4845
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# Val → Loss: 1.1969, Avg Acc: 0.5629, Min Acc: 0.4000, Avg F1: 0.5608
#   -> Saved Best Avg-Acc: 0.5629
#   -> Saved Best Min-Acc: 0.4000 (was 0.3800; ref-acc updated 0.5457 -> 0.5629)
#   -> Saved Best F1: 0.5608
#
# Epoch 7/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.16s/it]
# Train → Loss: 1.3583, Avg Acc: 0.5005, Min Acc: 0.3450, Avg F1: 0.4994
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
# Val → Loss: 1.1709, Avg Acc: 0.5914, Min Acc: 0.4400, Avg F1: 0.5867
#   -> Saved Best Avg-Acc: 0.5914
#   -> Saved Best Min-Acc: 0.4400 (was 0.4000; ref-acc updated 0.5629 -> 0.5914)
#   -> Saved Best F1: 0.5867
#
# Epoch 8/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:07<00:00,  1.17s/it]
# Train → Loss: 1.3105, Avg Acc: 0.5248, Min Acc: 0.3950, Avg F1: 0.5221
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# Val → Loss: 1.1758, Avg Acc: 0.5714, Min Acc: 0.4000, Avg F1: 0.5704
#
# Epoch 9/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Train → Loss: 1.2715, Avg Acc: 0.5402, Min Acc: 0.4125, Avg F1: 0.5399
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]
# Val → Loss: 1.1475, Avg Acc: 0.6029, Min Acc: 0.4000, Avg F1: 0.5973
#   -> Saved Best Avg-Acc: 0.6029
#   -> Saved Best F1: 0.5973
#
# Epoch 10/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Train → Loss: 1.2411, Avg Acc: 0.5488, Min Acc: 0.3800, Avg F1: 0.5469
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.1242, Avg Acc: 0.6143, Min Acc: 0.4600, Avg F1: 0.6101
#   -> Saved Best Avg-Acc: 0.6143
#   -> Saved Best Min-Acc: 0.4600 (was 0.4400; ref-acc updated 0.5914 -> 0.6143)
#   -> Saved Best F1: 0.6101
#
# Epoch 11/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 1.2073, Avg Acc: 0.5581, Min Acc: 0.4275, Avg F1: 0.5573
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Val → Loss: 1.1061, Avg Acc: 0.6229, Min Acc: 0.4800, Avg F1: 0.6197
#   -> Saved Best Avg-Acc: 0.6229
#   -> Saved Best Min-Acc: 0.4800 (was 0.4600; ref-acc updated 0.6143 -> 0.6229)
#   -> Saved Best F1: 0.6197
#
# Epoch 12/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 1.1970, Avg Acc: 0.5641, Min Acc: 0.4400, Avg F1: 0.5645
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.1030, Avg Acc: 0.6171, Min Acc: 0.4400, Avg F1: 0.6139
#
# Epoch 13/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 1.1587, Avg Acc: 0.5706, Min Acc: 0.3950, Avg F1: 0.5699
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Val → Loss: 1.0868, Avg Acc: 0.6171, Min Acc: 0.4600, Avg F1: 0.6160
#
# Epoch 14/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 1.1038, Avg Acc: 0.6009, Min Acc: 0.4825, Avg F1: 0.6014
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 1.0623, Avg Acc: 0.6200, Min Acc: 0.4200, Avg F1: 0.6177
#
# Epoch 15/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.1093, Avg Acc: 0.5956, Min Acc: 0.4400, Avg F1: 0.5929
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Val → Loss: 1.0596, Avg Acc: 0.6457, Min Acc: 0.3800, Avg F1: 0.6384
#   -> Saved Best Avg-Acc: 0.6457
#   -> Saved Best F1: 0.6384
#
# Epoch 16/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.0717, Avg Acc: 0.6113, Min Acc: 0.4125, Avg F1: 0.6083
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.0704, Avg Acc: 0.6514, Min Acc: 0.5400, Avg F1: 0.6491
#   -> Saved Best Avg-Acc: 0.6514
#   -> Saved Best Min-Acc: 0.5400 (was 0.4800; ref-acc updated 0.6229 -> 0.6514)
#   -> Saved Best F1: 0.6491
#
# Epoch 17/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 1.0642, Avg Acc: 0.6120, Min Acc: 0.4875, Avg F1: 0.6126
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 1.0626, Avg Acc: 0.6343, Min Acc: 0.3800, Avg F1: 0.6300
#
# Epoch 18/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.0552, Avg Acc: 0.6102, Min Acc: 0.4650, Avg F1: 0.6089
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Val → Loss: 1.0625, Avg Acc: 0.6486, Min Acc: 0.4600, Avg F1: 0.6434
#
# Epoch 19/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 1.0124, Avg Acc: 0.6342, Min Acc: 0.4850, Avg F1: 0.6324
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0405, Avg Acc: 0.6457, Min Acc: 0.4600, Avg F1: 0.6416
#
# Epoch 20/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.9918, Avg Acc: 0.6352, Min Acc: 0.4725, Avg F1: 0.6338
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 1.0354, Avg Acc: 0.6343, Min Acc: 0.4600, Avg F1: 0.6326
# Checkpoint at epoch 20 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-3.pth
#
# Epoch 21/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.9743, Avg Acc: 0.6427, Min Acc: 0.4800, Avg F1: 0.6425
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.00it/s]
# Val → Loss: 1.0386, Avg Acc: 0.6314, Min Acc: 0.4600, Avg F1: 0.6268
#
# Epoch 22/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.14s/it]
# Train → Loss: 0.9641, Avg Acc: 0.6488, Min Acc: 0.4700, Avg F1: 0.6463
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]
# Val → Loss: 1.0370, Avg Acc: 0.6457, Min Acc: 0.4400, Avg F1: 0.6398
#
# Epoch 23/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.9758, Avg Acc: 0.6413, Min Acc: 0.5150, Avg F1: 0.6398
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
# Val → Loss: 1.0297, Avg Acc: 0.6600, Min Acc: 0.5000, Avg F1: 0.6586
#   -> Saved Best Avg-Acc: 0.6600
#   -> Saved Best F1: 0.6586
#
# Epoch 24/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.9254, Avg Acc: 0.6656, Min Acc: 0.5225, Avg F1: 0.6656
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.0161, Avg Acc: 0.6457, Min Acc: 0.4400, Avg F1: 0.6426
#
# Epoch 25/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.9155, Avg Acc: 0.6635, Min Acc: 0.5300, Avg F1: 0.6628
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.0121, Avg Acc: 0.6543, Min Acc: 0.5000, Avg F1: 0.6522
#
# Epoch 26/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.9250, Avg Acc: 0.6624, Min Acc: 0.5300, Avg F1: 0.6616
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# Val → Loss: 1.0195, Avg Acc: 0.6429, Min Acc: 0.4800, Avg F1: 0.6384
#
# Epoch 27/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Train → Loss: 0.9129, Avg Acc: 0.6699, Min Acc: 0.5025, Avg F1: 0.6679
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
# Val → Loss: 1.0248, Avg Acc: 0.6514, Min Acc: 0.5000, Avg F1: 0.6499
#
# Epoch 28/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Train → Loss: 0.8823, Avg Acc: 0.6770, Min Acc: 0.5725, Avg F1: 0.6776
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# Val → Loss: 1.0184, Avg Acc: 0.6657, Min Acc: 0.4800, Avg F1: 0.6619
#   -> Saved Best Avg-Acc: 0.6657
#   -> Saved Best F1: 0.6619
#
# Epoch 29/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.15s/it]
# Train → Loss: 0.8978, Avg Acc: 0.6681, Min Acc: 0.5300, Avg F1: 0.6663
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]
# Val → Loss: 1.0078, Avg Acc: 0.6629, Min Acc: 0.4800, Avg F1: 0.6600
#
# Epoch 30/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Train → Loss: 0.8565, Avg Acc: 0.6856, Min Acc: 0.5625, Avg F1: 0.6853
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# Val → Loss: 1.0259, Avg Acc: 0.6629, Min Acc: 0.4800, Avg F1: 0.6613
#
# Epoch 31/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Train → Loss: 0.8727, Avg Acc: 0.6902, Min Acc: 0.6075, Avg F1: 0.6918
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]
# Val → Loss: 1.0209, Avg Acc: 0.6686, Min Acc: 0.5200, Avg F1: 0.6670
#   -> Saved Best Avg-Acc: 0.6686
#   -> Saved Best F1: 0.6670
#
# Epoch 32/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
# Train → Loss: 0.8810, Avg Acc: 0.6838, Min Acc: 0.5475, Avg F1: 0.6829
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]
# Val → Loss: 0.9940, Avg Acc: 0.6771, Min Acc: 0.5000, Avg F1: 0.6729
#   -> Saved Best Avg-Acc: 0.6771
#   -> Saved Best F1: 0.6729
#
# Epoch 33/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.11s/it]
# Train → Loss: 0.8504, Avg Acc: 0.6949, Min Acc: 0.5500, Avg F1: 0.6928
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# Val → Loss: 0.9888, Avg Acc: 0.6800, Min Acc: 0.5000, Avg F1: 0.6783
#   -> Saved Best Avg-Acc: 0.6800
#   -> Saved Best F1: 0.6783
#
# Epoch 34/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
# Train → Loss: 0.8348, Avg Acc: 0.6945, Min Acc: 0.5875, Avg F1: 0.6947
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]
# Val → Loss: 0.9903, Avg Acc: 0.6743, Min Acc: 0.5200, Avg F1: 0.6730
#
# Epoch 35/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.12s/it]
# Train → Loss: 0.8275, Avg Acc: 0.7020, Min Acc: 0.6125, Avg F1: 0.7025
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.04it/s]
# Val → Loss: 0.9952, Avg Acc: 0.6714, Min Acc: 0.5400, Avg F1: 0.6700
#   -> Saved Best Min-Acc: 0.5400 (was 0.5400; ref-acc updated 0.6514 -> 0.6714)
#
# Epoch 36/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.10s/it]
# Train → Loss: 0.8234, Avg Acc: 0.7099, Min Acc: 0.5750, Avg F1: 0.7086
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 0.9941, Avg Acc: 0.6771, Min Acc: 0.5000, Avg F1: 0.6729
#
# Epoch 37/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.7980, Avg Acc: 0.7078, Min Acc: 0.5625, Avg F1: 0.7060
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 0.9916, Avg Acc: 0.6657, Min Acc: 0.4800, Avg F1: 0.6627
#
# Epoch 38/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.8092, Avg Acc: 0.7053, Min Acc: 0.5950, Avg F1: 0.7061
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Val → Loss: 0.9967, Avg Acc: 0.6714, Min Acc: 0.5200, Avg F1: 0.6702
#
# Epoch 39/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.7893, Avg Acc: 0.7213, Min Acc: 0.6400, Avg F1: 0.7223
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]
# Val → Loss: 0.9934, Avg Acc: 0.6714, Min Acc: 0.5000, Avg F1: 0.6692
#
# Epoch 40/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.7847, Avg Acc: 0.7160, Min Acc: 0.6050, Avg F1: 0.7155
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# Val → Loss: 0.9927, Avg Acc: 0.6714, Min Acc: 0.5000, Avg F1: 0.6678
# Checkpoint at epoch 40 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-3.pth
#
# Epoch 41/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.7908, Avg Acc: 0.7092, Min Acc: 0.5850, Avg F1: 0.7078
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 0.9965, Avg Acc: 0.6686, Min Acc: 0.5000, Avg F1: 0.6654
#
# Epoch 42/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.7842, Avg Acc: 0.7163, Min Acc: 0.6050, Avg F1: 0.7156
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 0.9890, Avg Acc: 0.6771, Min Acc: 0.5200, Avg F1: 0.6753
#
# Epoch 43/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.7822, Avg Acc: 0.7260, Min Acc: 0.6200, Avg F1: 0.7258
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# Val → Loss: 0.9906, Avg Acc: 0.6714, Min Acc: 0.5200, Avg F1: 0.6694
#
# Epoch 44/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# Train → Loss: 0.7957, Avg Acc: 0.7174, Min Acc: 0.6250, Avg F1: 0.7172
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# Val → Loss: 0.9967, Avg Acc: 0.6686, Min Acc: 0.5200, Avg F1: 0.6669
#
# Epoch 45/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.7920, Avg Acc: 0.7145, Min Acc: 0.6200, Avg F1: 0.7154
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Val → Loss: 0.9963, Avg Acc: 0.6743, Min Acc: 0.5400, Avg F1: 0.6722
#   -> Saved Best Min-Acc: 0.5400 (was 0.5400; ref-acc updated 0.6714 -> 0.6743)
#
# Epoch 46/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.7476, Avg Acc: 0.7335, Min Acc: 0.6250, Avg F1: 0.7339
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# Val → Loss: 0.9978, Avg Acc: 0.6886, Min Acc: 0.5400, Avg F1: 0.6865
#   -> Saved Best Avg-Acc: 0.6886
#   -> Saved Best Min-Acc: 0.5400 (was 0.5400; ref-acc updated 0.6743 -> 0.6886)
#   -> Saved Best F1: 0.6865
#
# Epoch 47/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.09s/it]
# Train → Loss: 0.7752, Avg Acc: 0.7167, Min Acc: 0.5950, Avg F1: 0.7161
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# Val → Loss: 0.9991, Avg Acc: 0.6771, Min Acc: 0.5200, Avg F1: 0.6746
#
# Epoch 48/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.7683, Avg Acc: 0.7231, Min Acc: 0.6200, Avg F1: 0.7225
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 1.0077, Avg Acc: 0.6771, Min Acc: 0.5200, Avg F1: 0.6749
#
# Epoch 49/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.7652, Avg Acc: 0.7274, Min Acc: 0.5875, Avg F1: 0.7262
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.10it/s]
# Val → Loss: 1.0035, Avg Acc: 0.6771, Min Acc: 0.5600, Avg F1: 0.6757
#   -> Saved Best Min-Acc: 0.5600 (was 0.5400; ref-acc updated 0.6886 -> 0.6771)
#
# Epoch 50/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.7786, Avg Acc: 0.7131, Min Acc: 0.5825, Avg F1: 0.7129
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.0079, Avg Acc: 0.6800, Min Acc: 0.5400, Avg F1: 0.6781
# Final checkpoint at epoch 50 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-3.pth
#
# Training complete in 7m21s
# Final Bests → Avg Acc: 0.6886, Min Acc: 0.5600, Best-Min Ref Acc: 0.6771, Avg F1: 0.6865

# %%
MODEL_NAME    = 'Model-4'
BASE_DIR      = Path("/kaggle/input/datasetinat/01-CleanModel/Dataset")
SIZE          = 32
IMAGE_DIR     = BASE_DIR / f"{SIZE}x{SIZE}"
TRAIN_CSV     = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_train.csv"
VAL_CSV       = "/kaggle/input/datasetinat/01-CleanModel/Dataset/clean_model_val.csv"
BATCH_SIZE    = 512
NUM_EPOCHS    = 50
LEARNING_RATE = 0.0001
DEVICE        = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

BaseOutput = f'./Models/{SIZE}x{SIZE}/'

os.makedirs(BaseOutput, exist_ok=True)

SAVE_BEST_ACC      = Path(BaseOutput+f"best_avg_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_MINCLASS = Path(BaseOutput+f"best_min_acc_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_BEST_F1       = Path(BaseOutput+f"best_avg_f1_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_LAST          = Path(BaseOutput+f"last_checkpoint_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")
SAVE_FINAL         = Path(BaseOutput+f"final_vgg16_{SIZE}x{SIZE}_{MODEL_NAME}.pth")


SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Device: {DEVICE}")

train(TRAIN_CSV, VAL_CSV, IMAGE_DIR, BATCH_SIZE, LEARNING_RATE, NUM_EPOCHS, DEVICE,
          SEED, SAVE_LAST, SAVE_BEST_ACC, SAVE_BEST_MINCLASS, SAVE_BEST_F1, LR_ADJUSTMENT = False, CLASSIFIER_ONLY = False)
# Out:
# Device: cuda:0
# Found 7 classes: ['bird', 'cat', 'fish', 'frog', 'monkey', 'moth', 'spider']
# Sizes → Train: 2799, Val: 350
# No checkpoint found; initializing VGG-16 with ImageNet pretrained weights
#
# Epoch 1/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.8774, Avg Acc: 0.2426, Min Acc: 0.0950, Avg F1: 0.2361
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.3921, Avg Acc: 0.5057, Min Acc: 0.2600, Avg F1: 0.4986
#   -> Saved Best Avg-Acc: 0.5057
#   -> Saved Best Min-Acc: 0.2600 (was 0.0000; ref-acc updated 0.0000 -> 0.5057)
#   -> Saved Best F1: 0.4986
#
# Epoch 2/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.5730, Avg Acc: 0.4087, Min Acc: 0.2206, Avg F1: 0.4025
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 1.2805, Avg Acc: 0.5686, Min Acc: 0.4200, Avg F1: 0.5607
#   -> Saved Best Avg-Acc: 0.5686
#   -> Saved Best Min-Acc: 0.4200 (was 0.2600; ref-acc updated 0.5057 -> 0.5686)
#   -> Saved Best F1: 0.5607
#
# Epoch 3/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.2996, Avg Acc: 0.5252, Min Acc: 0.3175, Avg F1: 0.5244
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.2479, Avg Acc: 0.5857, Min Acc: 0.4000, Avg F1: 0.5781
#   -> Saved Best Avg-Acc: 0.5857
#   -> Saved Best F1: 0.5781
#
# Epoch 4/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 1.1690, Avg Acc: 0.5763, Min Acc: 0.4175, Avg F1: 0.5783
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 1.0716, Avg Acc: 0.6229, Min Acc: 0.5000, Avg F1: 0.6225
#   -> Saved Best Avg-Acc: 0.6229
#   -> Saved Best Min-Acc: 0.5000 (was 0.4200; ref-acc updated 0.5686 -> 0.6229)
#   -> Saved Best F1: 0.6225
#
# Epoch 5/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 1.0221, Avg Acc: 0.6217, Min Acc: 0.4175, Avg F1: 0.6202
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 1.0030, Avg Acc: 0.6486, Min Acc: 0.3800, Avg F1: 0.6450
#   -> Saved Best Avg-Acc: 0.6486
#   -> Saved Best F1: 0.6450
#
# Epoch 6/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.9269, Avg Acc: 0.6688, Min Acc: 0.4700, Avg F1: 0.6672
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 0.9618, Avg Acc: 0.6829, Min Acc: 0.5600, Avg F1: 0.6852
#   -> Saved Best Avg-Acc: 0.6829
#   -> Saved Best Min-Acc: 0.5600 (was 0.5000; ref-acc updated 0.6229 -> 0.6829)
#   -> Saved Best F1: 0.6852
#
# Epoch 7/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.8334, Avg Acc: 0.7056, Min Acc: 0.5850, Avg F1: 0.7081
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 0.9142, Avg Acc: 0.6886, Min Acc: 0.5200, Avg F1: 0.6887
#   -> Saved Best Avg-Acc: 0.6886
#   -> Saved Best F1: 0.6887
#
# Epoch 8/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.7395, Avg Acc: 0.7260, Min Acc: 0.5775, Avg F1: 0.7244
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Val → Loss: 0.9462, Avg Acc: 0.6829, Min Acc: 0.5400, Avg F1: 0.6837
#
# Epoch 9/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.6652, Avg Acc: 0.7660, Min Acc: 0.6600, Avg F1: 0.7653
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 0.9480, Avg Acc: 0.6886, Min Acc: 0.5600, Avg F1: 0.6918
#   -> Saved Best Min-Acc: 0.5600 (was 0.5600; ref-acc updated 0.6829 -> 0.6886)
#   -> Saved Best F1: 0.6918
#
# Epoch 10/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.6331, Avg Acc: 0.7724, Min Acc: 0.6500, Avg F1: 0.7728
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Val → Loss: 0.9297, Avg Acc: 0.6971, Min Acc: 0.5400, Avg F1: 0.7004
#   -> Saved Best Avg-Acc: 0.6971
#   -> Saved Best F1: 0.7004
#
# Epoch 11/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# Train → Loss: 0.5382, Avg Acc: 0.8085, Min Acc: 0.6875, Avg F1: 0.8078
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 0.8879, Avg Acc: 0.7143, Min Acc: 0.6000, Avg F1: 0.7179
#   -> Saved Best Avg-Acc: 0.7143
#   -> Saved Best Min-Acc: 0.6000 (was 0.5600; ref-acc updated 0.6886 -> 0.7143)
#   -> Saved Best F1: 0.7179
#
# Epoch 12/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.5285, Avg Acc: 0.8160, Min Acc: 0.7300, Avg F1: 0.8160
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 0.8891, Avg Acc: 0.7029, Min Acc: 0.5400, Avg F1: 0.7046
#
# Epoch 13/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.4801, Avg Acc: 0.8282, Min Acc: 0.6925, Avg F1: 0.8276
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 0.8741, Avg Acc: 0.7086, Min Acc: 0.6000, Avg F1: 0.7106
#
# Epoch 14/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.4293, Avg Acc: 0.8510, Min Acc: 0.7375, Avg F1: 0.8509
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 0.8790, Avg Acc: 0.7200, Min Acc: 0.6000, Avg F1: 0.7224
#   -> Saved Best Avg-Acc: 0.7200
#   -> Saved Best Min-Acc: 0.6000 (was 0.6000; ref-acc updated 0.7143 -> 0.7200)
#   -> Saved Best F1: 0.7224
#
# Epoch 15/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.4136, Avg Acc: 0.8539, Min Acc: 0.7625, Avg F1: 0.8535
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 0.8807, Avg Acc: 0.7314, Min Acc: 0.6200, Avg F1: 0.7337
#   -> Saved Best Avg-Acc: 0.7314
#   -> Saved Best Min-Acc: 0.6200 (was 0.6000; ref-acc updated 0.7200 -> 0.7314)
#   -> Saved Best F1: 0.7337
#
# Epoch 16/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.3865, Avg Acc: 0.8671, Min Acc: 0.8000, Avg F1: 0.8670
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
# Val → Loss: 0.9164, Avg Acc: 0.7286, Min Acc: 0.6400, Avg F1: 0.7321
#   -> Saved Best Min-Acc: 0.6400 (was 0.6200; ref-acc updated 0.7314 -> 0.7286)
#
# Epoch 17/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.3551, Avg Acc: 0.8714, Min Acc: 0.7850, Avg F1: 0.8713
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 0.9249, Avg Acc: 0.7171, Min Acc: 0.6200, Avg F1: 0.7204
#
# Epoch 18/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.3424, Avg Acc: 0.8846, Min Acc: 0.8100, Avg F1: 0.8848
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Val → Loss: 0.9145, Avg Acc: 0.7143, Min Acc: 0.6200, Avg F1: 0.7177
#
# Epoch 19/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.3114, Avg Acc: 0.8939, Min Acc: 0.8125, Avg F1: 0.8935
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Val → Loss: 0.9234, Avg Acc: 0.7229, Min Acc: 0.6400, Avg F1: 0.7243
#
# Epoch 20/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.3036, Avg Acc: 0.8932, Min Acc: 0.8250, Avg F1: 0.8928
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 0.9482, Avg Acc: 0.7229, Min Acc: 0.6200, Avg F1: 0.7256
# Checkpoint at epoch 20 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-4.pth
#
# Epoch 21/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2721, Avg Acc: 0.9028, Min Acc: 0.8250, Avg F1: 0.9031
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.05it/s]
# Val → Loss: 0.9774, Avg Acc: 0.7229, Min Acc: 0.6000, Avg F1: 0.7265
#
# Epoch 22/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.2730, Avg Acc: 0.9060, Min Acc: 0.8475, Avg F1: 0.9061
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 0.9985, Avg Acc: 0.7029, Min Acc: 0.5800, Avg F1: 0.7049
#
# Epoch 23/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2838, Avg Acc: 0.9003, Min Acc: 0.8125, Avg F1: 0.8998
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 0.9984, Avg Acc: 0.7029, Min Acc: 0.5800, Avg F1: 0.7050
#
# Epoch 24/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Train → Loss: 0.2580, Avg Acc: 0.9178, Min Acc: 0.8675, Avg F1: 0.9180
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 0.9906, Avg Acc: 0.7114, Min Acc: 0.6000, Avg F1: 0.7139
#
# Epoch 25/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.2620, Avg Acc: 0.9103, Min Acc: 0.8700, Avg F1: 0.9106
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 0.9872, Avg Acc: 0.7171, Min Acc: 0.6200, Avg F1: 0.7191
#
# Epoch 26/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# Train → Loss: 0.2490, Avg Acc: 0.9125, Min Acc: 0.8575, Avg F1: 0.9124
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Val → Loss: 0.9830, Avg Acc: 0.7229, Min Acc: 0.6200, Avg F1: 0.7249
#
# Epoch 27/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2339, Avg Acc: 0.9210, Min Acc: 0.8575, Avg F1: 0.9209
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
# Val → Loss: 0.9907, Avg Acc: 0.7171, Min Acc: 0.6000, Avg F1: 0.7198
#
# Epoch 28/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2182, Avg Acc: 0.9257, Min Acc: 0.8875, Avg F1: 0.9257
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# Val → Loss: 0.9983, Avg Acc: 0.7314, Min Acc: 0.6400, Avg F1: 0.7342
#   -> Saved Best Min-Acc: 0.6400 (was 0.6400; ref-acc updated 0.7286 -> 0.7314)
#   -> Saved Best F1: 0.7342
#
# Epoch 29/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2375, Avg Acc: 0.9182, Min Acc: 0.8650, Avg F1: 0.9182
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Val → Loss: 1.0051, Avg Acc: 0.7257, Min Acc: 0.6200, Avg F1: 0.7277
#
# Epoch 30/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2247, Avg Acc: 0.9285, Min Acc: 0.8625, Avg F1: 0.9283
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Val → Loss: 1.0098, Avg Acc: 0.7143, Min Acc: 0.5800, Avg F1: 0.7158
#
# Epoch 31/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2132, Avg Acc: 0.9260, Min Acc: 0.8625, Avg F1: 0.9260
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Val → Loss: 1.0061, Avg Acc: 0.7257, Min Acc: 0.6000, Avg F1: 0.7282
#
# Epoch 32/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2320, Avg Acc: 0.9228, Min Acc: 0.8825, Avg F1: 0.9230
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Val → Loss: 1.0043, Avg Acc: 0.7171, Min Acc: 0.6000, Avg F1: 0.7189
#
# Epoch 33/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.2337, Avg Acc: 0.9200, Min Acc: 0.8800, Avg F1: 0.9200
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
# Val → Loss: 1.0042, Avg Acc: 0.7229, Min Acc: 0.6200, Avg F1: 0.7246
#
# Epoch 34/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.2122, Avg Acc: 0.9275, Min Acc: 0.8800, Avg F1: 0.9274
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Val → Loss: 0.9948, Avg Acc: 0.7229, Min Acc: 0.6200, Avg F1: 0.7246
#
# Epoch 35/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.2175, Avg Acc: 0.9235, Min Acc: 0.8625, Avg F1: 0.9234
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# Val → Loss: 1.0021, Avg Acc: 0.7229, Min Acc: 0.6000, Avg F1: 0.7245
#
# Epoch 36/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2128, Avg Acc: 0.9285, Min Acc: 0.8700, Avg F1: 0.9286
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.06it/s]
# Val → Loss: 1.0039, Avg Acc: 0.7200, Min Acc: 0.6000, Avg F1: 0.7224
#
# Epoch 37/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2048, Avg Acc: 0.9343, Min Acc: 0.8950, Avg F1: 0.9342
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 1.0122, Avg Acc: 0.7200, Min Acc: 0.6000, Avg F1: 0.7230
#
# Epoch 38/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.2252, Avg Acc: 0.9207, Min Acc: 0.8775, Avg F1: 0.9206
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
# Val → Loss: 1.0185, Avg Acc: 0.7200, Min Acc: 0.6000, Avg F1: 0.7238
#
# Epoch 39/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train → Loss: 0.1993, Avg Acc: 0.9328, Min Acc: 0.8825, Avg F1: 0.9328
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Val → Loss: 1.0102, Avg Acc: 0.7200, Min Acc: 0.6000, Avg F1: 0.7224
#
# Epoch 40/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train → Loss: 0.1963, Avg Acc: 0.9325, Min Acc: 0.8900, Avg F1: 0.9324
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
# Val → Loss: 1.0119, Avg Acc: 0.7229, Min Acc: 0.6000, Avg F1: 0.7255
# Checkpoint at epoch 40 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-4.pth
#
# Epoch 41/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.2241, Avg Acc: 0.9214, Min Acc: 0.8800, Avg F1: 0.9215
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# Val → Loss: 1.0132, Avg Acc: 0.7229, Min Acc: 0.6000, Avg F1: 0.7253
#
# Epoch 42/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.1856, Avg Acc: 0.9428, Min Acc: 0.9125, Avg F1: 0.9429
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0037, Avg Acc: 0.7229, Min Acc: 0.6200, Avg F1: 0.7252
#
# Epoch 43/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.09s/it]
# Train → Loss: 0.1950, Avg Acc: 0.9314, Min Acc: 0.8875, Avg F1: 0.9313
# Val: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# Val → Loss: 0.9990, Avg Acc: 0.7229, Min Acc: 0.6000, Avg F1: 0.7253
#
# Epoch 44/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.2014, Avg Acc: 0.9310, Min Acc: 0.8875, Avg F1: 0.9311
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Val → Loss: 1.0116, Avg Acc: 0.7257, Min Acc: 0.6000, Avg F1: 0.7282
#
# Epoch 45/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.2010, Avg Acc: 0.9332, Min Acc: 0.8850, Avg F1: 0.9331
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Val → Loss: 1.0135, Avg Acc: 0.7257, Min Acc: 0.6200, Avg F1: 0.7279
#
# Epoch 46/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.1860, Avg Acc: 0.9346, Min Acc: 0.8775, Avg F1: 0.9345
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.06it/s]
# Val → Loss: 1.0078, Avg Acc: 0.7229, Min Acc: 0.6200, Avg F1: 0.7251
#
# Epoch 47/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.1998, Avg Acc: 0.9300, Min Acc: 0.8925, Avg F1: 0.9299
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Val → Loss: 1.0167, Avg Acc: 0.7257, Min Acc: 0.6200, Avg F1: 0.7281
#
# Epoch 48/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# Train → Loss: 0.1822, Avg Acc: 0.9375, Min Acc: 0.9000, Avg F1: 0.9376
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Val → Loss: 1.0197, Avg Acc: 0.7286, Min Acc: 0.6200, Avg F1: 0.7312
#
# Epoch 49/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.05s/it]
# Train → Loss: 0.2130, Avg Acc: 0.9325, Min Acc: 0.9025, Avg F1: 0.9325
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.07it/s]
# Val → Loss: 1.0192, Avg Acc: 0.7286, Min Acc: 0.6200, Avg F1: 0.7314
#
# Epoch 50/50
# ----------------------------------------
# Train: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train → Loss: 0.2207, Avg Acc: 0.9218, Min Acc: 0.8850, Avg F1: 0.9218
# Val: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Val → Loss: 1.0215, Avg Acc: 0.7229, Min Acc: 0.6200, Avg F1: 0.7259
# Final checkpoint at epoch 50 saved → Models/32x32/last_checkpoint_vgg16_32x32_Model-4.pth
#
# Training complete in 6m37s
# Final Bests → Avg Acc: 0.7314, Min Acc: 0.6400, Best-Min Ref Acc: 0.7314, Avg F1: 0.7342
