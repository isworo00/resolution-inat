# %%
import os
import math
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import torch.optim as optim
import numpy as np
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, precision_recall_fscore_support
import matplotlib.pyplot as plt

class ResidualDataset(Dataset):
    def __init__(self, csv_file, clean_base, adv_base, split='train'):
        self.df = pd.read_csv(csv_file, usecols=['rel_path', 'detect_split'])
        self.df = self.df[self.df['detect_split'] == split].reset_index(drop=True)
        self.clean_base = clean_base
        self.adv_base = adv_base

        self.files = []
        self.labels = []
        for _, row in self.df.iterrows():
            rel_path_pt = row['rel_path'].replace('.jpg', '.pt')
            # clean
            self.files.append(os.path.join(self.clean_base, rel_path_pt.lstrip('/')))
            self.labels.append(0)
            # adversarial
            self.files.append(os.path.join(self.adv_base, rel_path_pt.lstrip('/')))
            self.labels.append(1)

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        path = self.files[idx]
        label = self.labels[idx]
        tensor = torch.load(path)
        tensor = tensor.float() / 255.0
        return tensor, label

def evaluate_on_loader(model, loader, device='cuda'):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device)
            labels = labels.to(device)
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    acc = correct / total if total > 0 else 0.0
    return acc, total


def evaluate_on_loader_with_loss(model, loader, criterion, device='cuda'):
    model.eval()
    correct = 0
    total = 0
    running_loss = 0.0
    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device)
            labels = labels.to(device)
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * imgs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    avg_loss = running_loss / total if total > 0 else 0.0
    acc = correct / total if total > 0 else 0.0
    return acc, total, avg_loss


def evaluate_test(model=None, csv_file=None,
                  clean_base='../03-ExtractCharacteristics/jpg_residual-clean/256x256/',
                  adv_base='../03-ExtractCharacteristics/jpg_residual/256x256/cw/',
                  batch_size=16,
                  device='cuda',
                  model_path=None,
                  roc_path='./results/roc_test.png'):
    assert csv_file is not None, "csv_file must be provided"

    if model is None and model_path is not None:
        model = load_model_state(model_path, device=device)
    assert model is not None, "Either a model or model_path must be provided"

    test_ds = ResidualDataset(csv_file, clean_base, adv_base, split='test')
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    model.eval()
    all_preds = []
    all_labels = []
    all_probs = []  
    
    softmax = nn.Softmax(dim=1)
    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs = imgs.to(device)
            labels = labels.to(device)
            outputs = model(imgs)
            probs = softmax(outputs)[:, 1]  
            preds = torch.argmax(outputs, dim=1)

            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_probs = np.array(all_probs)
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    acc = (all_preds == all_labels).mean() if all_labels.size > 0 else 0.0
    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1]) if all_labels.size > 0 else np.zeros((2,2),dtype=int)

    auc = None
    roc_data = None
    try:
        if len(np.unique(all_labels)) == 2:
            auc = roc_auc_score(all_labels, all_probs)
            fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
            roc_data = (fpr, tpr, thresholds)
            # plot ROC
            os.makedirs(os.path.dirname(roc_path), exist_ok=True)
            plt.figure()
            plt.plot(fpr, tpr)
            plt.plot([0,1], [0,1], linestyle='--')
            plt.xlabel('False Positive Rate')
            plt.ylabel('True Positive Rate')
            plt.title(f'ROC curve (AUC = {auc:.4f})')
            plt.grid(True)
            plt.savefig(roc_path)
            plt.close()
        else:
            auc = None
            roc_data = None
    except Exception as e:
        auc = None
        roc_data = None

    pr, rec, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='binary', zero_division=0)

    results = {
        'accuracy': float(acc),
        'total': int(all_labels.size),
        'confusion_matrix': cm,
        'auc': float(auc) if auc is not None else None,
        'roc_curve': roc_data,
        'precision_recall_f1': (float(pr), float(rec), float(f1)),
        'roc_path': roc_path if roc_data is not None else None,
    }

    # Print a compact summary
    print(f"Test Accuracy: {results['accuracy']:.4f} over {results['total']} samples")
    print('Confusion Matrix (rows=true, cols=pred):')
    print(results['confusion_matrix'])
    if results['auc'] is not None:
        print(f"AUC-ROC: {results['auc']:.4f} (ROC plot saved to: {results['roc_path']})")
    else:
        print('AUC-ROC: not available (need both classes present in test set)')
    prc = results['precision_recall_f1']
    print(f"Precision: {prc[0]:.4f}, Recall: {prc[1]:.4f}, F1: {prc[2]:.4f}")

    return results

def save_model_state(model, path):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    torch.save(model.state_dict(), path)


def load_model_state(path, device='cuda'):
    model = models.resnet18(weights=None)
    model.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
    model.fc = nn.Linear(model.fc.in_features, 2)

    map_location = torch.device(device)
    checkpoint = torch.load(path, map_location=map_location)

    if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
        state = checkpoint['model_state_dict']
    else:
        state = checkpoint

    model.load_state_dict(state)
    model = model.to(device)
    model.eval()
    return model

def train_detector(csv_file,
                   clean_base='../03-ExtractCharacteristics/jpg_residual-clean/256x256/',
                   adv_base='../03-ExtractCharacteristics/jpg_residual/256x256/cw/',
                   batch_size=4,
                   num_epochs=50,
                   lr=1e-3,
                   device='cuda',
                   model_save_path='./saved_models/best_detector.pth',
                   save_best_only=True):
    train_ds = ResidualDataset(csv_file, clean_base, adv_base, split='train')
    val_ds = ResidualDataset(csv_file, clean_base, adv_base, split='val')

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, pin_memory=True)

    model = models.resnet18(weights=None)

    model.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
    model.fc = nn.Linear(model.fc.in_features, 2)
    model = model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.5, patience=5)

    best_val_acc = 0.0
    best_val_loss = math.inf
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct, total = 0, 0
        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * imgs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        train_loss = running_loss / total if total > 0 else 0.0
        train_acc = correct / total if total > 0 else 0.0

        val_acc, val_total, val_loss = evaluate_on_loader_with_loss(model, val_loader, criterion, device=device)

        scheduler.step(1 - val_acc)

        print(f"Epoch {epoch+1}/{num_epochs}: Train Loss={train_loss:.4f}, Train Acc={train_acc:.4f}, Val Acc={val_acc:.4f}, Val Loss={val_loss:.4f}")

        save_current = False
        if val_acc > best_val_acc:
            save_current = True
        elif val_acc == best_val_acc and val_loss < best_val_loss:
            save_current = True

        if save_current:
            best_val_acc = val_acc
            best_val_loss = val_loss
            
            if save_best_only:
                save_model_state(model, model_save_path)
                print(f"Saved best model (val_acc={best_val_acc:.4f}, val_loss={best_val_loss:.4f}) to: {model_save_path}")

    if not save_best_only:
        save_model_state(model, model_save_path)
        print(f"Saved final model to: {model_save_path}")

    return None

# %%
img_size = 32
attack_methods = ['fgsm','bim','pgd','df','cw']
for attack_method in attack_methods:
    print(f'Model Training - {img_size}x{img_size} - {attack_method} \n ')
    train_detector(csv_file='/kaggle/input/splits/common_success_detect_split.csv',
                   clean_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/clean',
                   adv_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/{attack_method}',
                   batch_size=32,
                   num_epochs=50,
                   lr=1e-3,
                   device='cuda',
                   model_save_path=f'./saved_models/best_detector_{img_size}x{img_size}_{attack_method}.pth',
                   save_best_only=True)
    print('Done. \n')
# Out:
# Model Training - 32x32 - fgsm
#
# Epoch 1/50: Train Loss=0.1210, Train Acc=0.9599, Val Acc=0.5000, Val Loss=8.1504
# Saved best model (val_acc=0.5000, val_loss=8.1504) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 2/50: Train Loss=0.0353, Train Acc=0.9918, Val Acc=0.5000, Val Loss=5.9487
# Saved best model (val_acc=0.5000, val_loss=5.9487) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 3/50: Train Loss=0.0023, Train Acc=1.0000, Val Acc=0.5000, Val Loss=6.5063
# Epoch 4/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0070
# Saved best model (val_acc=1.0000, val_loss=0.0070) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 5/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Saved best model (val_acc=1.0000, val_loss=0.0002) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 6/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 7/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 8/50: Train Loss=0.0087, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0003
# Epoch 9/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 10/50: Train Loss=0.0210, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0002
# Epoch 11/50: Train Loss=0.0019, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 12/50: Train Loss=0.0034, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 13/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 14/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 15/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 19/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 21/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 22/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 23/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 24/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 25/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 26/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_fgsm.pth
# Epoch 27/50: Train Loss=0.0018, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Epoch 28/50: Train Loss=0.0033, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0002
# Epoch 29/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 30/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 32/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 35/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 38/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 42/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 46/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 50/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Done.
#
# Model Training - 32x32 - bim
#
# Epoch 1/50: Train Loss=0.0664, Train Acc=0.9650, Val Acc=0.5000, Val Loss=6.2856
# Saved best model (val_acc=0.5000, val_loss=6.2856) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 2/50: Train Loss=0.0401, Train Acc=0.9918, Val Acc=0.5000, Val Loss=9.2931
# Epoch 3/50: Train Loss=0.0031, Train Acc=0.9990, Val Acc=0.5000, Val Loss=4.6543
# Saved best model (val_acc=0.5000, val_loss=4.6543) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 4/50: Train Loss=0.0059, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0010
# Saved best model (val_acc=1.0000, val_loss=0.0010) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 5/50: Train Loss=0.0222, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0004
# Saved best model (val_acc=1.0000, val_loss=0.0004) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 6/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 7/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 9/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 10/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 11/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 12/50: Train Loss=0.0042, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0002
# Epoch 13/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 14/50: Train Loss=0.0036, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 15/50: Train Loss=0.0014, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 26/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_bim.pth
# Epoch 38/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 32x32 - pgd
#
# Epoch 1/50: Train Loss=0.0533, Train Acc=0.9702, Val Acc=0.5000, Val Loss=5.1510
# Saved best model (val_acc=0.5000, val_loss=5.1510) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 2/50: Train Loss=0.0607, Train Acc=0.9897, Val Acc=0.5000, Val Loss=5.6608
# Epoch 3/50: Train Loss=0.0562, Train Acc=0.9866, Val Acc=0.5000, Val Loss=3.7463
# Saved best model (val_acc=0.5000, val_loss=3.7463) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 4/50: Train Loss=0.0056, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0068
# Saved best model (val_acc=1.0000, val_loss=0.0068) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 5/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Saved best model (val_acc=1.0000, val_loss=0.0002) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 6/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 7/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 9/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 10/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 11/50: Train Loss=0.0040, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0001
# Epoch 12/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 13/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_pgd.pth
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0019, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 32x32 - df
#
# Epoch 1/50: Train Loss=0.0884, Train Acc=0.9702, Val Acc=0.5000, Val Loss=4.1137
# Saved best model (val_acc=0.5000, val_loss=4.1137) to: ./saved_models/best_detector_32x32_df.pth
# Epoch 2/50: Train Loss=0.0128, Train Acc=0.9959, Val Acc=0.5000, Val Loss=5.4123
# Epoch 3/50: Train Loss=0.0152, Train Acc=0.9959, Val Acc=0.5000, Val Loss=4.7930
# Epoch 4/50: Train Loss=0.0137, Train Acc=0.9959, Val Acc=0.9815, Val Loss=0.0324
# Saved best model (val_acc=0.9815, val_loss=0.0324) to: ./saved_models/best_detector_32x32_df.pth
# Epoch 5/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0005
# Saved best model (val_acc=1.0000, val_loss=0.0005) to: ./saved_models/best_detector_32x32_df.pth
# Epoch 6/50: Train Loss=0.0039, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_df.pth
# Epoch 7/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 8/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_32x32_df.pth
# Epoch 9/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_df.pth
# Epoch 10/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 11/50: Train Loss=0.0022, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 13/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0017, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_df.pth
# Epoch 15/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0195, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0284, Train Acc=0.9907, Val Acc=1.0000, Val Loss=0.0007
# Epoch 21/50: Train Loss=0.0093, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0004
# Epoch 22/50: Train Loss=0.0080, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0013
# Epoch 23/50: Train Loss=0.0017, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0020
# Epoch 24/50: Train Loss=0.0012, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0017
# Epoch 25/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0009
# Epoch 26/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 27/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0005
# Epoch 28/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0006
# Epoch 29/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 30/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 31/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 32/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 33/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 34/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 35/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 36/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 37/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 38/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 39/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 41/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 42/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 43/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 44/50: Train Loss=0.0019, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 45/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 47/50: Train Loss=0.0026, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 48/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 49/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 50/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Done.
#
# Model Training - 32x32 - cw
#
# Epoch 1/50: Train Loss=0.0732, Train Acc=0.9660, Val Acc=0.5000, Val Loss=5.8240
# Saved best model (val_acc=0.5000, val_loss=5.8240) to: ./saved_models/best_detector_32x32_cw.pth
# Epoch 2/50: Train Loss=0.0203, Train Acc=0.9938, Val Acc=0.5000, Val Loss=4.1264
# Saved best model (val_acc=0.5000, val_loss=4.1264) to: ./saved_models/best_detector_32x32_cw.pth
# Epoch 3/50: Train Loss=0.0173, Train Acc=0.9938, Val Acc=0.5000, Val Loss=2.9362
# Saved best model (val_acc=0.5000, val_loss=2.9362) to: ./saved_models/best_detector_32x32_cw.pth
# Epoch 4/50: Train Loss=0.0122, Train Acc=0.9969, Val Acc=0.9938, Val Loss=0.0070
# Saved best model (val_acc=0.9938, val_loss=0.0070) to: ./saved_models/best_detector_32x32_cw.pth
# Epoch 5/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Saved best model (val_acc=1.0000, val_loss=0.0002) to: ./saved_models/best_detector_32x32_cw.pth
# Epoch 6/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_cw.pth
# Epoch 7/50: Train Loss=0.0011, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 8/50: Train Loss=0.0178, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0196
# Epoch 9/50: Train Loss=0.0065, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0190
# Epoch 10/50: Train Loss=0.0060, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_32x32_cw.pth
# Epoch 11/50: Train Loss=0.0155, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0014
# Epoch 12/50: Train Loss=0.0036, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 13/50: Train Loss=0.0017, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 14/50: Train Loss=0.0011, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 15/50: Train Loss=0.0024, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0006
# Epoch 16/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 17/50: Train Loss=0.0017, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 18/50: Train Loss=0.0031, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0026, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0015
# Epoch 20/50: Train Loss=0.0056, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 21/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0008
# Epoch 22/50: Train Loss=0.0031, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 25/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 26/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 28/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 30/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 32/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 33/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Done.

# %%
img_size = 64
attack_methods = ['fgsm','bim','pgd','df','cw']
for attack_method in attack_methods:
    print(f'Model Training - {img_size}x{img_size} - {attack_method} \n ')
    train_detector(csv_file='/kaggle/input/splits/common_success_detect_split.csv',
                   clean_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/clean',
                   adv_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/{attack_method}',
                   batch_size=32,
                   num_epochs=50,
                   lr=1e-3,
                   device='cuda',
                   model_save_path=f'./saved_models/best_detector_{img_size}x{img_size}_{attack_method}.pth',
                   save_best_only=True)
    print('Done. \n')
# Out:
# Model Training - 64x64 - fgsm
#
# Epoch 1/50: Train Loss=0.0270, Train Acc=0.9856, Val Acc=0.5000, Val Loss=5.4084
# Saved best model (val_acc=0.5000, val_loss=5.4084) to: ./saved_models/best_detector_64x64_fgsm.pth
# Epoch 2/50: Train Loss=0.0013, Train Acc=1.0000, Val Acc=0.5000, Val Loss=6.5196
# Epoch 3/50: Train Loss=0.0427, Train Acc=0.9949, Val Acc=0.5000, Val Loss=4.8773
# Saved best model (val_acc=0.5000, val_loss=4.8773) to: ./saved_models/best_detector_64x64_fgsm.pth
# Epoch 4/50: Train Loss=0.0011, Train Acc=1.0000, Val Acc=0.9753, Val Loss=0.0695
# Saved best model (val_acc=0.9753, val_loss=0.0695) to: ./saved_models/best_detector_64x64_fgsm.pth
# Epoch 5/50: Train Loss=0.0139, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_64x64_fgsm.pth
# Epoch 6/50: Train Loss=0.0024, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_64x64_fgsm.pth
# Epoch 7/50: Train Loss=0.0047, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_fgsm.pth
# Epoch 8/50: Train Loss=0.0104, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_fgsm.pth
# Epoch 9/50: Train Loss=0.0079, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Epoch 10/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0012, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 12/50: Train Loss=0.0016, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 13/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 14/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 15/50: Train Loss=0.0041, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 16/50: Train Loss=0.0052, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0016
# Epoch 17/50: Train Loss=0.0078, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0016, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 20/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 21/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 22/50: Train Loss=0.0023, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 23/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 24/50: Train Loss=0.0070, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Epoch 25/50: Train Loss=0.0012, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 26/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 27/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 28/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 29/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 30/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 32/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 33/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 37/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 38/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 42/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 46/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 50/50: Train Loss=0.0034, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Done.
#
# Model Training - 64x64 - bim
#
# Epoch 1/50: Train Loss=0.0224, Train Acc=0.9877, Val Acc=0.5000, Val Loss=8.0385
# Saved best model (val_acc=0.5000, val_loss=8.0385) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 2/50: Train Loss=0.0193, Train Acc=0.9938, Val Acc=0.5000, Val Loss=4.4004
# Saved best model (val_acc=0.5000, val_loss=4.4004) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 3/50: Train Loss=0.0125, Train Acc=0.9969, Val Acc=0.5000, Val Loss=5.5004
# Epoch 4/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=0.9938, Val Loss=0.0109
# Saved best model (val_acc=0.9938, val_loss=0.0109) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 5/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 6/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 7/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 9/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 10/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_bim.pth
# Epoch 14/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0089, Train Acc=0.9990, Val Acc=0.9568, Val Loss=0.1185
# Epoch 18/50: Train Loss=0.0093, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0003
# Epoch 19/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 20/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 21/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 64x64 - pgd
#
# Epoch 1/50: Train Loss=0.0254, Train Acc=0.9846, Val Acc=0.5000, Val Loss=3.8224
# Saved best model (val_acc=0.5000, val_loss=3.8224) to: ./saved_models/best_detector_64x64_pgd.pth
# Epoch 2/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=0.5000, Val Loss=5.8849
# Epoch 3/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=0.5000, Val Loss=5.8729
# Epoch 4/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=0.9877, Val Loss=0.0382
# Saved best model (val_acc=0.9877, val_loss=0.0382) to: ./saved_models/best_detector_64x64_pgd.pth
# Epoch 5/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_pgd.pth
# Epoch 6/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_pgd.pth
# Epoch 7/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_pgd.pth
# Epoch 8/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_pgd.pth
# Epoch 10/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_pgd.pth
# Epoch 12/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0046, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0189, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0092, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0073, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0081, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 64x64 - df
#
# Epoch 1/50: Train Loss=0.0845, Train Acc=0.9650, Val Acc=0.5000, Val Loss=3.1262
# Saved best model (val_acc=0.5000, val_loss=3.1262) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 2/50: Train Loss=0.0520, Train Acc=0.9887, Val Acc=0.5000, Val Loss=3.6890
# Epoch 3/50: Train Loss=0.0106, Train Acc=0.9979, Val Acc=0.5000, Val Loss=7.3208
# Epoch 4/50: Train Loss=0.0029, Train Acc=0.9990, Val Acc=0.9877, Val Loss=0.0412
# Saved best model (val_acc=0.9877, val_loss=0.0412) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 5/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 6/50: Train Loss=0.0010, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 7/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 8/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0013, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 10/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 12/50: Train Loss=0.0009, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 13/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 14/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 16/50: Train Loss=0.0010, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_df.pth
# Epoch 17/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=0.9877, Val Loss=0.0449
# Epoch 18/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 23/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 64x64 - cw
#
# Epoch 1/50: Train Loss=0.0551, Train Acc=0.9733, Val Acc=0.5000, Val Loss=4.7347
# Saved best model (val_acc=0.5000, val_loss=4.7347) to: ./saved_models/best_detector_64x64_cw.pth
# Epoch 2/50: Train Loss=0.0229, Train Acc=0.9938, Val Acc=0.5000, Val Loss=3.0603
# Saved best model (val_acc=0.5000, val_loss=3.0603) to: ./saved_models/best_detector_64x64_cw.pth
# Epoch 3/50: Train Loss=0.0067, Train Acc=0.9979, Val Acc=0.5000, Val Loss=5.9354
# Epoch 4/50: Train Loss=0.0014, Train Acc=1.0000, Val Acc=0.9938, Val Loss=0.0162
# Saved best model (val_acc=0.9938, val_loss=0.0162) to: ./saved_models/best_detector_64x64_cw.pth
# Epoch 5/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_cw.pth
# Epoch 6/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_cw.pth
# Epoch 7/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_cw.pth
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_64x64_cw.pth
# Epoch 9/50: Train Loss=0.0093, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0100
# Epoch 10/50: Train Loss=0.0014, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 11/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0398, Train Acc=0.9897, Val Acc=0.9877, Val Loss=0.0257
# Epoch 15/50: Train Loss=0.0108, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0008
# Epoch 16/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 17/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 21/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0006
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0023, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0031, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.

# %%
img_size = 128
attack_methods = ['fgsm','bim','pgd','df','cw']
for attack_method in attack_methods:
    print(f'Model Training - {img_size}x{img_size} - {attack_method} \n ')
    train_detector(csv_file='/kaggle/input/splits/common_success_detect_split.csv',
                   clean_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/clean',
                   adv_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/{attack_method}',
                   batch_size=32,
                   num_epochs=50,
                   lr=1e-3,
                   device='cuda',
                   model_save_path=f'./saved_models/best_detector_{img_size}x{img_size}_{attack_method}.pth',
                   save_best_only=True)
    print('Done. \n')
# Out:
# Model Training - 128x128 - fgsm
#
# Epoch 1/50: Train Loss=0.0748, Train Acc=0.9630, Val Acc=0.5000, Val Loss=5.3436
# Saved best model (val_acc=0.5000, val_loss=5.3436) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 2/50: Train Loss=0.0266, Train Acc=0.9918, Val Acc=0.5000, Val Loss=3.4101
# Saved best model (val_acc=0.5000, val_loss=3.4101) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 3/50: Train Loss=0.0022, Train Acc=1.0000, Val Acc=0.5000, Val Loss=4.5751
# Epoch 4/50: Train Loss=0.0037, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 5/50: Train Loss=0.0058, Train Acc=0.9969, Val Acc=0.9259, Val Loss=0.5230
# Epoch 6/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0254
# Epoch 7/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 9/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 10/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0012, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 12/50: Train Loss=0.0012, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0003
# Epoch 13/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 14/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_fgsm.pth
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 128x128 - bim
#
# Epoch 1/50: Train Loss=0.0384, Train Acc=0.9681, Val Acc=0.5000, Val Loss=5.0450
# Saved best model (val_acc=0.5000, val_loss=5.0450) to: ./saved_models/best_detector_128x128_bim.pth
# Epoch 2/50: Train Loss=0.0188, Train Acc=0.9969, Val Acc=0.5000, Val Loss=3.4566
# Saved best model (val_acc=0.5000, val_loss=3.4566) to: ./saved_models/best_detector_128x128_bim.pth
# Epoch 3/50: Train Loss=0.0049, Train Acc=0.9979, Val Acc=0.5000, Val Loss=5.0981
# Epoch 4/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_bim.pth
# Epoch 5/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_bim.pth
# Epoch 6/50: Train Loss=0.0332, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0001
# Epoch 7/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_bim.pth
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0054, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0000
# Epoch 10/50: Train Loss=0.0094, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 12/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0038, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0032, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0022
# Epoch 15/50: Train Loss=0.0038, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0032, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 128x128 - pgd
#
# Epoch 1/50: Train Loss=0.0276, Train Acc=0.9856, Val Acc=0.5000, Val Loss=7.3413
# Saved best model (val_acc=0.5000, val_loss=7.3413) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 2/50: Train Loss=0.0269, Train Acc=0.9959, Val Acc=0.5000, Val Loss=4.9838
# Saved best model (val_acc=0.5000, val_loss=4.9838) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 3/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=0.5000, Val Loss=4.5663
# Saved best model (val_acc=0.5000, val_loss=4.5663) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 4/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Saved best model (val_acc=1.0000, val_loss=0.0004) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 5/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 6/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=0.5556, Val Loss=0.4631
# Epoch 7/50: Train Loss=0.0132, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 8/50: Train Loss=0.0011, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 10/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 11/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 13/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 14/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 18/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 20/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_pgd.pth
# Epoch 41/50: Train Loss=0.0076, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 128x128 - df
#
# Epoch 1/50: Train Loss=0.0766, Train Acc=0.9774, Val Acc=0.5000, Val Loss=7.4383
# Saved best model (val_acc=0.5000, val_loss=7.4383) to: ./saved_models/best_detector_128x128_df.pth
# Epoch 2/50: Train Loss=0.0164, Train Acc=0.9928, Val Acc=0.5000, Val Loss=2.3295
# Saved best model (val_acc=0.5000, val_loss=2.3295) to: ./saved_models/best_detector_128x128_df.pth
# Epoch 3/50: Train Loss=0.0059, Train Acc=0.9990, Val Acc=0.5000, Val Loss=4.5196
# Epoch 4/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=0.9938, Val Loss=0.0311
# Saved best model (val_acc=0.9938, val_loss=0.0311) to: ./saved_models/best_detector_128x128_df.pth
# Epoch 5/50: Train Loss=0.0025, Train Acc=0.9990, Val Acc=0.9321, Val Loss=0.6483
# Epoch 6/50: Train Loss=0.0015, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_df.pth
# Epoch 7/50: Train Loss=0.0021, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0013
# Epoch 8/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_df.pth
# Epoch 10/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0094, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0067
# Epoch 12/50: Train Loss=0.0356, Train Acc=0.9907, Val Acc=0.5123, Val Loss=421.2859
# Epoch 13/50: Train Loss=0.0602, Train Acc=0.9815, Val Acc=1.0000, Val Loss=0.0001
# Epoch 14/50: Train Loss=0.0029, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0050, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0079, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0030, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0111, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0012
# Epoch 19/50: Train Loss=0.0016, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 20/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 21/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 22/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 26/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0013, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0013, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0017, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 128x128 - cw
#
# Epoch 1/50: Train Loss=0.0882, Train Acc=0.9537, Val Acc=0.5000, Val Loss=3.1778
# Saved best model (val_acc=0.5000, val_loss=3.1778) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 2/50: Train Loss=0.0166, Train Acc=0.9938, Val Acc=0.5000, Val Loss=5.2884
# Epoch 3/50: Train Loss=0.0153, Train Acc=0.9938, Val Acc=0.5000, Val Loss=4.1154
# Epoch 4/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=0.9691, Val Loss=0.1220
# Saved best model (val_acc=0.9691, val_loss=0.1220) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 5/50: Train Loss=0.0119, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0007
# Saved best model (val_acc=1.0000, val_loss=0.0007) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 6/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 7/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 9/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 10/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 12/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 14/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 15/50: Train Loss=0.0061, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0002
# Epoch 16/50: Train Loss=0.0146, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0002
# Epoch 17/50: Train Loss=0.0033, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_128x128_cw.pth
# Epoch 24/50: Train Loss=0.0061, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Epoch 25/50: Train Loss=0.0025, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0010
# Epoch 26/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 27/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 28/50: Train Loss=0.0018, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0010
# Epoch 30/50: Train Loss=0.0025, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 32/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 33/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 34/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 43/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.

# %%
img_size = 256
attack_methods = ['fgsm','bim','pgd','df','cw']
for attack_method in attack_methods:
    print(f'Model Training - {img_size}x{img_size} - {attack_method} \n ')
    train_detector(csv_file='/kaggle/input/splits/common_success_detect_split.csv',
                   clean_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/clean',
                   adv_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/{attack_method}',
                   batch_size=32,
                   num_epochs=50,
                   lr=1e-3,
                   device='cuda',
                   model_save_path=f'./saved_models/best_detector_{img_size}x{img_size}_{attack_method}.pth',
                   save_best_only=True)
    print('Done. \n')
# Out:
# Model Training - 256x256 - fgsm
#
# Epoch 1/50: Train Loss=0.1030, Train Acc=0.9609, Val Acc=0.5000, Val Loss=5.5890
# Saved best model (val_acc=0.5000, val_loss=5.5890) to: ./saved_models/best_detector_256x256_fgsm.pth
# Epoch 2/50: Train Loss=0.0304, Train Acc=0.9907, Val Acc=0.5000, Val Loss=3.2669
# Saved best model (val_acc=0.5000, val_loss=3.2669) to: ./saved_models/best_detector_256x256_fgsm.pth
# Epoch 3/50: Train Loss=0.0075, Train Acc=0.9979, Val Acc=0.5000, Val Loss=4.7336
# Epoch 4/50: Train Loss=0.0046, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0009
# Saved best model (val_acc=1.0000, val_loss=0.0009) to: ./saved_models/best_detector_256x256_fgsm.pth
# Epoch 5/50: Train Loss=0.0026, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_256x256_fgsm.pth
# Epoch 6/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_256x256_fgsm.pth
# Epoch 7/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_fgsm.pth
# Epoch 8/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 10/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_fgsm.pth
# Epoch 15/50: Train Loss=0.0073, Train Acc=0.9979, Val Acc=0.9938, Val Loss=0.0340
# Epoch 16/50: Train Loss=0.0067, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0010, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0008, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 32/50: Train Loss=0.0042, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 33/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 35/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 37/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 38/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 42/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 44/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 46/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 47/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 48/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 49/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 50/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Done.
#
# Model Training - 256x256 - bim
#
# Epoch 1/50: Train Loss=0.0360, Train Acc=0.9866, Val Acc=0.5000, Val Loss=4.3494
# Saved best model (val_acc=0.5000, val_loss=4.3494) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 2/50: Train Loss=0.0105, Train Acc=0.9959, Val Acc=0.5000, Val Loss=3.9613
# Saved best model (val_acc=0.5000, val_loss=3.9613) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 3/50: Train Loss=0.0570, Train Acc=0.9938, Val Acc=0.5000, Val Loss=2.2505
# Saved best model (val_acc=0.5000, val_loss=2.2505) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 4/50: Train Loss=0.0024, Train Acc=1.0000, Val Acc=0.5000, Val Loss=3.1325
# Epoch 5/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 6/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 7/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 8/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 9/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 10/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 12/50: Train Loss=0.0020, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0146, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0016, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_bim.pth
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 256x256 - pgd
#
# Epoch 1/50: Train Loss=0.0446, Train Acc=0.9825, Val Acc=0.5000, Val Loss=2.1093
# Saved best model (val_acc=0.5000, val_loss=2.1093) to: ./saved_models/best_detector_256x256_pgd.pth
# Epoch 2/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=0.5000, Val Loss=4.3254
# Epoch 3/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=0.5000, Val Loss=7.6233
# Epoch 4/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_pgd.pth
# Epoch 5/50: Train Loss=0.0019, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 6/50: Train Loss=0.0170, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0001
# Epoch 7/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 8/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 10/50: Train Loss=0.0019, Train Acc=0.9990, Val Acc=0.9568, Val Loss=0.1955
# Epoch 11/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_pgd.pth
# Epoch 13/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_pgd.pth
# Epoch 17/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_pgd.pth
# Epoch 18/50: Train Loss=0.0108, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_pgd.pth
# Epoch 21/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_pgd.pth
# Epoch 23/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 256x256 - df
#
# Epoch 1/50: Train Loss=0.1109, Train Acc=0.9640, Val Acc=0.5000, Val Loss=25.1191
# Saved best model (val_acc=0.5000, val_loss=25.1191) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 2/50: Train Loss=0.0780, Train Acc=0.9722, Val Acc=0.5000, Val Loss=4.7133
# Saved best model (val_acc=0.5000, val_loss=4.7133) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 3/50: Train Loss=0.0054, Train Acc=0.9990, Val Acc=0.5000, Val Loss=5.0593
# Epoch 4/50: Train Loss=0.0012, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Saved best model (val_acc=1.0000, val_loss=0.0002) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 5/50: Train Loss=0.0035, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0039
# Epoch 6/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=0.9877, Val Loss=0.0376
# Epoch 7/50: Train Loss=0.0059, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 8/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 9/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 10/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 11/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 13/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 15/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0010, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_df.pth
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0019, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0013, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 256x256 - cw
#
# Epoch 1/50: Train Loss=0.1114, Train Acc=0.9599, Val Acc=0.5000, Val Loss=2.6173
# Saved best model (val_acc=0.5000, val_loss=2.6173) to: ./saved_models/best_detector_256x256_cw.pth
# Epoch 2/50: Train Loss=0.0333, Train Acc=0.9938, Val Acc=0.5000, Val Loss=4.2644
# Epoch 3/50: Train Loss=0.0415, Train Acc=0.9887, Val Acc=0.5000, Val Loss=4.4066
# Epoch 4/50: Train Loss=0.0160, Train Acc=0.9969, Val Acc=0.9630, Val Loss=0.0800
# Saved best model (val_acc=0.9630, val_loss=0.0800) to: ./saved_models/best_detector_256x256_cw.pth
# Epoch 5/50: Train Loss=0.0219, Train Acc=0.9938, Val Acc=0.9938, Val Loss=0.0046
# Saved best model (val_acc=0.9938, val_loss=0.0046) to: ./saved_models/best_detector_256x256_cw.pth
# Epoch 6/50: Train Loss=0.0107, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_256x256_cw.pth
# Epoch 7/50: Train Loss=0.0144, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0015
# Epoch 8/50: Train Loss=0.0103, Train Acc=0.9979, Val Acc=0.5000, Val Loss=2.0213
# Epoch 9/50: Train Loss=0.0054, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_cw.pth
# Epoch 10/50: Train Loss=0.0049, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 11/50: Train Loss=0.0080, Train Acc=0.9969, Val Acc=0.6420, Val Loss=0.8687
# Epoch 12/50: Train Loss=0.0030, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0047, Train Acc=0.9979, Val Acc=0.7469, Val Loss=0.3865
# Epoch 15/50: Train Loss=0.0028, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0039
# Epoch 16/50: Train Loss=0.0046, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0200, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_256x256_cw.pth
# Epoch 18/50: Train Loss=0.0900, Train Acc=0.9866, Val Acc=0.9136, Val Loss=0.1524
# Epoch 19/50: Train Loss=0.0116, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0006
# Epoch 20/50: Train Loss=0.0060, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0005
# Epoch 21/50: Train Loss=0.0041, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0004
# Epoch 22/50: Train Loss=0.0029, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0004
# Epoch 23/50: Train Loss=0.0063, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0004
# Epoch 24/50: Train Loss=0.0065, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0005
# Epoch 25/50: Train Loss=0.0014, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0005
# Epoch 26/50: Train Loss=0.0025, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0007
# Epoch 27/50: Train Loss=0.0044, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0006
# Epoch 28/50: Train Loss=0.0043, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0010
# Epoch 29/50: Train Loss=0.0021, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0022
# Epoch 30/50: Train Loss=0.0084, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0028
# Epoch 31/50: Train Loss=0.0038, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0008
# Epoch 32/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0006
# Epoch 33/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0006
# Epoch 34/50: Train Loss=0.0015, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0008
# Epoch 35/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0006
# Epoch 36/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0005
# Epoch 37/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 38/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 39/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 40/50: Train Loss=0.0010, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 41/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0010
# Epoch 42/50: Train Loss=0.0010, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 43/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 44/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 45/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 46/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 47/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0005
# Epoch 48/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0006
# Epoch 49/50: Train Loss=0.0010, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 50/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Done.

# %%
img_size = 512
attack_methods = ['fgsm','bim','pgd','df','cw']
for attack_method in attack_methods:
    print(f'Model Training - {img_size}x{img_size} - {attack_method} \n ')
    train_detector(csv_file='/kaggle/input/splits/common_success_detect_split.csv',
                   clean_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/clean',
                   adv_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/{attack_method}',
                   batch_size=32,
                   num_epochs=50,
                   lr=1e-3,
                   device='cuda',
                   model_save_path=f'./saved_models/best_detector_{img_size}x{img_size}_{attack_method}.pth',
                   save_best_only=True)
    print('Done. \n')
# Out:
# Model Training - 512x512 - fgsm
#
# Epoch 1/50: Train Loss=0.1674, Train Acc=0.9609, Val Acc=0.5000, Val Loss=2.8731
# Saved best model (val_acc=0.5000, val_loss=2.8731) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 2/50: Train Loss=0.0557, Train Acc=0.9856, Val Acc=0.5000, Val Loss=2.6258
# Saved best model (val_acc=0.5000, val_loss=2.6258) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 3/50: Train Loss=0.0232, Train Acc=0.9949, Val Acc=0.5000, Val Loss=3.1980
# Epoch 4/50: Train Loss=0.0217, Train Acc=0.9938, Val Acc=0.6296, Val Loss=0.6038
# Saved best model (val_acc=0.6296, val_loss=0.6038) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 5/50: Train Loss=0.0225, Train Acc=0.9949, Val Acc=0.9198, Val Loss=0.4864
# Saved best model (val_acc=0.9198, val_loss=0.4864) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 6/50: Train Loss=0.0200, Train Acc=0.9949, Val Acc=0.9938, Val Loss=0.0373
# Saved best model (val_acc=0.9938, val_loss=0.0373) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 7/50: Train Loss=0.0197, Train Acc=0.9949, Val Acc=0.9938, Val Loss=0.0310
# Saved best model (val_acc=0.9938, val_loss=0.0310) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 8/50: Train Loss=0.0313, Train Acc=0.9928, Val Acc=0.9938, Val Loss=0.0443
# Epoch 9/50: Train Loss=0.0098, Train Acc=0.9969, Val Acc=0.9938, Val Loss=0.0087
# Saved best model (val_acc=0.9938, val_loss=0.0087) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 10/50: Train Loss=0.0287, Train Acc=0.9959, Val Acc=0.9938, Val Loss=0.0105
# Epoch 11/50: Train Loss=0.0203, Train Acc=0.9949, Val Acc=0.9877, Val Loss=0.0534
# Epoch 12/50: Train Loss=0.0150, Train Acc=0.9959, Val Acc=0.9568, Val Loss=0.3135
# Epoch 13/50: Train Loss=0.0184, Train Acc=0.9959, Val Acc=0.9938, Val Loss=0.0322
# Epoch 14/50: Train Loss=0.0210, Train Acc=0.9959, Val Acc=0.9938, Val Loss=0.0238
# Epoch 15/50: Train Loss=0.0057, Train Acc=0.9979, Val Acc=0.9938, Val Loss=0.0110
# Epoch 16/50: Train Loss=0.0098, Train Acc=0.9969, Val Acc=0.9938, Val Loss=0.0218
# Epoch 17/50: Train Loss=0.0069, Train Acc=0.9990, Val Acc=0.9938, Val Loss=0.0214
# Epoch 18/50: Train Loss=0.0027, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0038
# Saved best model (val_acc=1.0000, val_loss=0.0038) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 19/50: Train Loss=0.0024, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0142
# Epoch 20/50: Train Loss=0.0066, Train Acc=0.9979, Val Acc=0.9938, Val Loss=0.0369
# Epoch 21/50: Train Loss=0.0091, Train Acc=0.9979, Val Acc=0.9938, Val Loss=0.0380
# Epoch 22/50: Train Loss=0.0036, Train Acc=0.9990, Val Acc=0.9938, Val Loss=0.0064
# Epoch 23/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0010
# Saved best model (val_acc=1.0000, val_loss=0.0010) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 24/50: Train Loss=0.0011, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0013
# Epoch 25/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=0.9938, Val Loss=0.0284
# Epoch 26/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0012
# Epoch 27/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0008
# Saved best model (val_acc=1.0000, val_loss=0.0008) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 28/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Saved best model (val_acc=1.0000, val_loss=0.0004) to: ./saved_models/best_detector_512x512_fgsm.pth
# Epoch 29/50: Train Loss=0.0018, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0033
# Epoch 30/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0005
# Epoch 31/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0009
# Epoch 32/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0008
# Epoch 33/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0018
# Epoch 34/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 35/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0028
# Epoch 36/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0016
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0011
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0020
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0020
# Epoch 40/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0015
# Epoch 41/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0005
# Epoch 42/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0008
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0011
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0008
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0016
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0022
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0009
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0006
# Epoch 50/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0010
# Done.
#
# Model Training - 512x512 - bim
#
# Epoch 1/50: Train Loss=0.1348, Train Acc=0.9702, Val Acc=0.5000, Val Loss=3.9457
# Saved best model (val_acc=0.5000, val_loss=3.9457) to: ./saved_models/best_detector_512x512_bim.pth
# Epoch 2/50: Train Loss=0.0244, Train Acc=0.9918, Val Acc=0.5000, Val Loss=2.6179
# Saved best model (val_acc=0.5000, val_loss=2.6179) to: ./saved_models/best_detector_512x512_bim.pth
# Epoch 3/50: Train Loss=0.0057, Train Acc=0.9990, Val Acc=0.5000, Val Loss=3.9312
# Epoch 4/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_512x512_bim.pth
# Epoch 5/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 6/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_bim.pth
# Epoch 7/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_bim.pth
# Epoch 8/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0021, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_bim.pth
# Epoch 10/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0180, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0001
# Epoch 12/50: Train Loss=0.0017, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0007
# Epoch 13/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 14/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 15/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 17/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0042, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 20/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 22/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 23/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 25/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 26/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 28/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 512x512 - pgd
#
# Epoch 1/50: Train Loss=0.0501, Train Acc=0.9774, Val Acc=0.5000, Val Loss=7.4074
# Saved best model (val_acc=0.5000, val_loss=7.4074) to: ./saved_models/best_detector_512x512_pgd.pth
# Epoch 2/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=0.5000, Val Loss=5.8044
# Saved best model (val_acc=0.5000, val_loss=5.8044) to: ./saved_models/best_detector_512x512_pgd.pth
# Epoch 3/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=0.5000, Val Loss=5.4946
# Saved best model (val_acc=0.5000, val_loss=5.4946) to: ./saved_models/best_detector_512x512_pgd.pth
# Epoch 4/50: Train Loss=0.0013, Train Acc=0.9990, Val Acc=0.5000, Val Loss=3.3897
# Saved best model (val_acc=0.5000, val_loss=3.3897) to: ./saved_models/best_detector_512x512_pgd.pth
# Epoch 5/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_pgd.pth
# Epoch 6/50: Train Loss=0.0056, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 7/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 8/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 10/50: Train Loss=0.0020, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_pgd.pth
# Epoch 11/50: Train Loss=0.0064, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0023
# Epoch 12/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0030, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 512x512 - df
#
# Epoch 1/50: Train Loss=0.0836, Train Acc=0.9630, Val Acc=0.5000, Val Loss=3.3678
# Saved best model (val_acc=0.5000, val_loss=3.3678) to: ./saved_models/best_detector_512x512_df.pth
# Epoch 2/50: Train Loss=0.0590, Train Acc=0.9794, Val Acc=0.5000, Val Loss=2.8662
# Saved best model (val_acc=0.5000, val_loss=2.8662) to: ./saved_models/best_detector_512x512_df.pth
# Epoch 3/50: Train Loss=0.0116, Train Acc=0.9959, Val Acc=0.5000, Val Loss=4.7644
# Epoch 4/50: Train Loss=0.0202, Train Acc=0.9907, Val Acc=1.0000, Val Loss=0.0004
# Saved best model (val_acc=1.0000, val_loss=0.0004) to: ./saved_models/best_detector_512x512_df.pth
# Epoch 5/50: Train Loss=0.0021, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_df.pth
# Epoch 6/50: Train Loss=0.0032, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 7/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 8/50: Train Loss=0.0064, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Epoch 9/50: Train Loss=0.0035, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 10/50: Train Loss=0.0183, Train Acc=0.9928, Val Acc=1.0000, Val Loss=0.0007
# Epoch 11/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 12/50: Train Loss=0.0024, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_df.pth
# Epoch 13/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 14/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0009, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_df.pth
# Epoch 18/50: Train Loss=0.0110, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 20/50: Train Loss=0.0012, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 21/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 22/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 25/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 30/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 31/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 32/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 33/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 34/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 35/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 41/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 42/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 45/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 46/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Done.
#
# Model Training - 512x512 - cw
#
# Epoch 1/50: Train Loss=0.0769, Train Acc=0.9588, Val Acc=0.5000, Val Loss=5.3439
# Saved best model (val_acc=0.5000, val_loss=5.3439) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 2/50: Train Loss=0.0436, Train Acc=0.9918, Val Acc=0.5000, Val Loss=4.1626
# Saved best model (val_acc=0.5000, val_loss=4.1626) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 3/50: Train Loss=0.0147, Train Acc=0.9959, Val Acc=0.5000, Val Loss=6.1780
# Epoch 4/50: Train Loss=0.0186, Train Acc=0.9959, Val Acc=0.9815, Val Loss=0.0566
# Saved best model (val_acc=0.9815, val_loss=0.0566) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 5/50: Train Loss=0.0203, Train Acc=0.9959, Val Acc=0.9938, Val Loss=0.0136
# Saved best model (val_acc=0.9938, val_loss=0.0136) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 6/50: Train Loss=0.0163, Train Acc=0.9959, Val Acc=0.9938, Val Loss=0.0146
# Epoch 7/50: Train Loss=0.0051, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 8/50: Train Loss=0.0056, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0004
# Epoch 9/50: Train Loss=0.0229, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0009
# Epoch 10/50: Train Loss=0.0663, Train Acc=0.9815, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 11/50: Train Loss=0.0159, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0012
# Epoch 12/50: Train Loss=0.0016, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 13/50: Train Loss=0.0131, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0009
# Epoch 14/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 15/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 17/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 18/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 19/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 20/50: Train Loss=0.0068, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 21/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 22/50: Train Loss=0.0012, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 23/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 24/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 25/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0063, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 28/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 29/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 30/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0030, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Epoch 35/50: Train Loss=0.0023, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 36/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 37/50: Train Loss=0.0013, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 39/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 40/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_512x512_cw.pth
# Epoch 43/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 46/50: Train Loss=0.0003, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 49/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.

# %%
img_size = 1024
attack_methods = ['fgsm','bim','pgd','df','cw']
for attack_method in attack_methods:
    print(f'Model Training - {img_size}x{img_size} - {attack_method} \n ')
    train_detector(csv_file='/kaggle/input/splits/common_success_detect_split.csv',
                   clean_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/clean',
                   adv_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/{attack_method}',
                   batch_size=32,
                   num_epochs=50,
                   lr=1e-3,
                   device='cuda',
                   model_save_path=f'./saved_models/best_detector_{img_size}x{img_size}_{attack_method}.pth',
                   save_best_only=True)
    print('Done. \n')
# Out:
# Model Training - 1024x1024 - fgsm
#
# Epoch 1/50: Train Loss=0.1422, Train Acc=0.9547, Val Acc=0.5000, Val Loss=3.1972
# Saved best model (val_acc=0.5000, val_loss=3.1972) to: ./saved_models/best_detector_1024x1024_fgsm.pth
# Epoch 2/50: Train Loss=0.0280, Train Acc=0.9938, Val Acc=0.5000, Val Loss=2.6128
# Saved best model (val_acc=0.5000, val_loss=2.6128) to: ./saved_models/best_detector_1024x1024_fgsm.pth
# Epoch 3/50: Train Loss=0.0267, Train Acc=0.9938, Val Acc=0.5000, Val Loss=2.7896
# Epoch 4/50: Train Loss=0.0252, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0056
# Saved best model (val_acc=1.0000, val_loss=0.0056) to: ./saved_models/best_detector_1024x1024_fgsm.pth
# Epoch 5/50: Train Loss=0.0216, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0009
# Saved best model (val_acc=1.0000, val_loss=0.0009) to: ./saved_models/best_detector_1024x1024_fgsm.pth
# Epoch 6/50: Train Loss=0.0507, Train Acc=0.9877, Val Acc=1.0000, Val Loss=0.0025
# Epoch 7/50: Train Loss=0.0219, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0002
# Saved best model (val_acc=1.0000, val_loss=0.0002) to: ./saved_models/best_detector_1024x1024_fgsm.pth
# Epoch 8/50: Train Loss=0.0193, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0016
# Epoch 9/50: Train Loss=0.0233, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0005
# Epoch 10/50: Train Loss=0.0198, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0042
# Epoch 11/50: Train Loss=0.0165, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0019
# Epoch 12/50: Train Loss=0.0159, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0011
# Epoch 13/50: Train Loss=0.0170, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0025
# Epoch 14/50: Train Loss=0.0145, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0018
# Epoch 15/50: Train Loss=0.0147, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0014
# Epoch 16/50: Train Loss=0.0167, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0018
# Epoch 17/50: Train Loss=0.0155, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0022
# Epoch 18/50: Train Loss=0.0169, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0032
# Epoch 19/50: Train Loss=0.0162, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0030
# Epoch 20/50: Train Loss=0.0156, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0020
# Epoch 21/50: Train Loss=0.0176, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0038
# Epoch 22/50: Train Loss=0.0253, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0035
# Epoch 23/50: Train Loss=0.0168, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0040
# Epoch 24/50: Train Loss=0.0191, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0021
# Epoch 25/50: Train Loss=0.0152, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0020
# Epoch 26/50: Train Loss=0.0163, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0020
# Epoch 27/50: Train Loss=0.0163, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0020
# Epoch 28/50: Train Loss=0.0153, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0020
# Epoch 29/50: Train Loss=0.0146, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0022
# Epoch 30/50: Train Loss=0.0166, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0020
# Epoch 31/50: Train Loss=0.0144, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0019
# Epoch 32/50: Train Loss=0.0153, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0023
# Epoch 33/50: Train Loss=0.0144, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0020
# Epoch 34/50: Train Loss=0.0166, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0019
# Epoch 35/50: Train Loss=0.0170, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0023
# Epoch 36/50: Train Loss=0.0156, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0017
# Epoch 37/50: Train Loss=0.0139, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0021
# Epoch 38/50: Train Loss=0.0170, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0022
# Epoch 39/50: Train Loss=0.0129, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0017
# Epoch 40/50: Train Loss=0.0145, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0022
# Epoch 41/50: Train Loss=0.0141, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0022
# Epoch 42/50: Train Loss=0.0134, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0021
# Epoch 43/50: Train Loss=0.0132, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0022
# Epoch 44/50: Train Loss=0.0135, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0021
# Epoch 45/50: Train Loss=0.0139, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0019
# Epoch 46/50: Train Loss=0.0119, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0022
# Epoch 47/50: Train Loss=0.0146, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0023
# Epoch 48/50: Train Loss=0.0127, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0016
# Epoch 49/50: Train Loss=0.0133, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0025
# Epoch 50/50: Train Loss=0.0137, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0019
# Done.
#
# Model Training - 1024x1024 - bim
#
# Epoch 1/50: Train Loss=0.0515, Train Acc=0.9753, Val Acc=0.5000, Val Loss=15.2154
# Saved best model (val_acc=0.5000, val_loss=15.2154) to: ./saved_models/best_detector_1024x1024_bim.pth
# Epoch 2/50: Train Loss=0.0010, Train Acc=0.9990, Val Acc=0.5000, Val Loss=10.7771
# Saved best model (val_acc=0.5000, val_loss=10.7771) to: ./saved_models/best_detector_1024x1024_bim.pth
# Epoch 3/50: Train Loss=0.0127, Train Acc=0.9969, Val Acc=0.5000, Val Loss=6.2783
# Saved best model (val_acc=0.5000, val_loss=6.2783) to: ./saved_models/best_detector_1024x1024_bim.pth
# Epoch 4/50: Train Loss=0.0172, Train Acc=0.9918, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_bim.pth
# Epoch 5/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 6/50: Train Loss=0.0014, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0038
# Epoch 7/50: Train Loss=0.0010, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 8/50: Train Loss=0.0146, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Epoch 9/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 10/50: Train Loss=0.0016, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 11/50: Train Loss=0.0125, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0002
# Epoch 12/50: Train Loss=0.0045, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0101
# Epoch 13/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 14/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0295, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 1024x1024 - pgd
#
# Epoch 1/50: Train Loss=0.0236, Train Acc=0.9846, Val Acc=0.5000, Val Loss=4.8180
# Saved best model (val_acc=0.5000, val_loss=4.8180) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 2/50: Train Loss=0.0643, Train Acc=0.9928, Val Acc=0.5000, Val Loss=781.1972
# Epoch 3/50: Train Loss=0.0278, Train Acc=0.9928, Val Acc=0.5000, Val Loss=8.4240
# Epoch 4/50: Train Loss=0.0099, Train Acc=0.9979, Val Acc=0.9938, Val Loss=0.0079
# Saved best model (val_acc=0.9938, val_loss=0.0079) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 5/50: Train Loss=0.0027, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 6/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 7/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 8/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 9/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 10/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 13/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 15/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 16/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_pgd.pth
# Epoch 20/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 21/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0009, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0020, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0026, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 1024x1024 - df
#
# Epoch 1/50: Train Loss=0.0947, Train Acc=0.9588, Val Acc=0.5000, Val Loss=3.6543
# Saved best model (val_acc=0.5000, val_loss=3.6543) to: ./saved_models/best_detector_1024x1024_df.pth
# Epoch 2/50: Train Loss=0.0042, Train Acc=1.0000, Val Acc=0.5000, Val Loss=4.1354
# Epoch 3/50: Train Loss=0.0730, Train Acc=0.9877, Val Acc=0.5000, Val Loss=3.7401
# Epoch 4/50: Train Loss=0.0142, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0006
# Saved best model (val_acc=1.0000, val_loss=0.0006) to: ./saved_models/best_detector_1024x1024_df.pth
# Epoch 5/50: Train Loss=0.0035, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_df.pth
# Epoch 6/50: Train Loss=0.0011, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 7/50: Train Loss=0.0031, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_df.pth
# Epoch 8/50: Train Loss=0.0030, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0035
# Epoch 9/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 10/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 11/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 12/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 13/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 14/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 15/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 16/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 17/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_df.pth
# Epoch 18/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 19/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 20/50: Train Loss=0.0010, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Saved best model (val_acc=1.0000, val_loss=0.0000) to: ./saved_models/best_detector_1024x1024_df.pth
# Epoch 21/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 22/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 23/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 24/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 25/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 26/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 27/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 28/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 29/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 30/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 31/50: Train Loss=0.0017, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 32/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 33/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 34/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 35/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 36/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 37/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 38/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 39/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 40/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 41/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 42/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 43/50: Train Loss=0.0000, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 44/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 45/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 46/50: Train Loss=0.0017, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0000
# Epoch 47/50: Train Loss=0.0002, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 48/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 49/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Epoch 50/50: Train Loss=0.0001, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0000
# Done.
#
# Model Training - 1024x1024 - cw
#
# Epoch 1/50: Train Loss=0.1119, Train Acc=0.9702, Val Acc=0.5000, Val Loss=2.5710
# Saved best model (val_acc=0.5000, val_loss=2.5710) to: ./saved_models/best_detector_1024x1024_cw.pth
# Epoch 2/50: Train Loss=0.0275, Train Acc=0.9938, Val Acc=0.5000, Val Loss=3.3493
# Epoch 3/50: Train Loss=0.0191, Train Acc=0.9928, Val Acc=0.5000, Val Loss=2.8914
# Epoch 4/50: Train Loss=0.0517, Train Acc=0.9907, Val Acc=0.9938, Val Loss=0.0358
# Saved best model (val_acc=0.9938, val_loss=0.0358) to: ./saved_models/best_detector_1024x1024_cw.pth
# Epoch 5/50: Train Loss=0.0233, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_1024x1024_cw.pth
# Epoch 6/50: Train Loss=0.0292, Train Acc=0.9928, Val Acc=1.0000, Val Loss=0.0065
# Epoch 7/50: Train Loss=0.0367, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0008
# Epoch 8/50: Train Loss=0.0450, Train Acc=0.9897, Val Acc=1.0000, Val Loss=0.0006
# Epoch 9/50: Train Loss=0.0139, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_1024x1024_cw.pth
# Epoch 10/50: Train Loss=0.0179, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0007
# Epoch 11/50: Train Loss=0.0153, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0045
# Epoch 12/50: Train Loss=0.0138, Train Acc=0.9969, Val Acc=1.0000, Val Loss=0.0001
# Epoch 13/50: Train Loss=0.0079, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0005
# Epoch 14/50: Train Loss=0.0070, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0003
# Epoch 15/50: Train Loss=0.0047, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0004
# Epoch 16/50: Train Loss=0.0164, Train Acc=0.9949, Val Acc=1.0000, Val Loss=0.0366
# Epoch 17/50: Train Loss=0.0135, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0002
# Epoch 18/50: Train Loss=0.0103, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0007
# Epoch 19/50: Train Loss=0.0055, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0004
# Epoch 20/50: Train Loss=0.0108, Train Acc=0.9959, Val Acc=1.0000, Val Loss=0.0018
# Epoch 21/50: Train Loss=0.0084, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0006
# Epoch 22/50: Train Loss=0.0039, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 23/50: Train Loss=0.0091, Train Acc=0.9979, Val Acc=1.0000, Val Loss=0.0024
# Epoch 24/50: Train Loss=0.0033, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0011
# Epoch 25/50: Train Loss=0.0033, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0004
# Epoch 26/50: Train Loss=0.0023, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 27/50: Train Loss=0.0024, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0003
# Epoch 28/50: Train Loss=0.0015, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 29/50: Train Loss=0.0029, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0006
# Epoch 30/50: Train Loss=0.0013, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 31/50: Train Loss=0.0011, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 32/50: Train Loss=0.0019, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0004
# Epoch 33/50: Train Loss=0.0010, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Epoch 34/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 35/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 36/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 37/50: Train Loss=0.0009, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 38/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0009
# Epoch 39/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0003
# Epoch 40/50: Train Loss=0.0007, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 41/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 42/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 43/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 44/50: Train Loss=0.0024, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0001
# Saved best model (val_acc=1.0000, val_loss=0.0001) to: ./saved_models/best_detector_1024x1024_cw.pth
# Epoch 45/50: Train Loss=0.0005, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0001
# Epoch 46/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 47/50: Train Loss=0.0008, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 48/50: Train Loss=0.0006, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0002
# Epoch 49/50: Train Loss=0.0022, Train Acc=0.9990, Val Acc=1.0000, Val Loss=0.0002
# Epoch 50/50: Train Loss=0.0004, Train Acc=1.0000, Val Acc=1.0000, Val Loss=0.0004
# Done.

# %%
import os
import zipfile
import hashlib

# Define paths
folder_path = '/kaggle/working/saved_models'
zip_path = '/kaggle/working/saved_models.zip'
hash_path = '/kaggle/working/saved_models.sha256'

if os.path.exists(folder_path):
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                # Keep relative structure inside the zip
                arcname = os.path.relpath(file_path, start=folder_path)
                zipf.write(file_path, arcname)
    print(f"Zipped all contents to {zip_path}")
else:
    raise FileNotFoundError(f"Folder not found: {folder_path}")

def sha256sum(filename, block_size=65536):
    h = hashlib.sha256()
    with open(filename, 'rb') as f:
        for block in iter(lambda: f.read(block_size), b''):
            h.update(block)
    return h.hexdigest()

hash_value = sha256sum(zip_path)

with open(hash_path, 'w') as f:
    f.write(f"{hash_value}  {os.path.basename(zip_path)}\n")

print(f"SHA256 hash saved to {hash_path}")
print(f"Hash: {hash_value}")
# Out:
# Zipped all contents to /kaggle/working/saved_models.zip
# SHA256 hash saved to /kaggle/working/saved_models.sha256
# Hash: b1711da841aa5a328cd5cb23819b407604bc3f0e66589ee191da4909d9b86f18

# %%
# --- Add these imports at the top of your script ---
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import os
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, 
    roc_auc_score, 
    roc_curve, 
    precision_recall_fscore_support
)
from pathlib import Path
# --- Make sure your other imports (like ResidualDataset, load_model_state) are also present ---
# from your_dataset_module import ResidualDataset
# from your_model_utils import load_model_state
# --------------------------------------------------


def evaluate_test(model=None, csv_file=None,
                  clean_base='../03-ExtractCharacteristics/jpg_residual-clean/256x256/',
                  adv_base='../03-ExtractCharacteristics/jpg_residual/256x256/cw/',
                  batch_size=16,
                  device='cuda',
                  model_path=None,
                  roc_path='./results/roc_test.png',
                  output_csv_path=None,  
                  return_predictions=False 
                 ):
    assert csv_file is not None, "csv_file must be provided"

    if model is None and model_path is not None:
        model = load_model_state(model_path, device=device)
    assert model is not None, "Either a model or model_path must be provided"

    test_ds = ResidualDataset(csv_file, clean_base, adv_base, split='test')
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    model.eval()
    all_preds = []
    all_labels = []
    all_probs = []  
    
    softmax = nn.Softmax(dim=1)
    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs = imgs.to(device)
            labels = labels.to(device)
            outputs = model(imgs)
            probs = softmax(outputs)[:, 1] 
            preds = torch.argmax(outputs, dim=1)

            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_probs = np.array(all_probs)
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    acc = (all_preds == all_labels).mean() if all_labels.size > 0 else 0.0
    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1]) if all_labels.size > 0 else np.zeros((2,2),dtype=int)

    auc = None
    roc_data = None
    try:
        if len(np.unique(all_labels)) == 2:
            auc = roc_auc_score(all_labels, all_probs)
            fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
            roc_data = (fpr, tpr, thresholds)
            # plot ROC
            os.makedirs(os.path.dirname(roc_path), exist_ok=True)
            plt.figure()
            plt.plot(fpr, tpr)
            plt.plot([0,1], [0,1], linestyle='--')
            plt.xlabel('False Positive Rate')
            plt.ylabel('True Positive Rate')
            plt.title(f'ROC curve (AUC = {auc:.4f})')
            plt.grid(True)
            plt.savefig(roc_path)
            plt.close()
        else:
            auc = None
            roc_data = None
    except Exception as e:
        auc = None
        roc_data = None

    pr, rec, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='binary', zero_division=0)

    results = {
        'accuracy': float(acc),
        'total': int(all_labels.size),
        'confusion_matrix': cm,
        'auc': float(auc) if auc is not None else None,
        'roc_curve': roc_data,
        'precision_recall_f1': (float(pr), float(rec), float(f1)),
        'roc_path': roc_path if roc_data is not None else None,
    }

    # Print a compact summary
    print(f"Test Accuracy: {results['accuracy']:.4f} over {results['total']} samples")
    print('Confusion Matrix (rows=true, cols=pred):')
    print(results['confusion_matrix'])
    if results['auc'] is not None:
        print(f"AUC-ROC: {results['auc']:.4f} (ROC plot saved to: {results['roc_path']})")
    else:
        print('AUC-ROC: not available (need both classes present in test set)')
    prc = results['precision_recall_f1']
    print(f"Precision: {prc[0]:.4f}, Recall: {prc[1]:.4f}, F1: {prc[2]:.4f}")

    # --- Save results to CSV (Added block) ---
    if output_csv_path is not None:
        csv_path = Path(output_csv_path)
        csv_path.parent.mkdir(parents=True, exist_ok=True)

        # Prepare metrics for CSV
        pr, rec, f1 = results['precision_recall_f1']
        cm_to_save = results['confusion_matrix']
        
        # Handle case where cm might be empty if all_labels.size == 0
        if cm_to_save.size == 4:
            # Ensure native int types for csv
            tn, fp, fn, tp = map(int, cm_to_save.ravel()) 
        else:
            tn, fp, fn, tp = 0, 0, 0, 0

        metrics_to_save = {
            'accuracy': results['accuracy'],
            'precision': pr,
            'recall': rec,
            'f1': f1,
            'auc': results['auc'],
            'total_samples': results['total'],
            'tn': tn,
            'fp': fp,
            'fn': fn,
            'tp': tp,
            'roc_path': results['roc_path']
        }
        
        metrics_df = pd.DataFrame([metrics_to_save])
        metrics_df.to_csv(csv_path, index=False)
        print(f"Metrics saved to: {csv_path}")

        if return_predictions:
            preds_path = csv_path.with_name(csv_path.stem + "_predictions.csv")
            preds_df = pd.DataFrame({
                "y_true": all_labels,
                "y_pred": all_preds,
                "y_score_class1": all_probs # Using a more specific name
            })
            preds_df.to_csv(preds_path, index=False)
            print(f"Predictions saved to: {preds_path}")

    return None

# %%
attack_methods = ['fgsm', 'bim', 'pgd', 'df', 'cw']
datasets = ['fgsm', 'bim', 'pgd', 'df', 'cw']
img_sizes = [32, 64, 128, 256, 512, 1024]
classifier = 'adam'

for img_size in img_sizes:
    print (f'Image Size: {img_size}\n')
    for dataset in datasets:
        print (f'Dataset: {dataset}\n')
        for attack_method in attack_methods:
            print (f'Attack Method: {attack_method}\n')
            evaluate_test(model=None,
                          csv_file='/kaggle/input/splits/common_success_detect_split.csv',
                          clean_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/clean',
                          adv_base=f'/kaggle/input/jpg-residual-100/jpg_residual-100/{img_size}x{img_size}/{dataset}',
                          batch_size=32,
                          device='cuda',
                          model_path=f'./saved_models/best_detector_{img_size}x{img_size}_{attack_method}.pth',
                          roc_path=f'./eval-TEST/{attack_method}-{dataset}-{img_size}-{classifier}_ROC.png',
                          output_csv_path=f'./eval-TEST/{attack_method}-{dataset}-{img_size}-{classifier}_test_result.csv',
                          return_predictions=False)
            print('------------------------------\n')
        print ('++++++++++++++++++++++++++++++++\n')
    print ('=================================\n')
# Out:
# Image Size: 32
#
# Dataset: fgsm
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-fgsm-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-fgsm-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-fgsm-32-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/bim-fgsm-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-fgsm-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-fgsm-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-fgsm-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-fgsm-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-fgsm-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-fgsm-32-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: bim
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-bim-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-bim-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-bim-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-bim-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-bim-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-bim-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-bim-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-bim-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-bim-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-bim-32-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: pgd
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-pgd-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-pgd-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-pgd-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-pgd-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-pgd-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-pgd-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-pgd-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-pgd-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-pgd-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-pgd-32-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: df
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-df-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-df-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-df-32-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/bim-df-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-df-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-df-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-df-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-df-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-df-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-df-32-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: cw
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-cw-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-cw-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-cw-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-cw-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-cw-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-cw-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-cw-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-cw-32-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-cw-32-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-cw-32-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# =================================
#
# Image Size: 64
#
# Dataset: fgsm
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-fgsm-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-fgsm-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-fgsm-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-fgsm-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-fgsm-64-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/pgd-fgsm-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-fgsm-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-fgsm-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-fgsm-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-fgsm-64-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: bim
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-bim-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-bim-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-bim-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-bim-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-bim-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-bim-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-bim-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-bim-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-bim-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-bim-64-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: pgd
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-pgd-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-pgd-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-pgd-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-pgd-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-pgd-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-pgd-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-pgd-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-pgd-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-pgd-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-pgd-64-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: df
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-df-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-df-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9634 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 6 76]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-df-64-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9268, F1: 0.9620
# Metrics saved to: eval-TEST/bim-df-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-df-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-df-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-df-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-df-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-df-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-df-64-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: cw
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-cw-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-cw-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9573 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 7 75]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-cw-64-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9146, F1: 0.9554
# Metrics saved to: eval-TEST/bim-cw-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9756 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 4 78]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-cw-64-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9512, F1: 0.9750
# Metrics saved to: eval-TEST/pgd-cw-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-cw-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-cw-64-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-cw-64-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-cw-64-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# =================================
#
# Image Size: 128
#
# Dataset: fgsm
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-fgsm-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-fgsm-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9878 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 2 80]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-fgsm-128-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9756, F1: 0.9877
# Metrics saved to: eval-TEST/bim-fgsm-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9878 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 2 80]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-fgsm-128-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9756, F1: 0.9877
# Metrics saved to: eval-TEST/pgd-fgsm-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-fgsm-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-fgsm-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-fgsm-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-fgsm-128-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: bim
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-bim-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-bim-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-bim-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-bim-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-bim-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-bim-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-bim-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-bim-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-bim-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-bim-128-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: pgd
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-pgd-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-pgd-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-pgd-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-pgd-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-pgd-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-pgd-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-pgd-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-pgd-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-pgd-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-pgd-128-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: df
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-df-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-df-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9329 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [11 71]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-df-128-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8659, F1: 0.9281
# Metrics saved to: eval-TEST/bim-df-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9085 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [15 67]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-df-128-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8171, F1: 0.8993
# Metrics saved to: eval-TEST/pgd-df-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-df-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-df-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-df-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-df-128-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: cw
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-cw-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-cw-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9390 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [10 72]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-cw-128-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8780, F1: 0.9351
# Metrics saved to: eval-TEST/bim-cw-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9024 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [16 66]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-cw-128-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8049, F1: 0.8919
# Metrics saved to: eval-TEST/pgd-cw-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-cw-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-cw-128-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-cw-128-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-cw-128-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# =================================
#
# Image Size: 256
#
# Dataset: fgsm
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-fgsm-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-fgsm-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-fgsm-256-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/bim-fgsm-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9573 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 7 75]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-fgsm-256-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9146, F1: 0.9554
# Metrics saved to: eval-TEST/pgd-fgsm-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-fgsm-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-fgsm-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-fgsm-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-fgsm-256-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: bim
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-bim-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-bim-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-bim-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-bim-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-bim-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-bim-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-bim-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-bim-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-bim-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-bim-256-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: pgd
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-pgd-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-pgd-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-pgd-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-pgd-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-pgd-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-pgd-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-pgd-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-pgd-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-pgd-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-pgd-256-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: df
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-df-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-df-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9268 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [12 70]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-df-256-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8537, F1: 0.9211
# Metrics saved to: eval-TEST/bim-df-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.7805 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [36 46]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-df-256-adam_ROC.png)
# Precision: 1.0000, Recall: 0.5610, F1: 0.7188
# Metrics saved to: eval-TEST/pgd-df-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-df-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-df-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-df-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-df-256-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: cw
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-cw-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-cw-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9512 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 8 74]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-cw-256-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9024, F1: 0.9487
# Metrics saved to: eval-TEST/bim-cw-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.8171 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [30 52]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-cw-256-adam_ROC.png)
# Precision: 1.0000, Recall: 0.6341, F1: 0.7761
# Metrics saved to: eval-TEST/pgd-cw-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-cw-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-cw-256-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-cw-256-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-cw-256-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# =================================
#
# Image Size: 512
#
# Dataset: fgsm
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-fgsm-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-fgsm-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9817 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 3 79]]
# AUC-ROC: 0.9994 (ROC plot saved to: ./eval-TEST/bim-fgsm-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9634, F1: 0.9814
# Metrics saved to: eval-TEST/bim-fgsm-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9878 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 2 80]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-fgsm-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9756, F1: 0.9877
# Metrics saved to: eval-TEST/pgd-fgsm-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 0.9878 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 2 80]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-fgsm-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9756, F1: 0.9877
# Metrics saved to: eval-TEST/df-fgsm-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 0.9878 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 2 80]]
# AUC-ROC: 0.9999 (ROC plot saved to: ./eval-TEST/cw-fgsm-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9756, F1: 0.9877
# Metrics saved to: eval-TEST/cw-fgsm-512-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: bim
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-bim-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-bim-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-bim-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-bim-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-bim-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-bim-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-bim-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-bim-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-bim-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-bim-512-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: pgd
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-pgd-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-pgd-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-pgd-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-pgd-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-pgd-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-pgd-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-pgd-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-pgd-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-pgd-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-pgd-512-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: df
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-df-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-df-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9634 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 6 76]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-df-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9268, F1: 0.9620
# Metrics saved to: eval-TEST/bim-df-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9268 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [12 70]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-df-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8537, F1: 0.9211
# Metrics saved to: eval-TEST/pgd-df-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-df-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-df-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-df-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-df-512-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: cw
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-cw-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-cw-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9817 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 3 79]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-cw-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9634, F1: 0.9814
# Metrics saved to: eval-TEST/bim-cw-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9573 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 7 75]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-cw-512-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9146, F1: 0.9554
# Metrics saved to: eval-TEST/pgd-cw-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-cw-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-cw-512-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-cw-512-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-cw-512-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# =================================
#
# Image Size: 1024
#
# Dataset: fgsm
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-fgsm-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-fgsm-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-fgsm-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-fgsm-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-fgsm-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-fgsm-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-fgsm-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-fgsm-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-fgsm-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-fgsm-1024-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: bim
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-bim-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-bim-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-bim-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-bim-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-bim-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-bim-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-bim-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-bim-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-bim-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-bim-1024-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: pgd
#
# Attack Method: fgsm
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/fgsm-pgd-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/fgsm-pgd-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/bim-pgd-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/bim-pgd-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-pgd-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/pgd-pgd-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-pgd-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/df-pgd-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-pgd-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-pgd-1024-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: df
#
# Attack Method: fgsm
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 0.9999 (ROC plot saved to: ./eval-TEST/fgsm-df-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/fgsm-df-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.8963 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [17 65]]
# AUC-ROC: 0.9964 (ROC plot saved to: ./eval-TEST/bim-df-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.7927, F1: 0.8844
# Metrics saved to: eval-TEST/bim-df-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9329 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [11 71]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/pgd-df-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8659, F1: 0.9281
# Metrics saved to: eval-TEST/pgd-df-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/df-df-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/df-df-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 1.0000 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 0 82]]
# AUC-ROC: 1.0000 (ROC plot saved to: ./eval-TEST/cw-df-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Metrics saved to: eval-TEST/cw-df-1024-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# Dataset: cw
#
# Attack Method: fgsm
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 0.9924 (ROC plot saved to: ./eval-TEST/fgsm-cw-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/fgsm-cw-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: bim
#
# Test Accuracy: 0.9329 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [11 71]]
# AUC-ROC: 0.9948 (ROC plot saved to: ./eval-TEST/bim-cw-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.8659, F1: 0.9281
# Metrics saved to: eval-TEST/bim-cw-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: pgd
#
# Test Accuracy: 0.9756 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 4 78]]
# AUC-ROC: 0.9951 (ROC plot saved to: ./eval-TEST/pgd-cw-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9512, F1: 0.9750
# Metrics saved to: eval-TEST/pgd-cw-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: df
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 0.9943 (ROC plot saved to: ./eval-TEST/df-cw-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/df-cw-1024-adam_test_result.csv
# ------------------------------
#
# Attack Method: cw
#
# Test Accuracy: 0.9939 over 164 samples
# Confusion Matrix (rows=true, cols=pred):
# [[82  0]
#  [ 1 81]]
# AUC-ROC: 0.9999 (ROC plot saved to: ./eval-TEST/cw-cw-1024-adam_ROC.png)
# Precision: 1.0000, Recall: 0.9878, F1: 0.9939
# Metrics saved to: eval-TEST/cw-cw-1024-adam_test_result.csv
# ------------------------------
#
# ++++++++++++++++++++++++++++++++
#
# =================================

# %%
import hashlib
import os
from pathlib import Path
import zipfile
from datetime import datetime

# -------------------------------
# Config
# -------------------------------
input_dir = Path("/kaggle/working/eval-TEST")
output_zip = Path("/kaggle/working/evals-TEST.zip")
manifest_path = Path("/kaggle/working/manifest-evals-TEST-sha256.txt")
chunk_size = 8 * 1024 * 1024  # 8 MB
skip_files = {output_zip.name, manifest_path.name}

# -------------------------------
# Helper: compute SHA256
# -------------------------------
def sha256_of_file(path: Path) -> str:
    h = hashlib.sha256()
    with path.open("rb") as f:
        while True:
            chunk = f.read(chunk_size)
            if not chunk:
                break
            h.update(chunk)
    return h.hexdigest()

# -------------------------------
# Collect files to zip
# -------------------------------
files_to_add = []
for root, dirs, files in os.walk(input_dir):
    for fname in files:
        full = Path(root) / fname
        rel = full.relative_to(input_dir)
        rel_str = str(rel).replace(os.sep, "/")
        if rel.name in skip_files:
            continue
        files_to_add.append((full, rel))

if not files_to_add:
    print(f"No files found in {input_dir} to archive.")
else:
    # -------------------------------
    # Create zip
    # -------------------------------
    print(f"Creating zip: {output_zip}")
    with zipfile.ZipFile(output_zip, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for full, rel in files_to_add:
            arcname = str(rel).replace(os.sep, "/")
            print(f"  adding: {arcname}")
            zf.write(full, arcname=arcname)

    # -------------------------------
    # Create manifest
    # -------------------------------
    print(f"Computing per-file SHA-256 and writing manifest: {manifest_path}")
    with manifest_path.open("w", encoding="utf-8") as mf:
        mf.write(f"# manifest generated: {datetime.utcnow().isoformat()}Z\n")
        mf.write(f"# input_dir: {input_dir}\n")
        mf.write("# format: <sha256>  <relative/path>\n")
        for full, rel in files_to_add:
            rel_unix = str(rel).replace(os.sep, "/")
            h = sha256_of_file(full)
            size = full.stat().st_size
            mf.write(f"{h}  {rel_unix}  # {size} bytes\n")

    # -------------------------------
    # Compute zip SHA256
    # -------------------------------
    zip_hash = sha256_of_file(output_zip)
    ziphash_path = output_zip.with_suffix(output_zip.suffix + ".sha256")
    with ziphash_path.open("w", encoding="utf-8") as zh:
        zh.write(f"{zip_hash}  {output_zip.name}\n")

    print("Done.")
    print(f"Created: {output_zip}")
    print(f"Created: {manifest_path}")
    print(f"Created: {ziphash_path}")
# Out:
# Creating zip: /kaggle/working/evals-TEST.zip
#   adding: df-df-1024-adam_test_result.csv
#   adding: fgsm-df-64-adam_ROC.png
#   adding: df-pgd-256-adam_test_result.csv
#   adding: pgd-bim-128-adam_ROC.png
#   adding: df-fgsm-256-adam_test_result.csv
#   adding: bim-df-32-adam_ROC.png
#   adding: cw-pgd-32-adam_test_result.csv
#   adding: fgsm-bim-64-adam_test_result.csv
#   adding: cw-pgd-256-adam_ROC.png
#   adding: fgsm-bim-512-adam_test_result.csv
#   adding: pgd-cw-1024-adam_test_result.csv
#   adding: pgd-bim-32-adam_test_result.csv
#   adding: pgd-fgsm-512-adam_test_result.csv
#   adding: pgd-bim-128-adam_test_result.csv
#   adding: cw-cw-512-adam_ROC.png
#   adding: df-bim-128-adam_ROC.png
#   adding: fgsm-bim-128-adam_ROC.png
#   adding: cw-bim-64-adam_ROC.png
#   adding: fgsm-fgsm-32-adam_test_result.csv
#   adding: bim-df-512-adam_test_result.csv
#   adding: fgsm-cw-256-adam_ROC.png
#   adding: cw-cw-32-adam_ROC.png
#   adding: pgd-pgd-512-adam_test_result.csv
#   adding: bim-df-512-adam_ROC.png
#   adding: fgsm-fgsm-32-adam_ROC.png
#   adding: df-cw-256-adam_test_result.csv
#   adding: bim-fgsm-64-adam_ROC.png
#   adding: pgd-df-64-adam_ROC.png
#   adding: cw-df-32-adam_ROC.png
#   adding: df-fgsm-64-adam_test_result.csv
#   adding: bim-cw-32-adam_test_result.csv
#   adding: cw-pgd-512-adam_test_result.csv
#   adding: fgsm-pgd-64-adam_ROC.png
#   adding: bim-cw-256-adam_test_result.csv
#   adding: fgsm-df-32-adam_ROC.png
#   adding: fgsm-df-1024-adam_ROC.png
#   adding: fgsm-bim-256-adam_ROC.png
#   adding: cw-df-128-adam_ROC.png
#   adding: fgsm-df-512-adam_ROC.png
#   adding: df-df-512-adam_test_result.csv
#   adding: df-pgd-1024-adam_test_result.csv
#   adding: cw-bim-128-adam_test_result.csv
#   adding: df-cw-128-adam_ROC.png
#   adding: fgsm-cw-1024-adam_ROC.png
#   adding: fgsm-cw-64-adam_test_result.csv
#   adding: df-pgd-512-adam_ROC.png
#   adding: pgd-cw-512-adam_test_result.csv
#   adding: cw-cw-512-adam_test_result.csv
#   adding: cw-cw-256-adam_test_result.csv
#   adding: bim-bim-128-adam_test_result.csv
#   adding: bim-df-1024-adam_ROC.png
#   adding: bim-fgsm-128-adam_test_result.csv
#   adding: fgsm-pgd-512-adam_ROC.png
#   adding: pgd-df-32-adam_test_result.csv
#   adding: cw-df-64-adam_test_result.csv
#   adding: cw-bim-32-adam_ROC.png
#   adding: bim-cw-512-adam_test_result.csv
#   adding: cw-bim-32-adam_test_result.csv
#   adding: cw-pgd-64-adam_test_result.csv
#   adding: fgsm-fgsm-128-adam_ROC.png
#   adding: pgd-bim-1024-adam_test_result.csv
#   adding: cw-cw-32-adam_test_result.csv
#   adding: cw-bim-512-adam_ROC.png
#   adding: df-fgsm-1024-adam_test_result.csv
#   adding: pgd-cw-64-adam_ROC.png
#   adding: fgsm-fgsm-64-adam_test_result.csv
#   adding: cw-pgd-64-adam_ROC.png
#   adding: pgd-cw-256-adam_test_result.csv
#   adding: df-fgsm-32-adam_ROC.png
#   adding: fgsm-df-256-adam_ROC.png
#   adding: bim-fgsm-1024-adam_test_result.csv
#   adding: cw-df-256-adam_test_result.csv
#   adding: bim-fgsm-32-adam_ROC.png
#   adding: bim-cw-256-adam_ROC.png
#   adding: pgd-cw-256-adam_ROC.png
#   adding: df-fgsm-128-adam_test_result.csv
#   adding: cw-cw-1024-adam_test_result.csv
#   adding: bim-fgsm-128-adam_ROC.png
#   adding: cw-bim-64-adam_test_result.csv
#   adding: pgd-fgsm-1024-adam_test_result.csv
#   adding: cw-fgsm-512-adam_ROC.png
#   adding: bim-df-1024-adam_test_result.csv
#   adding: fgsm-df-512-adam_test_result.csv
#   adding: cw-df-512-adam_test_result.csv
#   adding: df-df-256-adam_test_result.csv
#   adding: cw-fgsm-256-adam_ROC.png
#   adding: fgsm-cw-1024-adam_test_result.csv
#   adding: bim-bim-256-adam_ROC.png
#   adding: cw-bim-128-adam_ROC.png
#   adding: cw-pgd-32-adam_ROC.png
#   adding: fgsm-fgsm-1024-adam_test_result.csv
#   adding: fgsm-cw-128-adam_ROC.png
#   adding: pgd-bim-256-adam_ROC.png
#   adding: pgd-fgsm-256-adam_test_result.csv
#   adding: bim-cw-1024-adam_test_result.csv
#   adding: bim-bim-1024-adam_ROC.png
#   adding: fgsm-pgd-256-adam_ROC.png
#   adding: fgsm-df-256-adam_test_result.csv
#   adding: fgsm-cw-256-adam_test_result.csv
#   adding: pgd-bim-256-adam_test_result.csv
#   adding: pgd-pgd-256-adam_ROC.png
#   adding: df-bim-1024-adam_test_result.csv
#   adding: df-bim-64-adam_test_result.csv
#   adding: bim-df-256-adam_ROC.png
#   adding: pgd-fgsm-1024-adam_ROC.png
#   adding: fgsm-df-32-adam_test_result.csv
#   adding: fgsm-pgd-32-adam_test_result.csv
#   adding: fgsm-cw-128-adam_test_result.csv
#   adding: df-cw-1024-adam_test_result.csv
#   adding: pgd-bim-64-adam_test_result.csv
#   adding: df-pgd-1024-adam_ROC.png
#   adding: bim-pgd-256-adam_test_result.csv
#   adding: fgsm-pgd-64-adam_test_result.csv
#   adding: pgd-pgd-256-adam_test_result.csv
#   adding: fgsm-fgsm-64-adam_ROC.png
#   adding: pgd-bim-512-adam_test_result.csv
#   adding: cw-fgsm-1024-adam_test_result.csv
#   adding: df-fgsm-128-adam_ROC.png
#   adding: fgsm-bim-256-adam_test_result.csv
#   adding: pgd-cw-128-adam_ROC.png
#   adding: pgd-df-64-adam_test_result.csv
#   adding: bim-df-32-adam_test_result.csv
#   adding: df-fgsm-512-adam_test_result.csv
#   adding: pgd-df-256-adam_ROC.png
#   adding: fgsm-bim-1024-adam_ROC.png
#   adding: bim-bim-512-adam_test_result.csv
#   adding: bim-fgsm-64-adam_test_result.csv
#   adding: df-pgd-512-adam_test_result.csv
#   adding: df-df-256-adam_ROC.png
#   adding: df-pgd-64-adam_ROC.png
#   adding: bim-cw-64-adam_ROC.png
#   adding: fgsm-cw-512-adam_test_result.csv
#   adding: pgd-df-256-adam_test_result.csv
#   adding: fgsm-bim-32-adam_test_result.csv
#   adding: fgsm-pgd-512-adam_test_result.csv
#   adding: fgsm-cw-32-adam_test_result.csv
#   adding: df-fgsm-32-adam_test_result.csv
#   adding: cw-df-32-adam_test_result.csv
#   adding: bim-pgd-128-adam_ROC.png
#   adding: pgd-pgd-64-adam_test_result.csv
#   adding: bim-fgsm-32-adam_test_result.csv
#   adding: df-df-32-adam_ROC.png
#   adding: cw-df-128-adam_test_result.csv
#   adding: cw-bim-256-adam_ROC.png
#   adding: fgsm-df-128-adam_test_result.csv
#   adding: fgsm-bim-512-adam_ROC.png
#   adding: pgd-cw-1024-adam_ROC.png
#   adding: bim-cw-512-adam_ROC.png
#   adding: bim-bim-64-adam_test_result.csv
#   adding: fgsm-pgd-128-adam_ROC.png
#   adding: pgd-df-1024-adam_ROC.png
#   adding: bim-fgsm-1024-adam_ROC.png
#   adding: pgd-df-512-adam_test_result.csv
#   adding: pgd-cw-32-adam_ROC.png
#   adding: pgd-pgd-64-adam_ROC.png
#   adding: pgd-bim-512-adam_ROC.png
#   adding: bim-pgd-32-adam_ROC.png
#   adding: df-cw-1024-adam_ROC.png
#   adding: fgsm-fgsm-128-adam_test_result.csv
#   adding: cw-fgsm-256-adam_test_result.csv
#   adding: cw-pgd-128-adam_test_result.csv
#   adding: df-bim-256-adam_ROC.png
#   adding: fgsm-df-1024-adam_test_result.csv
#   adding: df-fgsm-1024-adam_ROC.png
#   adding: fgsm-bim-64-adam_ROC.png
#   adding: df-pgd-128-adam_ROC.png
#   adding: fgsm-pgd-1024-adam_ROC.png
#   adding: cw-fgsm-32-adam_ROC.png
#   adding: pgd-fgsm-32-adam_ROC.png
#   adding: fgsm-df-128-adam_ROC.png
#   adding: cw-cw-256-adam_ROC.png
#   adding: cw-fgsm-32-adam_test_result.csv
#   adding: bim-fgsm-256-adam_ROC.png
#   adding: df-bim-256-adam_test_result.csv
#   adding: fgsm-fgsm-512-adam_ROC.png
#   adding: df-df-64-adam_test_result.csv
#   adding: pgd-pgd-1024-adam_test_result.csv
#   adding: bim-bim-128-adam_ROC.png
#   adding: cw-fgsm-64-adam_ROC.png
#   adding: df-cw-64-adam_ROC.png
#   adding: bim-pgd-128-adam_test_result.csv
#   adding: df-cw-128-adam_test_result.csv
#   adding: cw-fgsm-128-adam_test_result.csv
#   adding: bim-bim-64-adam_ROC.png
#   adding: pgd-df-1024-adam_test_result.csv
#   adding: df-cw-64-adam_test_result.csv
#   adding: pgd-df-512-adam_ROC.png
#   adding: cw-df-1024-adam_ROC.png
#   adding: pgd-cw-512-adam_ROC.png
#   adding: df-bim-128-adam_test_result.csv
#   adding: df-bim-64-adam_ROC.png
#   adding: fgsm-pgd-1024-adam_test_result.csv
#   adding: cw-bim-512-adam_test_result.csv
#   adding: cw-fgsm-128-adam_ROC.png
#   adding: fgsm-fgsm-256-adam_test_result.csv
#   adding: df-df-128-adam_test_result.csv
#   adding: cw-cw-128-adam_test_result.csv
#   adding: df-fgsm-64-adam_ROC.png
#   adding: bim-bim-32-adam_test_result.csv
#   adding: pgd-fgsm-512-adam_ROC.png
#   adding: bim-pgd-64-adam_ROC.png
#   adding: fgsm-pgd-128-adam_test_result.csv
#   adding: df-bim-32-adam_test_result.csv
#   adding: cw-bim-1024-adam_ROC.png
#   adding: pgd-fgsm-128-adam_test_result.csv
#   adding: df-df-64-adam_ROC.png
#   adding: bim-pgd-512-adam_ROC.png
#   adding: fgsm-fgsm-1024-adam_ROC.png
#   adding: bim-cw-128-adam_test_result.csv
#   adding: df-cw-256-adam_ROC.png
#   adding: bim-fgsm-512-adam_ROC.png
#   adding: cw-pgd-1024-adam_test_result.csv
#   adding: df-df-1024-adam_ROC.png
#   adding: pgd-cw-128-adam_test_result.csv
#   adding: df-df-32-adam_test_result.csv
#   adding: pgd-df-128-adam_test_result.csv
#   adding: pgd-pgd-32-adam_ROC.png
#   adding: df-cw-32-adam_ROC.png
#   adding: cw-bim-256-adam_test_result.csv
#   adding: bim-pgd-1024-adam_ROC.png
#   adding: cw-bim-1024-adam_test_result.csv
#   adding: bim-cw-64-adam_test_result.csv
#   adding: pgd-df-32-adam_ROC.png
#   adding: bim-cw-1024-adam_ROC.png
#   adding: df-cw-32-adam_test_result.csv
#   adding: pgd-bim-1024-adam_ROC.png
#   adding: df-bim-32-adam_ROC.png
#   adding: bim-df-128-adam_test_result.csv
#   adding: fgsm-df-64-adam_test_result.csv
#   adding: fgsm-fgsm-512-adam_test_result.csv
#   adding: pgd-pgd-128-adam_ROC.png
#   adding: df-cw-512-adam_test_result.csv
#   adding: fgsm-bim-32-adam_ROC.png
#   adding: bim-df-64-adam_test_result.csv
#   adding: df-bim-512-adam_ROC.png
#   adding: bim-bim-32-adam_ROC.png
#   adding: fgsm-pgd-32-adam_ROC.png
#   adding: pgd-bim-32-adam_ROC.png
#   adding: pgd-pgd-128-adam_test_result.csv
#   adding: pgd-fgsm-64-adam_test_result.csv
#   adding: bim-df-64-adam_ROC.png
#   adding: df-pgd-256-adam_ROC.png
#   adding: pgd-pgd-1024-adam_ROC.png
#   adding: pgd-fgsm-128-adam_ROC.png
#   adding: cw-df-1024-adam_test_result.csv
#   adding: bim-pgd-32-adam_test_result.csv
#   adding: pgd-pgd-512-adam_ROC.png
#   adding: df-pgd-32-adam_ROC.png
#   adding: pgd-fgsm-256-adam_ROC.png
#   adding: df-pgd-64-adam_test_result.csv
#   adding: cw-cw-1024-adam_ROC.png
#   adding: cw-cw-64-adam_test_result.csv
#   adding: df-pgd-128-adam_test_result.csv
#   adding: cw-cw-64-adam_ROC.png
#   adding: df-cw-512-adam_ROC.png
#   adding: bim-df-128-adam_ROC.png
#   adding: df-fgsm-512-adam_ROC.png
#   adding: pgd-fgsm-64-adam_ROC.png
#   adding: bim-pgd-512-adam_test_result.csv
#   adding: pgd-cw-32-adam_test_result.csv
#   adding: df-fgsm-256-adam_ROC.png
#   adding: bim-fgsm-512-adam_test_result.csv
#   adding: bim-df-256-adam_test_result.csv
#   adding: pgd-df-128-adam_ROC.png
#   adding: fgsm-fgsm-256-adam_ROC.png
#   adding: cw-df-64-adam_ROC.png
#   adding: df-bim-1024-adam_ROC.png
#   adding: bim-bim-256-adam_test_result.csv
#   adding: cw-df-512-adam_ROC.png
#   adding: bim-pgd-1024-adam_test_result.csv
#   adding: df-pgd-32-adam_test_result.csv
#   adding: df-bim-512-adam_test_result.csv
#   adding: df-df-512-adam_ROC.png
#   adding: fgsm-bim-1024-adam_test_result.csv
#   adding: cw-pgd-128-adam_ROC.png
#   adding: bim-bim-1024-adam_test_result.csv
#   adding: pgd-fgsm-32-adam_test_result.csv
#   adding: cw-fgsm-512-adam_test_result.csv
#   adding: cw-pgd-1024-adam_ROC.png
#   adding: pgd-cw-64-adam_test_result.csv
#   adding: fgsm-cw-32-adam_ROC.png
#   adding: cw-df-256-adam_ROC.png
#   adding: fgsm-cw-64-adam_ROC.png
#   adding: cw-fgsm-1024-adam_ROC.png
#   adding: cw-fgsm-64-adam_test_result.csv
#   adding: bim-pgd-256-adam_ROC.png
#   adding: bim-bim-512-adam_ROC.png
#   adding: fgsm-cw-512-adam_ROC.png
#   adding: df-df-128-adam_ROC.png
#   adding: fgsm-bim-128-adam_test_result.csv
#   adding: bim-cw-128-adam_ROC.png
#   adding: fgsm-pgd-256-adam_test_result.csv
#   adding: bim-pgd-64-adam_test_result.csv
#   adding: pgd-bim-64-adam_ROC.png
#   adding: bim-fgsm-256-adam_test_result.csv
#   adding: cw-pgd-256-adam_test_result.csv
#   adding: bim-cw-32-adam_ROC.png
#   adding: pgd-pgd-32-adam_test_result.csv
#   adding: cw-pgd-512-adam_ROC.png
#   adding: cw-cw-128-adam_ROC.png
# Computing per-file SHA-256 and writing manifest: /kaggle/working/manifest-evals-TEST-sha256.txt
# Done.
# Created: /kaggle/working/evals-TEST.zip
# Created: /kaggle/working/manifest-evals-TEST-sha256.txt
# Created: /kaggle/working/evals-TEST.zip.sha256

# %%
import hashlib
import os
from pathlib import Path
import zipfile
from datetime import datetime

# -------------------------------
# Config
# -------------------------------
input_dir = Path("/kaggle/working/saved_models")
output_zip = Path("/kaggle/working/saved_models.zip")
manifest_path = Path("/kaggle/working/manifest-saved_models-sha256.txt")
chunk_size = 8 * 1024 * 1024  # 8 MB
skip_files = {output_zip.name, manifest_path.name}

# -------------------------------
# Helper: compute SHA256
# -------------------------------
def sha256_of_file(path: Path) -> str:
    h = hashlib.sha256()
    with path.open("rb") as f:
        while True:
            chunk = f.read(chunk_size)
            if not chunk:
                break
            h.update(chunk)
    return h.hexdigest()

# -------------------------------
# Collect files to zip
# -------------------------------
files_to_add = []
for root, dirs, files in os.walk(input_dir):
    for fname in files:
        full = Path(root) / fname
        rel = full.relative_to(input_dir)
        rel_str = str(rel).replace(os.sep, "/")
        if rel.name in skip_files:
            continue
        files_to_add.append((full, rel))

if not files_to_add:
    print(f"No files found in {input_dir} to archive.")
else:
    # -------------------------------
    # Create zip
    # -------------------------------
    print(f"Creating zip: {output_zip}")
    with zipfile.ZipFile(output_zip, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        for full, rel in files_to_add:
            arcname = str(rel).replace(os.sep, "/")
            print(f"  adding: {arcname}")
            zf.write(full, arcname=arcname)

    # -------------------------------
    # Create manifest
    # -------------------------------
    print(f"Computing per-file SHA-256 and writing manifest: {manifest_path}")
    with manifest_path.open("w", encoding="utf-8") as mf:
        mf.write(f"# manifest generated: {datetime.utcnow().isoformat()}Z\n")
        mf.write(f"# input_dir: {input_dir}\n")
        mf.write("# format: <sha256>  <relative/path>\n")
        for full, rel in files_to_add:
            rel_unix = str(rel).replace(os.sep, "/")
            h = sha256_of_file(full)
            size = full.stat().st_size
            mf.write(f"{h}  {rel_unix}  # {size} bytes\n")

    # -------------------------------
    # Compute zip SHA256
    # -------------------------------
    zip_hash = sha256_of_file(output_zip)
    ziphash_path = output_zip.with_suffix(output_zip.suffix + ".sha256")
    with ziphash_path.open("w", encoding="utf-8") as zh:
        zh.write(f"{zip_hash}  {output_zip.name}\n")

    print("Done.")
    print(f"Created: {output_zip}")
    print(f"Created: {manifest_path}")
    print(f"Created: {ziphash_path}")
# Out:
# Creating zip: /kaggle/working/saved_models.zip
#   adding: best_detector_1024x1024_df.pth
#   adding: best_detector_256x256_pgd.pth
#   adding: best_detector_512x512_cw.pth
#   adding: best_detector_1024x1024_bim.pth
#   adding: best_detector_32x32_pgd.pth
#   adding: best_detector_512x512_pgd.pth
#   adding: best_detector_128x128_df.pth
#   adding: best_detector_512x512_bim.pth
#   adding: best_detector_128x128_fgsm.pth
#   adding: best_detector_32x32_fgsm.pth
#   adding: best_detector_1024x1024_pgd.pth
#   adding: best_detector_64x64_pgd.pth
#   adding: best_detector_64x64_df.pth
#   adding: best_detector_64x64_bim.pth
#   adding: best_detector_512x512_df.pth
#   adding: best_detector_1024x1024_cw.pth
#   adding: best_detector_256x256_bim.pth
#   adding: best_detector_256x256_fgsm.pth
#   adding: best_detector_512x512_fgsm.pth
#   adding: best_detector_32x32_bim.pth
#   adding: best_detector_64x64_cw.pth
#   adding: best_detector_128x128_pgd.pth
#   adding: best_detector_256x256_cw.pth
#   adding: best_detector_128x128_bim.pth
#   adding: best_detector_32x32_df.pth
#   adding: best_detector_1024x1024_fgsm.pth
#   adding: best_detector_128x128_cw.pth
#   adding: best_detector_32x32_cw.pth
#   adding: best_detector_64x64_fgsm.pth
#   adding: best_detector_256x256_df.pth
# Computing per-file SHA-256 and writing manifest: /kaggle/working/manifest-saved_models-sha256.txt
# Done.
# Created: /kaggle/working/saved_models.zip
# Created: /kaggle/working/manifest-saved_models-sha256.txt
# Created: /kaggle/working/saved_models.zip.sha256
